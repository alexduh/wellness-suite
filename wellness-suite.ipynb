# %%
import logging
import os

# Clean up any previous logs
for log_file in ["logger.log", "web.log", "tunnel.log"]:
    if os.path.exists(log_file):
        os.remove(log_file)
        print(f"🧹 Cleaned up {log_file}")

# Configure logging with DEBUG log level.
logging.basicConfig(
    filename="logger.log",
    level=logging.DEBUG,
    format="%(filename)s:%(lineno)s %(levelname)s:%(message)s",
)

print("✅ Logging configured")
# Out:
# ✅ Logging configured

# %%
api_key = os.getenv("GEMINI_API_KEY")

# %%
from typing import Any, Dict

from google.adk.agents import LlmAgent, SequentialAgent, ParallelAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.runners import Runner
from google.adk.plugins.logging_plugin import (LoggingPlugin)
from google.adk.tools import AgentTool, google_search
from google.adk.tools.tool_context import ToolContext
from google.genai import types

# %%
APP_NAME = "Wellness Suite"
USER_ID = "default"
SESSION = "default"

MODEL_NAME = "gemini-2.5-flash-lite"

# %%
retry_config = types.HttpRetryOptions(
    attempts=3,
    exp_base=7, # Delay multiplier
    initial_delay=1, # initial delay before first retry (seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
# Create a SQLite database with DatabaseSessionService
db_url = "sqlite:///agentic_wellness_data.db"

# Set up Session Management
session_service = DatabaseSessionService(db_url=db_url)

# %%
# Helper functions for running a session
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")

# %%
# Session state management tools
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")

# tool for writing to session state
def save_userinfo(
    # 'user:' prefix indicates the following is user-specific data
    tool_context: ToolContext, user_name: str, user_age: str, user_height: str, user_weight: str, user_gender: str,
    user_dietary_preferences: str, user_current_fitness_level: str, user_fitness_goals: str, user_injury_history: str,
) -> Dict[str, Any]:
    """
    Tool to record and save user personal wellness information in session state.

    Args:
        user_name: The username to store in session state
        user_age: The user's age to store in session state
        user_height: The user's height to store in session state
        user_weight: The user's weight to store in session state
        user_gender: The user's gender to store in session state
        user_dietary_preferences: The user's dietary preferences to store in session state
        user_current_fitness_level: The user's current fitness level to store in session state
        user_fitness_goals: The user's fitness goals to store in session state
        user_injury_history: The user's injury history to store in session state
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:age"] = user_age
    tool_context.state["user:height"] = user_height
    tool_context.state["user:weight"] = user_weight
    tool_context.state["user:gender"] = user_gender
    tool_context.state["user:dietary_preferences"] = user_dietary_preferences
    tool_context.state["user:current_fitness_level"] = user_current_fitness_level
    tool_context.state["user:fitness_goals"] = user_fitness_goals
    tool_context.state["user:injury_history"] = user_injury_history

    return {"status": "success"}

# tool for reading from session state
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name from session state.
    """

    user_name = tool_context.state.get("user:name", "User name not found")
    user_age = tool_context.state.get("user:age", "User age not found")
    user_height = tool_context.state.get("user:height", "User height not found")
    user_weight = tool_context.state.get("user:weight", "User weight not found")
    user_gender = tool_context.state.get("user:gender", "User gender not found")
    user_dietary_preferences = tool_context.state.get("user:dietary_preferences", "User dietary preferences not found")
    user_current_fitness_level = tool_context.state.get("user:current_fitness_level", "User current fitness level not found")
    user_fitness_goals = tool_context.state.get("user:fitness_goals", "User fitness goals not found")
    user_injury_history = tool_context.state.get("user:injury_history", "User injury history not found")

    return {"status": "success", "user_name": user_name, "age": user_age, "height": user_height, "weight": user_weight,
            "gender": user_gender, "dietary_preferences": user_dietary_preferences, 
            "current_fitness_level": user_current_fitness_level,
            "fitness_goals": user_fitness_goals, "injury_history": user_injury_history}

# %%
# Specialist Agents

# Fitness Trainer Agent: focuses on fitness
fitness_trainer_agent = LlmAgent(
    name="FitnessTrainer",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert fitness trainer with deep knowledge of human physiology.
    Please provide a detailed fitness training plan for the user
    that is customized for the user's personal wellness information (use the `retrieve_userinfo` tool to obtain this)
    """,
    tools=[retrieve_userinfo],
    output_key="fitness_plan"
)

# Nutritionist Agent: focuses on nutrition
nutritionist_agent = LlmAgent(
    name="Nutritionist",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert nutritionist with deep knowledge of diet and human metabolism.
    Please provide a detailed nutrition plan for the user that is customized
    for the user's personal wellness information (use the `retrieve_userinfo` tool to obtain this)
    Ensure that the nutrition plan meets the macronutrient and micronutrient needs to achieve their goals
    """,
    tools=[retrieve_userinfo],
    output_key="nutrition_plan"
)

# %%
# Aggregator Agent

aggregator_agent = LlmAgent(
    name="WellnessAggregator",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""Combine the fitness plan and nutrition plan into a single wellness plan tailored for the user.
    Focus on the synergy between the fitness and nutrition aspects to maximize the user's health and wellness outcomes.

    **Fitness Plan:**
    {fitness_plan}

    **Nutrition Plan:**
    {nutrition_plan}

    Your final wellness plan should seamlessly integrate both components and provide clear, actionable recommendations.
    """,
    tools=[],
    output_key="wellness_plan"
)

# %%
# Parallel Agent to run both specialists simultaneously
parallel_wellness_team = ParallelAgent(
    name="ParallelWellnessTeam",
    sub_agents=[fitness_trainer_agent, nutritionist_agent],
)

# %%
# Sequential Agent to run the parallel team first, then run the aggregator
sequential_wellness = SequentialAgent(
    name="WellnessSystem",
    sub_agents=[parallel_wellness_team, aggregator_agent],
)

# %%
# Intake Agent

intake_agent = LlmAgent(
    name="WellnessIntakeAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert wellness assistant agent with concise yet kind verbiage.
    Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about their health.
    Use the `retrieve_userinfo` tool to check what information you currently have and lack to determine which questions to ask.
    Craft your questions to collect the most essential information.
    """,
    tools=[retrieve_userinfo],
    output_key="intake_questions",
)

# %%
# Centralized root Wellness Coordinator Agent to provide holistic wellness plan

root_agent = LlmAgent(
    name="WellnessCoordinatorAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are the Wellness Coordinator Agent.
    Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
    1. First, ascertain whether or not you have the user's necessary personal information to provide customized fitness and nutrition advice. Use the `retrieve_userinfo` tool to do so.
    2. If you lack any information, call the `WellnessIntakeAgent` tool to craft questions to obtain the necessary personal information.
    3. Use the `save_userinfo` tool to save personal information about the user over the course of your conversation.
    4. Once you have sufficient information, call the `WellnessSystem` tool to create a wellness plan for the user.
    5. Present the results of the wellness plan to the user.
    """,
    tools=[
        save_userinfo,
        retrieve_userinfo,
        AgentTool(intake_agent),
        AgentTool(sequential_wellness)
    ],
)

# %%
# App with Events Compaction enabled
wellness_app_compacting = App(
    name="wellness_app_compacting",
    root_agent=root_agent,
    plugins=[LoggingPlugin()], 
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=2, # Trigger compaction every 2 invocations
        overlap_size=1, # Keep 1 previous turn for context
    ),
)
# Out:
# /var/folders/p1/bgzqkn9s51lc2t_bx4c0djmr0000gn/T/ipykernel_70680/3334778997.py:6: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %%
wellness_runner_compacting = Runner(app=wellness_app_compacting, session_service=session_service)

# %%
await run_session(
    wellness_runner_compacting,
    [
        """Hello! My name is Hector.
        """
    ],
    "test-db-session-01",
)
# Out:
# User > Hello! My name is Hector.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-9644d759-60a0-4c90-bdd4-7e3a337bf056
# [logging_plugin]    Session ID: test-db-session-01
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'Hello! My name is Hector.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-9644d759-60a0-4c90-bdd4-7e3a337bf056
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-9644d759-60a0-4c90-bdd4-7e3a337bf056
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Token Usage - Input: 648, Output: 11
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: b1f63045-ee18-45cc-bc7e-276c22aea907
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['retrieve_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-033f3dad-3f5e-4383-ab21-dd83185852d0
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-033f3dad-3f5e-4383-ab21-dd83185852d0
# [logging_plugin]    Result: {'status': 'success', 'user_name': 'User name not found', 'age': 'User age not found', 'height': 'User height not found', 'weight': 'User weight not found', 'gender': 'User gender not found', 'dietary_preferences': 'User dietary preferences not found', 'current_fitness_level': 'User current fitness ...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c3672e29-0e83-4ab6-af6c-01e911745a7f
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Token Usage - Input: 774, Output: 114
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 62b9e353-408b-47c6-9d16-498f58fe4706
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['save_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-5afe6b98-5ed8-4fe5-b456-2f0476846a4e
# [logging_plugin]    Arguments: {'user_injury_history': 'User injury history not found', 'user_current_fitness_level': 'User current fitness level not found', 'user_name': 'Hector', 'user_fitness_goals': 'User fitness goals not found', 'user_height': 'User height not found', 'user_age': 'User age not found', 'user_gender': 'User g...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-5afe6b98-5ed8-4fe5-b456-2f0476846a4e
# [logging_plugin]    Result: {'status': 'success'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: b4988d20-bf22-4e8b-be97-2371eb58fc74
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['save_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessIntakeAgent
# [logging_plugin]    Token Usage - Input: 904, Output: 49
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c83a4152-8821-4a6d-ac88-19acfa980244
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessIntakeAgent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['WellnessIntakeAgent']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: WellnessIntakeAgent
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-636b9472-6a33-4779-aa16-b1aa0d6a893e
# [logging_plugin]    Arguments: {'request': 'I need to gather the following information to create a wellness plan: age, height, weight, gender, dietary preferences, current fitness level, fitness goals, and injury history.'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-34956673-630f-4453-b4e0-3b485f0a8114
# [logging_plugin]    Session ID: a39e129d-8f6d-4299-90ce-36bf8922050c
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessIntakeAgent
# [logging_plugin]    User Content: text: 'I need to gather the following information to create a wellness plan: age, height, weight, gender, dietary preferences, current fitness level, fitness goals, and injury history.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-34956673-630f-4453-b4e0-3b485f0a8114
# [logging_plugin]    Starting Agent: WellnessIntakeAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessIntakeAgent
# [logging_plugin]    Invocation ID: e-34956673-630f-4453-b4e0-3b485f0a8114
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    System Instruction: 'You are an expert wellness assistant agent with concise yet kind verbiage.
#     Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about t...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Token Usage - Input: 166, Output: 11
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ba62ad9f-98fe-4ed4-8c61-a87d1b1e3812
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['retrieve_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Function Call ID: adk-9a12a300-a1d0-4f1d-89be-84ad123b6578
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Function Call ID: adk-9a12a300-a1d0-4f1d-89be-84ad123b6578
# [logging_plugin]    Result: {'status': 'success', 'user_name': 'Hector', 'age': 'User age not found', 'height': 'User height not found', 'weight': 'User weight not found', 'gender': 'User gender not found', 'dietary_preferences': 'User dietary preferences not found', 'current_fitness_level': 'User current fitness level not fou...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 36c2f3cd-42b2-444e-bce4-f5f5319bf386
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: function_response: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    System Instruction: 'You are an expert wellness assistant agent with concise yet kind verbiage.
#     Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about t...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Content: text: 'Hello Hector! I'd be happy to help you create a personalized wellness plan. To ensure it's just right for you, could you please share a few details?
#
# Could you let me know your:
# *   Age
# *   Height
# *  ...'
# [logging_plugin]    Token Usage - Input: 289, Output: 123
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 1f743299-0451-4287-90df-ab9fab93ca46
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: text: 'Hello Hector! I'd be happy to help you create a personalized wellness plan. To ensure it's just right for you, could you please share a few details?
#
# Could you let me know your:
# *   Age
# *   Height
# *  ...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessIntakeAgent
# [logging_plugin]    Invocation ID: e-34956673-630f-4453-b4e0-3b485f0a8114
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-34956673-630f-4453-b4e0-3b485f0a8114
# [logging_plugin]    Final Agent: WellnessIntakeAgent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: WellnessIntakeAgent
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-636b9472-6a33-4779-aa16-b1aa0d6a893e
# [logging_plugin]    Result: Hello Hector! I'd be happy to help you create a personalized wellness plan. To ensure it's just right for you, could you please share a few details?
#
# Could you let me know your:
# *   Age
# *   Height
# *   Weight
# *   Gender
# *   Any dietary preferences or restrictions you have
# *   Your current fitness lev...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 8f12a478-f68e-47ac-bc04-2e661e399cb6
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: WellnessIntakeAgent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['WellnessIntakeAgent']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Hello Hector! I'd be happy to help you create a personalized wellness plan. To ensure it's just right for you, could you please share a few details?
#
# Could you let me know your:
# *   Age
# *   Height
# *  ...'
# [logging_plugin]    Token Usage - Input: 1098, Output: 123
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6fe5bcaf-6e59-4568-b71b-b78392646389
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Hello Hector! I'd be happy to help you create a personalized wellness plan. To ensure it's just right for you, could you please share a few details?
#
# Could you let me know your:
# *   Age
# *   Height
# *  ...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite >  Hello Hector! I'd be happy to help you create a personalized wellness plan. To ensure it's just right for you, could you please share a few details?
#
# Could you let me know your:
# *   Age
# *   Height
# *   Weight
# *   Gender
# *   Any dietary preferences or restrictions you have
# *   Your current fitness level (e.g., beginner, intermediate, advanced)
# *   Your main fitness goals (e.g., build strength, improve endurance, lose weight)
# *   And any past or current injuries I should be aware of?
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-9644d759-60a0-4c90-bdd4-7e3a337bf056
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-9644d759-60a0-4c90-bdd4-7e3a337bf056
# [logging_plugin]    Final Agent: WellnessCoordinatorAgent

# %%
await run_session(
    wellness_runner_compacting,
    [
        """I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
        I am currently sedentary but have prior powerlifting experience (about 7 years ago).
        I have no particular dietary preferences or restrictions.
        I tore my left rotator cuff and had it surgically repaired.
        I wish to lose weight and build muscle.
        """
    ],
    "test-db-session-01",
)
# Out:
# User > I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
#         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#         I have no particular dietary preferences or restrictions.
#         I tore my left rotator cuff and had it surgically repaired.
#         I wish to lose weight and build muscle.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-38ddbf7d-150f-4acc-be22-71b14f0a2267
# [logging_plugin]    Session ID: test-db-session-01
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
#         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#         I have no particular dietary prefere...'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-38ddbf7d-150f-4acc-be22-71b14f0a2267
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-38ddbf7d-150f-4acc-be22-71b14f0a2267
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Token Usage - Input: 1305, Output: 119
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 26bad42b-84ee-4483-bdeb-e0cd61d1a576
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['save_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-3a9521d5-baaf-41d6-993d-5203a1984a84
# [logging_plugin]    Arguments: {'user_injury_history': 'Tore left rotator cuff, surgically repaired', 'user_fitness_goals': 'Lose weight and build muscle', 'user_height': '5 foot 6 inches', 'user_age': '30', 'user_dietary_preferences': 'No particular preferences or restrictions', 'user_name': 'Hector', 'user_weight': '170 pounds'...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-3a9521d5-baaf-41d6-993d-5203a1984a84
# [logging_plugin]    Result: {'status': 'success'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: f06a85c3-5d3e-46a5-9380-d513d744a25c
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['save_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessSystem
# [logging_plugin]    Token Usage - Input: 1440, Output: 94
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e90d240d-8b04-4735-be97-37ff82e0391e
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessSystem
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['WellnessSystem']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: WellnessSystem
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-b70d9ed9-f93d-44cc-8152-dd1c171001e2
# [logging_plugin]    Arguments: {'request': 'Create a wellness plan for Hector. He is male, 30 years old, 5 foot 6 inches tall, and weighs 170 pounds. He has no particular dietary preferences or restrictions. He is currently sedentary but has prior powerlifting experience from 7 years ago. His fitness goals are to lose weight and ...}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-0db3573c-75e7-410d-bdb4-b4bea8a5068d
# [logging_plugin]    Session ID: 413d2ad8-3caa-4e26-a725-cb743052cb8a
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessSystem
# [logging_plugin]    User Content: text: 'Create a wellness plan for Hector. He is male, 30 years old, 5 foot 6 inches tall, and weighs 170 pounds. He has no particular dietary preferences or restrictions. He is currently sedentary but has pr...'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-0db3573c-75e7-410d-bdb4-b4bea8a5068d
# [logging_plugin]    Starting Agent: WellnessSystem
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessSystem
# [logging_plugin]    Invocation ID: e-0db3573c-75e7-410d-bdb4-b4bea8a5068d
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ParallelWellnessTeam
# [logging_plugin]    Invocation ID: e-0db3573c-75e7-410d-bdb4-b4bea8a5068d
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: FitnessTrainer
# [logging_plugin]    Invocation ID: e-0db3573c-75e7-410d-bdb4-b4bea8a5068d
# [logging_plugin]    Branch: ParallelWellnessTeam.FitnessTrainer
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: FitnessTrainer
# [logging_plugin]    System Instruction: 'You are an expert fitness trainer with deep knowledge of human physiology.
#     Please provide a detailed fitness training plan for the user
#     that is customized for the user's personal wellness info...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: Nutritionist
# [logging_plugin]    Invocation ID: e-0db3573c-75e7-410d-bdb4-b4bea8a5068d
# [logging_plugin]    Branch: ParallelWellnessTeam.Nutritionist
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    System Instruction: 'You are an expert nutritionist with deep knowledge of diet and human metabolism.
#     Please provide a detailed nutrition plan for the user that is customized
#     for the user's personal wellness infor...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Token Usage - Input: 206, Output: 11
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 53ccd1ad-f229-4bd7-95d7-f58da237503d
# [logging_plugin]    Author: Nutritionist
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['retrieve_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    Function Call ID: adk-d6af9bcb-dc83-4ec8-ada8-9728d0f043f3
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    Function Call ID: adk-d6af9bcb-dc83-4ec8-ada8-9728d0f043f3
# [logging_plugin]    Result: {'status': 'success', 'user_name': 'Hector', 'age': '30', 'height': '5 foot 6 inches', 'weight': '170 pounds', 'gender': 'male', 'dietary_preferences': 'No particular preferences or restrictions', 'current_fitness_level': 'Sedentary with prior powerlifting experience (7 years ago)', 'fitness_goals':...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: cccaffb1-ddf7-488a-ab22-e738c55c7322
# [logging_plugin]    Author: Nutritionist
# [logging_plugin]    Content: function_response: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    System Instruction: 'You are an expert nutritionist with deep knowledge of diet and human metabolism.
#     Please provide a detailed nutrition plan for the user that is customized
#     for the user's personal wellness infor...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    Content: None
# [logging_plugin]    Token Usage - Input: 334, Output: None
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4d985a58-e876-40f4-82aa-6a307cb35fac
# [logging_plugin]    Author: Nutritionist
# [logging_plugin]    Content: None
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: Nutritionist
# [logging_plugin]    Invocation ID: e-0db3573c-75e7-410d-bdb4-b4bea8a5068d
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: FitnessTrainer
# [logging_plugin]    Content: text: 'Hello Hector! I'm excited to help you create a personalized wellness plan. Based on the information you've provided, we'll focus on a balanced approach to weight loss and muscle building, keeping your...'
# [logging_plugin]    Token Usage - Input: 187, Output: 1632
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 157ce586-578c-4190-94a5-54e243f7607c
# [logging_plugin]    Author: FitnessTrainer
# [logging_plugin]    Content: text: 'Hello Hector! I'm excited to help you create a personalized wellness plan. Based on the information you've provided, we'll focus on a balanced approach to weight loss and muscle building, keeping your...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: FitnessTrainer
# [logging_plugin]    Invocation ID: e-0db3573c-75e7-410d-bdb4-b4bea8a5068d
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ParallelWellnessTeam
# [logging_plugin]    Invocation ID: e-0db3573c-75e7-410d-bdb4-b4bea8a5068d
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessAggregator
# [logging_plugin]    Invocation ID: e-0db3573c-75e7-410d-bdb4-b4bea8a5068d
# [logging_plugin] 🔧 TOOL ERROR
# [logging_plugin]    Tool Name: WellnessSystem
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-b70d9ed9-f93d-44cc-8152-dd1c171001e2
# [logging_plugin]    Arguments: {'request': 'Create a wellness plan for Hector. He is male, 30 years old, 5 foot 6 inches tall, and weighs 170 pounds. He has no particular dietary preferences or restrictions. He is currently sedentary but has prior powerlifting experience from 7 years ago. His fitness goals are to lose weight and ...}
# [logging_plugin]    Error: 'Context variable not found: `nutrition_plan`.'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 await run_session(
#       2     wellness_runner_compacting,
#       3     [
#       4         """I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
#       5         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#       6         I have no particular dietary preferences or restrictions.
#       7         I tore my left rotator cuff and had it surgically repaired.
#       8         I wish to lose weight and build muscle.
#       9         """
#      10     ],
#      11     "test-db-session-01",
#      12 )
#
# Cell In[7], line 35, in run_session(runner_instance, user_queries, session_name)
#      32 query = types.Content(role="user", parts=[types.Part(text=query)])
#      34 # Stream the agent's response asynchronously
# ---> 35 async for event in runner_instance.run_async(
#      36     user_id=USER_ID, session_id=session.id, new_message=query
#      37 ):
#      38     # Check if the event contains valid content
#      39     if event.content and event.content.parts:
#      40         # Filter out empty or "None" responses before printing
#      41         if (
#      42             event.content.parts[0].text != "None"
#      43             and event.content.parts[0].text
#      44         ):
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/runners.py:443, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     436       asyncio.create_task(
#     437           _run_compaction_for_sliding_window(
#     438               self.app, session, self.session_service
#     439           )
#     440       )
#     442 async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 443   async for event in agen:
#     444     yield event
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/runners.py:427, in Runner.run_async.<locals>._run_with_trace(new_message, invocation_id)
#     417       yield event
#     419 async with Aclosing(
#     420     self._exec_with_plugin(
#     421         invocation_context=invocation_context,
#    (...)    425     )
#     426 ) as agen:
# --> 427   async for event in agen:
#     428     yield event
#     429 # Run compaction after all events are yielded from the agent.
#     430 # (We don't compact in the middle of an invocation, we only compact at the end of an invocation.)
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/runners.py:653, in Runner._exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     650 else:
#     651   # Step 2: Otherwise continue with normal execution
#     652   async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 653     async for event in agen:
#     654       if not event.partial:
#     655         if self._should_append_event(event, is_live_call):
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/runners.py:416, in Runner.run_async.<locals>._run_with_trace.<locals>.execute(ctx)
#     414 async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     415   async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 416     async for event in agen:
#     417       yield event
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/agents/llm_agent.py:435, in LlmAgent._run_async_impl(self, ctx)
#     433 should_pause = False
#     434 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 435   async for event in agen:
#     436     self.__maybe_save_output_to_state(event)
#     437     yield event
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:356, in BaseLlmFlow.run_async(self, invocation_context)
#     354 last_event = None
#     355 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 356   async for event in agen:
#     357     last_event = event
#     358     yield event
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:443, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     433 async for llm_response in agen:
#     434   # Postprocess after calling the LLM.
#     435   async with Aclosing(
#     436       self._postprocess_async(
#     437           invocation_context,
#    (...)    441       )
#     442   ) as agen:
# --> 443     async for event in agen:
#     444       # Update the mutable event id to avoid conflict
#     445       model_response_event.id = Event.new_id()
#     446       model_response_event.timestamp = datetime.datetime.now().timestamp()
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:545, in BaseLlmFlow._postprocess_async(self, invocation_context, llm_request, llm_response, model_response_event)
#     539 if model_response_event.get_function_calls():
#     540   async with Aclosing(
#     541       self._postprocess_handle_function_calls_async(
#     542           invocation_context, model_response_event, llm_request
#     543       )
#     544   ) as agen:
# --> 545     async for event in agen:
#     546       yield event
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:669, in BaseLlmFlow._postprocess_handle_function_calls_async(self, invocation_context, function_call_event, llm_request)
#     663 async def _postprocess_handle_function_calls_async(
#     664     self,
#     665     invocation_context: InvocationContext,
#     666     function_call_event: Event,
#     667     llm_request: LlmRequest,
#     668 ) -> AsyncGenerator[Event, None]:
# --> 669   if function_response_event := await functions.handle_function_calls_async(
#     670       invocation_context, function_call_event, llm_request.tools_dict
#     671   ):
#     672     auth_event = functions.generate_auth_event(
#     673         invocation_context, function_response_event
#     674     )
#     675     if auth_event:
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:198, in handle_function_calls_async(invocation_context, function_call_event, tools_dict, filters, tool_confirmation_dict)
#     196 """Calls the functions and returns the function response event."""
#     197 function_calls = function_call_event.get_function_calls()
# --> 198 return await handle_function_call_list_async(
#     199     invocation_context,
#     200     function_calls,
#     201     tools_dict,
#     202     filters,
#     203     tool_confirmation_dict,
#     204 )
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:244, in handle_function_call_list_async(invocation_context, function_calls, tools_dict, filters, tool_confirmation_dict)
#     228 tasks = [
#     229     asyncio.create_task(
#     230         _execute_single_function_call_async(
#    (...)    240     for function_call in filtered_calls
#     241 ]
#     243 # Wait for all tasks to complete
# --> 244 function_response_events = await asyncio.gather(*tasks)
#     246 # Filter out None results
#     247 function_response_events = [
#     248     event for event in function_response_events if event is not None
#     249 ]
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:430, in _execute_single_function_call_async(invocation_context, function_call, tools_dict, agent, tool_confirmation)
#     428 with tracer.start_as_current_span(f'execute_tool {tool.name}'):
#     429   try:
# --> 430     function_response_event = await _run_with_trace()
#     431     trace_tool_call(
#     432         tool=tool,
#     433         args=function_args,
#     434         function_response_event=function_response_event,
#     435     )
#     436     return function_response_event
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:379, in _execute_single_function_call_async.<locals>._run_with_trace()
#     377       function_response = error_response
#     378     else:
# --> 379       raise tool_error
#     381 # Step 4: Check if plugin after_tool_callback overrides the function
#     382 # response.
#     383 altered_function_response = (
#     384     await invocation_context.plugin_manager.run_after_tool_callback(
#     385         tool=tool,
#    (...)    389     )
#     390 )
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:366, in _execute_single_function_call_async.<locals>._run_with_trace()
#     364 if function_response is None:
#     365   try:
# --> 366     function_response = await __call_tool_async(
#     367         tool, args=function_args, tool_context=tool_context
#     368     )
#     369   except Exception as tool_error:
#     370     error_response = await _run_on_tool_error_callbacks(
#     371         tool=tool,
#     372         tool_args=function_args,
#     373         tool_context=tool_context,
#     374         error=tool_error,
#     375     )
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/functions.py:788, in __call_tool_async(tool, args, tool_context)
#     782 async def __call_tool_async(
#     783     tool: BaseTool,
#     784     args: dict[str, Any],
#     785     tool_context: ToolContext,
#     786 ) -> Any:
#     787   """Calls the tool."""
# --> 788   return await tool.run_async(args=args, tool_context=tool_context)
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/tools/agent_tool.py:160, in AgentTool.run_async(self, args, tool_context)
#     154 last_content = None
#     155 async with Aclosing(
#     156     runner.run_async(
#     157         user_id=session.user_id, session_id=session.id, new_message=content
#     158     )
#     159 ) as agen:
# --> 160   async for event in agen:
#     161     # Forward state delta to parent session.
#     162     if event.actions.state_delta:
#     163       tool_context.state.update(event.actions.state_delta)
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/runners.py:443, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     436       asyncio.create_task(
#     437           _run_compaction_for_sliding_window(
#     438               self.app, session, self.session_service
#     439           )
#     440       )
#     442 async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 443   async for event in agen:
#     444     yield event
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/runners.py:427, in Runner.run_async.<locals>._run_with_trace(new_message, invocation_id)
#     417       yield event
#     419 async with Aclosing(
#     420     self._exec_with_plugin(
#     421         invocation_context=invocation_context,
#    (...)    425     )
#     426 ) as agen:
# --> 427   async for event in agen:
#     428     yield event
#     429 # Run compaction after all events are yielded from the agent.
#     430 # (We don't compact in the middle of an invocation, we only compact at the end of an invocation.)
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/runners.py:653, in Runner._exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     650 else:
#     651   # Step 2: Otherwise continue with normal execution
#     652   async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 653     async for event in agen:
#     654       if not event.partial:
#     655         if self._should_append_event(event, is_live_call):
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/runners.py:416, in Runner.run_async.<locals>._run_with_trace.<locals>.execute(ctx)
#     414 async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     415   async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 416     async for event in agen:
#     417       yield event
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/agents/sequential_agent.py:77, in SequentialAgent._run_async_impl(self, ctx)
#      74     yield self._create_agent_state_event(ctx)
#      76 async with Aclosing(sub_agent.run_async(ctx)) as agen:
# ---> 77   async for event in agen:
#      78     yield event
#      79     if ctx.should_pause_invocation(event):
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/agents/llm_agent.py:435, in LlmAgent._run_async_impl(self, ctx)
#     433 should_pause = False
#     434 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 435   async for event in agen:
#     436     self.__maybe_save_output_to_state(event)
#     437     yield event
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:356, in BaseLlmFlow.run_async(self, invocation_context)
#     354 last_event = None
#     355 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 356   async for event in agen:
#     357     last_event = event
#     358     yield event
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:375, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     371 # Preprocess before calling the LLM.
#     372 async with Aclosing(
#     373     self._preprocess_async(invocation_context, llm_request)
#     374 ) as agen:
# --> 375   async for event in agen:
#     376     yield event
#     377 if invocation_context.end_invocation:
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:465, in BaseLlmFlow._preprocess_async(self, invocation_context, llm_request)
#     461 for processor in self.request_processors:
#     462   async with Aclosing(
#     463       processor.run_async(invocation_context, llm_request)
#     464   ) as agen:
# --> 465     async for event in agen:
#     466       yield event
#     468 # Run processors for tools.
#     469
#     470 # We may need to wrap some built-in tools if there are other tools
#     471 # because the built-in tools cannot be used together with other tools.
#     472 # TODO(b/448114567): Remove once the workaround is no longer needed.
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/instructions.py:95, in _InstructionsLlmRequestProcessor.run_async(self, invocation_context, llm_request)
#      92 # Handle instruction based on whether static_instruction exists
#      93 if agent.instruction and not agent.static_instruction:
#      94   # Only add to system instructions if no static instruction exists
# ---> 95   si = await self._process_agent_instruction(agent, invocation_context)
#      96   llm_request.append_instructions([si])
#      97 elif agent.instruction and agent.static_instruction:
#      98   # Static instruction exists, so add dynamic instruction to content
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/instructions.py:55, in _InstructionsLlmRequestProcessor._process_agent_instruction(self, agent, invocation_context)
#      53 si = raw_si
#      54 if not bypass_state_injection:
# ---> 55   si = await instructions_utils.inject_session_state(
#      56       raw_si, ReadonlyContext(invocation_context)
#      57   )
#      58 return si
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/utils/instructions_utils.py:124, in inject_session_state(template, readonly_context)
#     121       else:
#     122         raise KeyError(f'Context variable not found: `{var_name}`.')
# --> 124 return await _async_sub(r'{+[^{}]*}+', _replace_match, template)
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/utils/instructions_utils.py:75, in inject_session_state.<locals>._async_sub(pattern, repl_async_fn, string)
#      73 for match in re.finditer(pattern, string):
#      74   result.append(string[last_end : match.start()])
# ---> 75   replacement = await repl_async_fn(match)
#      76   result.append(replacement)
#      77   last_end = match.end()
#
# File ~/venvs/gemini_venv/lib/python3.11/site-packages/google/adk/utils/instructions_utils.py:122, in inject_session_state.<locals>._replace_match(match)
#     120   return ''
#     121 else:
# --> 122   raise KeyError(f'Context variable not found: `{var_name}`.')
#
# KeyError: 'Context variable not found: `nutrition_plan`.'

# %%
# Final session state
final_session = await session_service.get_session(
    app_name=wellness_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="test-db-session-01",
)
found_summary = False
for event in final_session.events:
    if event.actions and event.actions.compaction:
        print("Found Compaction Event")
        print(f"\n Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print("\n No compaction event found.")
# Out:
#  No compaction event found.

# %%
if os.path.exists("agentic_wellness_data.db"):
    os.remove("agentic_wellness_data.db")
print("Cleaned up old database files")
# Out:
# Cleaned up old database files
