# %%
import logging
import os

# Clean up any previous logs
for log_file in ["logger.log", "web.log", "tunnel.log"]:
    if os.path.exists(log_file):
        os.remove(log_file)
        print(f"🧹 Cleaned up {log_file}")

# Configure logging with DEBUG log level.
logging.basicConfig(
    filename="logger.log",
    level=logging.DEBUG,
    format="%(filename)s:%(lineno)s %(levelname)s:%(message)s",
)

print("✅ Logging configured")
# Out:
# ✅ Logging configured

# %%
api_key = os.getenv("GEMINI_API_KEY")

# %%
from typing import Any, Dict

from google.adk.agents import LlmAgent, SequentialAgent, ParallelAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.runners import Runner
from google.adk.plugins.logging_plugin import (LoggingPlugin)
from google.adk.tools import AgentTool, google_search
from google.adk.tools.tool_context import ToolContext
from google.genai import types

# %%
APP_NAME = "Wellness Suite"
USER_ID = "default"
SESSION = "default"

MODEL_NAME = "gemini-2.5-flash-lite"

# %%
retry_config = types.HttpRetryOptions(
    attempts=3,
    exp_base=7, # Delay multiplier
    initial_delay=1, # initial delay before first retry (seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
# Create a SQLite database with DatabaseSessionService
db_url = "sqlite:///agentic_wellness_data.db"

# Set up Session Management
session_service = DatabaseSessionService(db_url=db_url)

# %%
# Helper functions for running a session
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")

# %%
# Session state management tools
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")

# tool for writing to session state
def save_userinfo(
    # 'user:' prefix indicates the following is user-specific data
    tool_context: ToolContext, user_name: str, user_age: str, user_height: str, user_weight: str, user_gender: str,
    user_dietary_preferences: str, user_current_fitness_level: str, user_fitness_goals: str, user_injury_history: str,
) -> Dict[str, Any]:
    """
    Tool to record and save user personal wellness information in session state.

    Args:
        user_name: The username to store in session state
        user_age: The user's age to store in session state
        user_height: The user's height to store in session state
        user_weight: The user's weight to store in session state
        user_gender: The user's gender to store in session state
        user_dietary_preferences: The user's dietary preferences to store in session state
        user_current_fitness_level: The user's current fitness level to store in session state
        user_fitness_goals: The user's fitness goals to store in session state
        user_injury_history: The user's injury history to store in session state
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:age"] = user_age
    tool_context.state["user:height"] = user_height
    tool_context.state["user:weight"] = user_weight
    tool_context.state["user:gender"] = user_gender
    tool_context.state["user:dietary_preferences"] = user_dietary_preferences
    tool_context.state["user:current_fitness_level"] = user_current_fitness_level
    tool_context.state["user:fitness_goals"] = user_fitness_goals
    tool_context.state["user:injury_history"] = user_injury_history

    return {"status": "success"}

# tool for reading from session state
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name from session state.
    """

    user_name = tool_context.state.get("user:name", "User name not found")
    user_age = tool_context.state.get("user:age", "User age not found")
    user_height = tool_context.state.get("user:height", "User height not found")
    user_weight = tool_context.state.get("user:weight", "User weight not found")
    user_gender = tool_context.state.get("user:gender", "User gender not found")
    user_dietary_preferences = tool_context.state.get("user:dietary_preferences", "User dietary preferences not found")
    user_current_fitness_level = tool_context.state.get("user:current_fitness_level", "User current fitness level not found")
    user_fitness_goals = tool_context.state.get("user:fitness_goals", "User fitness goals not found")
    user_injury_history = tool_context.state.get("user:injury_history", "User injury history not found")

    return {"status": "success", "user_name": user_name, "age": user_age, "height": user_height, "weight": user_weight,
            "gender": user_gender, "dietary_preferences": user_dietary_preferences, 
            "current_fitness_level": user_current_fitness_level,
            "fitness_goals": user_fitness_goals, "injury_history": user_injury_history}

# %%
# Specialist Agents

# Fitness Trainer Agent: focuses on fitness
fitness_trainer_agent = LlmAgent(
    name="FitnessTrainer",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert fitness trainer with deep knowledge of human physiology.
    Please provide a detailed fitness training plan for the user
    that is customized for the user's personal wellness information.
    """,
    tools=[retrieve_userinfo],
    output_key="fitness_plan"
)

# Nutritionist Agent: focuses on nutrition
nutritionist_agent = LlmAgent(
    name="Nutritionist",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert nutritionist with deep knowledge of diet and human metabolism.
    Please provide a detailed nutrition plan for the user that is customized
    for the user's personal wellness information.
    Ensure that the nutrition plan meets the macronutrient and micronutrient needs to achieve their goals
    """,
    tools=[retrieve_userinfo],
    output_key="nutrition_plan"
)

# %%
# Aggregator Agent

aggregator_agent = LlmAgent(
    name="WellnessAggregator",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""Combine the fitness plan and nutrition plan into a single wellness plan tailored for the user.
    Focus on the synergy between the fitness and nutrition aspects to maximize the user's health and wellness outcomes.

    **Fitness Plan:**
    {fitness_plan}

    **Nutrition Plan:**
    {nutrition_plan}

    Your final wellness plan should seamlessly integrate both components and provide clear, actionable recommendations.
    """,
    tools=[],
    output_key="wellness_plan"
)

# %%
# Parallel Agent to run both specialists simultaneously
parallel_wellness_team = ParallelAgent(
    name="ParallelWellnessTeam",
    sub_agents=[fitness_trainer_agent, nutritionist_agent],
)

# %%
# Sequential Agent to run the parallel team first, then run the aggregator
sequential_wellness = SequentialAgent(
    name="WellnessSystem",
    sub_agents=[parallel_wellness_team, aggregator_agent],
)

# %%
# Intake Agent

intake_agent = LlmAgent(
    name="WellnessIntakeAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert wellness assistant agent with concise yet kind verbiage.
    Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about their health.
    Use the `retrieve_userinfo` tool to check what information you currently have and lack to determine which questions to ask.
    Craft your questions to collect the most essential information.
    """,
    tools=[retrieve_userinfo],
    output_key="intake_questions",
)

# %%
# Centralized root Wellness Coordinator Agent to provide holistic wellness plan

root_agent = LlmAgent(
    name="WellnessCoordinatorAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are the Wellness Coordinator Agent.
    Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
    1. First, ascertain whether or not you have the user's necessary personal information to provide customized fitness and nutrition advice. Use the `retrieve_userinfo` tool to do so.
    2. If you lack any information, call the `WellnessIntakeAgent` tool to craft questions to obtain the necessary personal information.
    3. Use the `save_userinfo` tool to save personal information about the user over the course of your conversation.
    4. Once you have sufficient information, call the `WellnessSystem` tool to create a wellness plan for the user.
    5. Present the results of the wellness plan to the user.
    """,
    tools=[
        save_userinfo,
        retrieve_userinfo,
        AgentTool(intake_agent),
        AgentTool(sequential_wellness)
    ],
)

# %%
# App with Events Compaction enabled
wellness_app_compacting = App(
    name="wellness_app_compacting",
    root_agent=root_agent,
    plugins=[LoggingPlugin()], 
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=2, # Trigger compaction every 2 invocations
        overlap_size=1, # Keep 1 previous turn for context
    ),
)
# Out:
# /var/folders/p1/bgzqkn9s51lc2t_bx4c0djmr0000gn/T/ipykernel_70680/3334778997.py:6: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %%
wellness_runner_compacting = Runner(app=wellness_app_compacting, session_service=session_service)

# %%
await run_session(
    wellness_runner_compacting,
    [
        """Hello! My name is Hector.
        """
    ],
    "test-db-session-01",
)
# Out:
# User > Hello! My name is Hector.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-024c0dff-8a45-42f7-9eaa-d18e7700e906
# [logging_plugin]    Session ID: test-db-session-01
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'Hello! My name is Hector.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-024c0dff-8a45-42f7-9eaa-d18e7700e906
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-024c0dff-8a45-42f7-9eaa-d18e7700e906
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Token Usage - Input: 648, Output: 11
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 07d7e7ea-0955-412e-a15c-ae2371ba4094
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['retrieve_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-4bad79a2-7ca3-45ae-aba1-efabb49351bd
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-4bad79a2-7ca3-45ae-aba1-efabb49351bd
# [logging_plugin]    Result: {'status': 'success', 'user_name': 'User name not found', 'age': 'User age not found', 'height': 'User height not found', 'weight': 'User weight not found', 'gender': 'User gender not found', 'dietary_preferences': 'User dietary preferences not found', 'current_fitness_level': 'User current fitness ...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: bc0b0197-03df-49d4-8d32-9f0451e040b2
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Token Usage - Input: 774, Output: 114
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2ab1217a-58db-42b7-bdfc-0715ed5f2d37
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['save_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-3bdfca37-a85a-4496-a05f-3b7ce82d1ffe
# [logging_plugin]    Arguments: {'user_current_fitness_level': 'User current fitness level not found', 'user_gender': 'User gender not found', 'user_fitness_goals': 'User fitness goals not found', 'user_height': 'User height not found', 'user_weight': 'User weight not found', 'user_age': 'User age not found', 'user_injury_history'...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-3bdfca37-a85a-4496-a05f-3b7ce82d1ffe
# [logging_plugin]    Result: {'status': 'success'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: bde90640-6488-4c9e-8a23-869d3b976981
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['save_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessIntakeAgent
# [logging_plugin]    Token Usage - Input: 904, Output: 63
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7d41744d-d7f2-4679-8c96-1d48066c54a3
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessIntakeAgent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['WellnessIntakeAgent']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: WellnessIntakeAgent
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-844bf57c-25b1-44b7-8bf5-1c6053b772c1
# [logging_plugin]    Arguments: {'request': 'Hello Hector! To help you create a personalized wellness plan, I need a bit more information. Could you please tell me your age, height, weight, gender, dietary preferences, current fitness level, fitness goals, and any injury history?'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-d158f1f9-e052-4e8d-8943-25cfd2dd4d6d
# [logging_plugin]    Session ID: cd952a80-f7e5-4585-aeac-c47ddf666299
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessIntakeAgent
# [logging_plugin]    User Content: text: 'Hello Hector! To help you create a personalized wellness plan, I need a bit more information. Could you please tell me your age, height, weight, gender, dietary preferences, current fitness level, fit...'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-d158f1f9-e052-4e8d-8943-25cfd2dd4d6d
# [logging_plugin]    Starting Agent: WellnessIntakeAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessIntakeAgent
# [logging_plugin]    Invocation ID: e-d158f1f9-e052-4e8d-8943-25cfd2dd4d6d
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    System Instruction: 'You are an expert wellness assistant agent with concise yet kind verbiage.
#     Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about t...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Token Usage - Input: 179, Output: 11
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7f085de9-1937-4e99-bb25-396799dc4094
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['retrieve_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Function Call ID: adk-016e88a4-edf5-4cd4-aa93-58bf53da104d
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Function Call ID: adk-016e88a4-edf5-4cd4-aa93-58bf53da104d
# [logging_plugin]    Result: {'status': 'success', 'user_name': 'Hector', 'age': 'User age not found', 'height': 'User height not found', 'weight': 'User weight not found', 'gender': 'User gender not found', 'dietary_preferences': 'User dietary preferences not found', 'current_fitness_level': 'User current fitness level not fou...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6e67f7ef-851a-4475-b09d-b707fdf7ee20
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: function_response: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    System Instruction: 'You are an expert wellness assistant agent with concise yet kind verbiage.
#     Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about t...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Content: text: 'Hello Hector! It seems there might be a slight misunderstanding. I'm here to help *you* create a personalized wellness plan! To do that, I'll need a bit of information from you.
#
# Could you please shar...'
# [logging_plugin]    Token Usage - Input: 302, Output: 91
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 42d1e04c-bc3f-4583-bc82-bd14657f0fa4
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: text: 'Hello Hector! It seems there might be a slight misunderstanding. I'm here to help *you* create a personalized wellness plan! To do that, I'll need a bit of information from you.
#
# Could you please shar...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessIntakeAgent
# [logging_plugin]    Invocation ID: e-d158f1f9-e052-4e8d-8943-25cfd2dd4d6d
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-d158f1f9-e052-4e8d-8943-25cfd2dd4d6d
# [logging_plugin]    Final Agent: WellnessIntakeAgent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: WellnessIntakeAgent
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-844bf57c-25b1-44b7-8bf5-1c6053b772c1
# [logging_plugin]    Result: Hello Hector! It seems there might be a slight misunderstanding. I'm here to help *you* create a personalized wellness plan! To do that, I'll need a bit of information from you.
#
# Could you please share your age, height, weight, gender, any dietary preferences you have, your current fitness level, yo...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 5f87b03f-982c-48e1-aeaf-ca2275cfdde9
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: WellnessIntakeAgent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['WellnessIntakeAgent']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Hello Hector! It seems there might be a slight misunderstanding. I'm here to help *you* create a personalized wellness plan! To do that, I'll need a bit of information from you.
#
# Could you please shar...'
# [logging_plugin]    Token Usage - Input: 1075, Output: 91
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 3e417e08-515e-41a6-b66d-377d794033e8
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Hello Hector! It seems there might be a slight misunderstanding. I'm here to help *you* create a personalized wellness plan! To do that, I'll need a bit of information from you.
#
# Could you please shar...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite >  Hello Hector! It seems there might be a slight misunderstanding. I'm here to help *you* create a personalized wellness plan! To do that, I'll need a bit of information from you.
#
# Could you please share your age, height, weight, gender, any dietary preferences you have, your current fitness level, your fitness goals, and if you have any injury history? This will help me tailor the best advice for you.
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-024c0dff-8a45-42f7-9eaa-d18e7700e906
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-024c0dff-8a45-42f7-9eaa-d18e7700e906
# [logging_plugin]    Final Agent: WellnessCoordinatorAgent

# %%
await run_session(
    wellness_runner_compacting,
    [
        """I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
        I am currently sedentary but have prior powerlifting experience (about 7 years ago).
        I have no particular dietary preferences or restrictions.
        I tore my left rotator cuff and had it surgically repaired.
        I wish to lose weight and build muscle.
        """
    ],
    "test-db-session-01",
)
# Out:
# User > I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
#         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#         I have no particular dietary preferences or restrictions.
#         I tore my left rotator cuff and had it surgically repaired.
#         I wish to lose weight and build muscle.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-bb9e13e8-87c6-4e26-b018-fdebcca6c46a
# [logging_plugin]    Session ID: test-db-session-01
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
#         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#         I have no particular dietary prefere...'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-bb9e13e8-87c6-4e26-b018-fdebcca6c46a
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-bb9e13e8-87c6-4e26-b018-fdebcca6c46a
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Token Usage - Input: 1250, Output: 112
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: fe987b8a-83c7-4b8e-b268-2f27aa1e1ff7
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['save_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-9868576d-43e1-499c-8006-8edecba0d646
# [logging_plugin]    Arguments: {'user_age': '30', 'user_name': 'Hector', 'user_current_fitness_level': 'sedentary with prior powerlifting experience (7 years ago)', 'user_gender': 'male', 'user_weight': '170', 'user_injury_history': 'tore left rotator cuff, surgically repaired', 'user_fitness_goals': 'lose weight and build muscle...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-9868576d-43e1-499c-8006-8edecba0d646
# [logging_plugin]    Result: {'status': 'success'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: eb7c6ae9-cdcd-4e14-8ad9-7468b0ea3d46
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['save_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessSystem
# [logging_plugin]    Token Usage - Input: 1378, Output: 79
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6e47dc8b-3c3a-4bee-92dc-f06ce92a2292
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessSystem
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['WellnessSystem']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: WellnessSystem
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-e7327b97-a48c-4be7-9cd1-a721e298b550
# [logging_plugin]    Arguments: {'request': 'Hector is a 30-year-old male, 5\'6" tall, and weighs 170 pounds. He is currently sedentary but has prior powerlifting experience. He has no dietary preferences. His injury history includes a surgically repaired torn left rotator cuff. His fitness goals are to lose weight and build muscl...}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin]    Session ID: 8717fd36-48fb-441b-9431-5ffa607a3641
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessSystem
# [logging_plugin]    User Content: text: 'Hector is a 30-year-old male, 5'6" tall, and weighs 170 pounds. He is currently sedentary but has prior powerlifting experience. He has no dietary preferences. His injury history includes a surgically...'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin]    Starting Agent: WellnessSystem
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessSystem
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ParallelWellnessTeam
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: FitnessTrainer
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin]    Branch: ParallelWellnessTeam.FitnessTrainer
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: FitnessTrainer
# [logging_plugin]    System Instruction: 'You are an expert fitness trainer with deep knowledge of human physiology.
#     Please provide a detailed fitness training plan for the user
#     that is customized for the user's personal wellness info...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: Nutritionist
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin]    Branch: ParallelWellnessTeam.Nutritionist
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    System Instruction: 'You are an expert nutritionist with deep knowledge of diet and human metabolism.
#     Please provide a detailed nutrition plan for the user that is customized
#     for the user's personal wellness infor...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    Content: text: 'Hello Hector,
#
# It's great that you're focusing on your health and fitness goals! With your prior powerlifting experience and current goals of weight loss and muscle gain, we can create a comprehensive...'
# [logging_plugin]    Token Usage - Input: 178, Output: 2032
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7b8133d0-8428-4c4b-a4d7-cbfffb0ea76c
# [logging_plugin]    Author: Nutritionist
# [logging_plugin]    Content: text: 'Hello Hector,
#
# It's great that you're focusing on your health and fitness goals! With your prior powerlifting experience and current goals of weight loss and muscle gain, we can create a comprehensive...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: Nutritionist
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: FitnessTrainer
# [logging_plugin]    Content: text: 'Hello Hector! Based on your information, here's a fitness plan designed to help you lose weight and build muscle.
#
# **Important Considerations:**
#
# *   **Rotator Cuff Injury:** Your previous left rotato...'
# [logging_plugin]    Token Usage - Input: 159, Output: 2219
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6d32b616-ec54-46f4-8a92-2810a1312813
# [logging_plugin]    Author: FitnessTrainer
# [logging_plugin]    Content: text: 'Hello Hector! Based on your information, here's a fitness plan designed to help you lose weight and build muscle.
#
# **Important Considerations:**
#
# *   **Rotator Cuff Injury:** Your previous left rotato...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: FitnessTrainer
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ParallelWellnessTeam
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessAggregator
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: WellnessAggregator
# [logging_plugin]    System Instruction: 'Combine the fitness plan and nutrition plan into a single wellness plan tailored for the user.
#     Focus on the synergy between the fitness and nutrition aspects to maximize the user's health and well...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessAggregator
# [logging_plugin]    Content: text: '## Hector's Integrated Wellness Plan: Rebuilding Strength & Optimizing Health
#
# Hector, this comprehensive wellness plan is designed to synergistically address your goals of weight loss and muscle buil...'
# [logging_plugin]    Token Usage - Input: 8682, Output: 2590
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0cda07a9-d2df-45aa-afc1-ad92447b262c
# [logging_plugin]    Author: WellnessAggregator
# [logging_plugin]    Content: text: '## Hector's Integrated Wellness Plan: Rebuilding Strength & Optimizing Health
#
# Hector, this comprehensive wellness plan is designed to synergistically address your goals of weight loss and muscle buil...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessAggregator
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessSystem
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-5594a1fb-8c9e-4d37-8ca1-117048993d8d
# [logging_plugin]    Final Agent: WellnessSystem
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: WellnessSystem
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-e7327b97-a48c-4be7-9cd1-a721e298b550
# [logging_plugin]    Result: ## Hector's Integrated Wellness Plan: Rebuilding Strength & Optimizing Health
#
# Hector, this comprehensive wellness plan is designed to synergistically address your goals of weight loss and muscle building, while prioritizing the long-term health of your surgically repaired left rotator cuff. We'll l...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7c1ad95e-ebce-4945-9da6-6577a12011b7
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: WellnessSystem
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['WellnessSystem']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: '## Hector's Integrated Wellness Plan: Rebuilding Strength & Optimizing Health
#
# Hector, this comprehensive wellness plan is designed to synergistically address your goals of weight loss and muscle buil...'
# [logging_plugin]    Token Usage - Input: 4167, Output: 2589
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 42ba191a-0a96-483f-b1bb-f6ede8a0e27f
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: '## Hector's Integrated Wellness Plan: Rebuilding Strength & Optimizing Health
#
# Hector, this comprehensive wellness plan is designed to synergistically address your goals of weight loss and muscle buil...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite >  ## Hector's Integrated Wellness Plan: Rebuilding Strength & Optimizing Health
#
# Hector, this comprehensive wellness plan is designed to synergistically address your goals of weight loss and muscle building, while prioritizing the long-term health of your surgically repaired left rotator cuff. We'll leverage your powerlifting background to build strength efficiently, coupled with a precise nutrition strategy to fuel your progress and recovery.
#
# **Core Philosophy:**
#
# This plan is built on the principle that **nutrition fuels performance and recovery, while exercise builds the physique and metabolic engine.** By aligning your food intake with your training demands and recovery needs, we'll maximize your results and minimize the risk of re-injury.
#
# **Phase 1: Foundation & Adaptation (Weeks 1-4)**
#
# This initial phase focuses on re-introducing your body to consistent training and establishing healthy eating habits.
#
# **1. Fitness: Strength Training (3 days/week, non-consecutive)**
#
# *   **Frequency:** 3 days per week (e.g., Monday, Wednesday, Friday). Allow at least one rest day between sessions.
# *   **Focus:** Full body with emphasis on controlled movements, proper form, and shoulder joint protection.
# *   **Sets & Reps:** 3 sets of 10-12 repetitions for most exercises. Prioritize a controlled eccentric (lowering) phase.
# *   **Rest:** 60-90 seconds between sets.
#
# **Workout A:**
#
# *   **Warm-up (5-10 mins):** Light cardio (jogging, cycling), dynamic stretches (arm circles, leg swings, torso twists). **Crucially, include shoulder mobility:** wall slides, band pull-aparts (light resistance), and gentle scapular retraction exercises.
# *   **Lower Body:**
#     *   Goblet Squats: 3x10-12 (Focus on depth and maintaining an upright torso)
#     *   Dumbbell Romanian Deadlifts (RDLs): 3x10-12 (Focus on hip hinge, neutral spine)
#     *   Glute Bridges: 3x12-15
# *   **Upper Body (Push):**
#     *   Incline Dumbbell Press: 3x10-12 (Start with lighter weight, ensure no shoulder impingement. Focus on controlled descent.)
#     *   Push-ups (on knees if needed): 3x AMRAP (As Many Reps As Possible) with good form.
# *   **Upper Body (Pull):**
#     *   Dumbbell Rows: 3x10-12 per arm (Maintain a stable core, avoid excessive torso rotation)
#     *   **Face Pulls:** 3x12-15 (Essential for rear delt and upper back strength, critical for shoulder health)
# *   **Core:**
#     *   Plank: 3x30-60 seconds
#     *   Bird-Dog: 3x10-12 per side
#
# **Workout B:**
#
# *   **Warm-up (5-10 mins):** As above, with specific attention to shoulder mobility.
# *   **Lower Body:**
#     *   Lunges (alternating legs): 3x10-12 per leg
#     *   Leg Press: 3x10-12
#     *   Hamstring Curls: 3x12-15
# *   **Upper Body (Push):**
#     *   Seated Dumbbell Overhead Press: 3x10-12 (Use lighter weight, strict form, avoid excessive back arch. **If any discomfort, substitute with Arnold Press or skip for now.**)
#     *   Dips (assisted if needed): 3x8-10
# *   **Upper Body (Pull):
#     *   Lat Pulldowns (or Assisted Pull-ups): 3x10-12
#     *   Seated Cable Rows: 3x10-12
# *   **Core:**
#     *   Russian Twists (bodyweight or light weight): 3x15-20 per side
#     *   Dead Bug: 3x10-12 per side
#
# **2. Cardiovascular Training (2-3 days/week)**
#
# *   **Frequency:** On rest days from strength training or after your strength workouts.
# *   **Type:** Low-to-moderate intensity steady-state cardio. Prioritize activities that don't aggravate your shoulder.
#     *   Brisk walking
#     *   Cycling (stationary or outdoor)
#     *   Elliptical trainer
# *   **Duration:** 30-45 minutes per session.
# *   **Intensity:** You should be able to hold a conversation (Rate of Perceived Exertion 4-6 out of 10).
#
# **3. Nutrition: Fueling for Growth and Recovery**
#
# *   **Caloric Intake:** ~1700 kcal (slight deficit for weight loss)
# *   **Macronutrient Goals:**
#     *   **Protein:** ~170g (essential for muscle repair and growth)
#     *   **Fat:** ~47g (hormone production, satiety)
#     *   **Carbohydrates:** ~149g (primary energy source for workouts)
# *   **Meal Timing:**
#     *   **Pre-Workout (1-2 hours prior):** Focus on easily digestible carbs and some protein. Examples: Oatmeal with berries and protein powder, banana with a small handful of almonds.
#     *   **Post-Workout (within 1-2 hours):** Prioritize protein and carbohydrates for recovery. Examples: Protein shake with a banana, grilled chicken with sweet potato.
#     *   **Throughout the Day:** Aim for 3 main meals and 1-2 snacks to maintain energy and nutrient supply.
# *   **Food Choices:** Focus on nutrient-dense whole foods.
#     *   **Lean Protein:** Chicken, turkey, fish, eggs, Greek yogurt, cottage cheese, lean beef, legumes, tofu.
#     *   **Complex Carbs:** Oats, quinoa, brown rice, whole grains, sweet potatoes, fruits, vegetables.
#     *   **Healthy Fats:** Avocados, nuts, seeds, olive oil, fatty fish.
# *   **Hydration:** Aim for at least 0.5-1 ounce of water per pound of body weight (approx. 85-170 oz daily).
#
# **4. Flexibility & Mobility (Daily)**
#
# *   Incorporate light stretching and mobility work, with specific attention to:
#     *   **Shoulder Health:** Cat-Cow, thoracic rotations, **gentle** shoulder dislocations with a band/broomstick (light resistance, controlled range of motion), external/internal rotations with light bands.
#     *   **Hips and Thoracic Spine:** Hip flexor stretches, cat-cow, thoracic rotations.
#
# **Phase 2: Progression (Weeks 5-8)**
#
# As your body adapts, we'll gradually increase the challenge.
#
# *   **Fitness:**
#     *   **Strength Training:**
#         *   Increase resistance on exercises where you consistently hit the higher rep range.
#         *   Consider slightly lower rep ranges (8-10) for compound lifts if form is perfect and your shoulder feels strong.
#         *   **Introduce variations cautiously:** Barbell squats (if shoulder allows and form is impeccable), Barbell RDLs, Barbell Overhead Press (start very light, prioritize form and shoulder comfort).
#         *   Add one additional set to 1-2 key exercises.
#     *   **Cardiovascular Training:**
#         *   Increase duration to 45-50 minutes.
#         *   **Consider introducing HIIT once per week:** e.g., 30 seconds sprint/high effort, 60 seconds recovery, repeat 8-10 times. **Monitor shoulder response closely.**
# *   **Nutrition:**
#     *   **Monitor Progress:** If weight loss stalls for 2 weeks, slightly reduce calories by ~100-150 kcal. If you feel excessively fatigued or are losing weight too rapidly, increase by ~100-150 kcal, focusing on carbs and protein.
#
# **Phase 3: Intensification & Specialization (Weeks 9+)**
#
# Continue to build upon your established foundation.
#
# *   **Fitness:**
#     *   **Strength Training:**
#         *   Consider an **Upper/Lower split** or **Push/Pull/Legs (PPL) split** if recovery allows and you desire more volume per muscle group.
#         *   **Introduce powerlifting-style rep ranges (5-8)** for key compound lifts (squat, bench press, deadlift variants) *only if shoulder stability and form are excellent.*
#         *   **Continue to prioritize shoulder health:** Include dedicated rotator cuff strengthening (external/internal rotations with bands/cables, light weight, controlled), and robust upper back work (face pulls, rows, rear delt flyes).
#     *   **Cardiovascular Training:** Maintain a balanced mix of steady-state and HIIT, adjusted to your recovery and overall energy levels.
# *   **Nutrition:**
#     *   **Fine-tune Macros:** Adjust macronutrient ratios based on your body composition changes and how you feel. For example, if muscle gain is a higher priority, you might slightly increase calories from protein and complex carbs.
#
# **Key Synergies & Integrations:**
#
# *   **Nutrition for Recovery:** Adequate protein intake (170g) is crucial for muscle repair after your strength training sessions. Timing your protein and carbohydrate intake around workouts will optimize this process.
# *   **Energy for Performance:** The ~149g of carbohydrates provides the fuel needed for your workouts, especially as you progress to heavier lifting. Prioritizing complex carbs ensures sustained energy release.
# *   **Joint Health:** Healthy fats (avocado, nuts, seeds, fatty fish) provide essential fatty acids that can help manage inflammation, which is beneficial for your rotator cuff.
# *   **Hydration:** Proper hydration is essential for nutrient transport, energy levels, and overall joint lubrication, supporting both your fitness and recovery.
# *   **Weight Management:** The slight caloric deficit (~1700 kcal) will drive weight loss, making your workouts more effective for body recomposition.
#
# **Monitoring Your Progress:**
#
# *   **Weight:** Weigh yourself 1-2 times weekly, consistently (e.g., first thing in the morning). Focus on weekly averages, not daily fluctuations.
# *   **Body Measurements:** Take measurements (waist, hips, chest, arms) every 2-4 weeks.
# *   **Progress Photos:** Take photos every 4 weeks to visually track changes.
# *   **Training Log:** Record weights, reps, and sets. Aim for gradual improvement (e.g., adding 5 lbs, completing an extra rep) each week or two.
# *   **Subjective Feelings:** Pay close attention to your energy levels, sleep quality, mood, and any pain or discomfort, especially around your shoulder.
#
# **Crucial Reminders:**
#
# *   **Listen to Your Body (Especially Your Shoulder):** This is non-negotiable. Never push through sharp or persistent pain. Modify exercises, reduce weight, or skip an exercise if necessary. **Consult with a physical therapist or doctor regarding specific shoulder rehabilitation exercises.**
# *   **Consistency is Paramount:** Adherence to this plan over time will yield the best results. Don't let minor setbacks derail your progress.
# *   **Sleep is Your Recovery Ally:** Aim for 7-9 hours of quality sleep nightly. This is when muscle repair and growth primarily occur.
# *   **Stress Management:** High stress levels can negatively impact hormone balance and recovery. Find healthy outlets for stress.
# *   **Warm-up & Cool-down:** Never skip these. They prepare your body for exercise and aid in recovery.
#
# Hector, this integrated plan provides a roadmap for your success. By carefully balancing your nutrition with your fitness, and by respecting your past injury, you're setting yourself up for sustainable progress and improved overall well-being. Let's check in regularly to make any necessary adjustments as you move forward.
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-bb9e13e8-87c6-4e26-b018-fdebcca6c46a
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-bb9e13e8-87c6-4e26-b018-fdebcca6c46a
# [logging_plugin]    Final Agent: WellnessCoordinatorAgent

# %%
# Final session state
final_session = await session_service.get_session(
    app_name=wellness_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="test-db-session-01",
)
found_summary = False
for event in final_session.events:
    if event.actions and event.actions.compaction:
        print("Found Compaction Event")
        print(f"\n Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print("\n No compaction event found.")
# Out:
# Found Compaction Event
#
#  Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='6b9d0be0-c676-4421-8920-b05d7d6c5765' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1764571095.862366, 'end_timestamp': 1764571148.367968, 'compacted_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'The user, Hector (30, male, 5\'6", 170 lbs, sedentary with prior powerlifting experience, but a surgically repaired left rotator cuff), requested a personalized wellness plan to lose weight and build muscle without specific dietary restrictions.\n\nThe AI agent provided a comprehensive, phased wellness plan focused on integrated fitness and nutrition, prioritizing the health of Hector\'s rotator cuff.\n\n**Key elements of the plan:**\n\n*   **Core Philosophy:** Nutrition fuels performance/recovery, exercise builds physique/metabolic engine.\n*   **Phased Approach:**\n    *   **Phase 1 (Weeks 1-4: Foundation & Adaptation):** Focus on re-introducing training and establishing habits.\n    *   **Phase 2 (Weeks 5-8: Progression):** Gradual increase in challenge.\n    *   **Phase 3 (Weeks 9+: Intensification & Specialization):** Building on foundation, potential for advanced splits/rep ranges.\n*   **Fitness:**\n    *   **Strength Training:** 3 days/week full-body (Workout A & B provided), emphasizing controlled movements, proper form, and shoulder protection. Includes specific shoulder mobility and strengthening exercises (e.g., Face Pulls).\n    *   **Cardiovascular Training:** 2-3 days/week (30-45 mins) of low-to-moderate intensity activities that don\'t aggravate the shoulder.\n    *   **Flexibility & Mobility:** Daily, with a strong focus on shoulder health.\n*   **Nutrition:**\n    *   **Caloric Intake:** ~1700 kcal (slight deficit for weight loss).\n    *   **Macronutrients:** Protein ~170g, Fat ~47g, Carbohydrates ~149g.\n    *   Emphasis on nutrient-dense whole foods and strategic meal timing around workouts.\n    *   Hydration target: 0.5-1 oz of water per pound of body weight.\n*   **Monitoring Progress:** Tracking weight, body measurements, photos, training log, and subjective feelings.\n*   **Crucial Reminders:** Paramount importance of listening to the body (especially the shoulder), consistency, sleep, stress management, and warm-up/cool-down.\n\n**Unresolved Questions/Tasks:** The AI agent concluded by stating, "Let\'s check in regularly to make any necessary adjustments as you move forward," indicating an ongoing need for monitoring and potential modifications to the plan.', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}}, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='3eb32f44-c8b2-4af6-a75c-7727050e05c8' timestamp=1764571163.928878

# %%
if os.path.exists("agentic_wellness_data.db"):
    os.remove("agentic_wellness_data.db")
print("Cleaned up old database files")
# Out:
# Cleaned up old database files
