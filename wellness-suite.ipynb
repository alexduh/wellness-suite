# %%
import logging
import os

# Clean up any previous logs
for log_file in ["logger.log", "web.log", "tunnel.log"]:
    if os.path.exists(log_file):
        os.remove(log_file)
        print(f"🧹 Cleaned up {log_file}")

# Configure logging with DEBUG log level.
logging.basicConfig(
    filename="logger.log",
    level=logging.DEBUG,
    format="%(filename)s:%(lineno)s %(levelname)s:%(message)s",
)

print("✅ Logging configured")
# Out:
# 🧹 Cleaned up logger.log
# ✅ Logging configured

# %%
api_key = os.getenv("GEMINI_API_KEY")

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent, SequentialAgent, ParallelAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner, InMemoryRunner
from google.adk.plugins.logging_plugin import (LoggingPlugin)
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.adk.tools.tool_context import ToolContext
from google.adk.code_executors import BuiltInCodeExecutor
from google.genai import types
# Out:
# Sessions and context engineering (3a) and MAS (1b) and Tools (2a) ADK imports

# %%
APP_NAME = "Wellness Suite"
USER_ID = "default"
SESSION = "default"

MODEL_NAME = "gemini-2.5-flash-lite"

# %%
retry_config = types.HttpRetryOptions(
    attempts=3,
    exp_base=7, # Delay multiplier
    initial_delay=1, # initial delay before first retry (seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
# Create a SQLite database with DatabaseSessionService
db_url = "sqlite:///agentic_wellness_data.db"

# Set up Session Management
session_service = DatabaseSessionService(db_url=db_url)

# %%
# Helper functions for running a session
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")

# %%
# Session state management tools
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")

# tool for writing to session state
def save_userinfo(
    # 'user:' prefix indicates the following is user-specific data
    tool_context: ToolContext, user_name: str, user_age: str, user_height: str, user_weight: str, user_gender: str,
    user_dietary_preferences: str, user_current_fitness_level: str, user_fitness_goals: str, user_injury_history: str,
) -> Dict[str, Any]:
    """
    Tool to record and save user personal wellness information in session state.

    Args:
        user_name: The username to store in session state
        user_age: The user's age to store in session state
        user_height: The user's height to store in session state
        user_weight: The user's weight to store in session state
        user_gender: The user's gender to store in session state
        user_dietary_preferences: The user's dietary preferences to store in session state
        user_current_fitness_level: The user's current fitness level to store in session state
        user_fitness_goals: The user's fitness goals to store in session state
        user_injury_history: The user's injury history to store in session state
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:age"] = user_age
    tool_context.state["user:height"] = user_height
    tool_context.state["user:weight"] = user_weight
    tool_context.state["user:gender"] = user_gender
    tool_context.state["user:dietary_preferences"] = user_dietary_preferences
    tool_context.state["user:current_fitness_level"] = user_current_fitness_level
    tool_context.state["user:fitness_goals"] = user_fitness_goals
    tool_context.state["user:injury_history"] = user_injury_history

    return {"status": "success"}

# tool for reading from session state
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name from session state.
    """

    user_name = tool_context.state.get("user:name", "User name not found")
    user_age = tool_context.state.get("user:age", "User age not found")
    user_height = tool_context.state.get("user:height", "User height not found")
    user_weight = tool_context.state.get("user:weight", "User weight not found")
    user_gender = tool_context.state.get("user:gender", "User gender not found")
    user_dietary_preferences = tool_context.state.get("user:dietary_preferences", "User dietary preferences not found")
    user_current_fitness_level = tool_context.state.get("user:current_fitness_level", "User current fitness level not found")
    user_fitness_goals = tool_context.state.get("user:fitness_goals", "User fitness goals not found")
    user_injury_history = tool_context.state.get("user:injury_history", "User injury history not found")

    return {"status": "success", "user_name": user_name, "age": user_age, "height": user_height, "weight": user_weight,
            "gender": user_gender, "dietary_preferences": user_dietary_preferences, 
            "current_fitness_level": user_current_fitness_level,
            "fitness_goals": user_fitness_goals, "injury_history": user_injury_history}

# %%
# Specialist Agents

# Fitness Trainer Agent: focuses on fitness
fitness_trainer_agent = LlmAgent(
    name="FitnessTrainer",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert fitness trainer with deep knowledge of human physiology.
    Please provide a detailed fitness training plan for the user
    that is customized for the user's personal wellness information (use the `retrieve_userinfo` tool to obtain this)
    """,
    tools=[retrieve_userinfo],
    output_key="fitness_plan"
)

# Nutritionist Agent: focuses on nutrition
nutritionist_agent = LlmAgent(
    name="Nutritionist",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert nutritionist with deep knowledge of diet and human metabolism.
    Please provide a detailed nutrition plan for the user that is customized
    for the user's personal wellness information (use the `retrieve_userinfo` tool to obtain this)
    Ensure that the nutrition plan meets the macronutrient and micronutrient needs to achieve their goals
    """,
    tools=[retrieve_userinfo],
    output_key="nutrition_plan"
)

# %%
# Aggregator Agent

aggregator_agent = LlmAgent(
    name="WellnessAggregator",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""Combine the fitness plan and nutrition plan into a single wellness plan tailored for the user.
    Focus on the synergy between the fitness and nutrition aspects to maximize the user's health and wellness outcomes.

    **Fitness Plan:**
    {fitness_plan}

    **Nutrition Plan:**
    {nutrition_plan}

    Your final wellness plan should seamlessly integrate both components and provide clear, actionable recommendations.
    """,
    tools=[],
    output_key="wellness_plan"
)

# %%
# Parallel Agent to run both specialists simultaneously
parallel_wellness_team = ParallelAgent(
    name="ParallelWellnessTeam",
    sub_agents=[fitness_trainer_agent, nutritionist_agent],
)

# %%
# Sequential Agent to run the parallel team first, then run the aggregator
sequential_wellness = SequentialAgent(
    name="WellnessSystem",
    sub_agents=[parallel_wellness_team, aggregator_agent],
)

# %%
# Intake Agent

intake_agent = LlmAgent(
    name="WellnessIntakeAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert wellness assistant agent with concise yet kind verbiage.
    Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about their health.
    Use the `retrieve_userinfo` tool to check what information you currently have and lack to determine which questions to ask.
    Craft your questions to collect the most essential information.
    """,
    tools=[retrieve_userinfo],
    output_key="intake_questions",
)

# %%
# Centralized root Wellness Coordinator Agent to provide holistic wellness plan

root_agent = LlmAgent(
    name="WellnessCoordinatorAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are the Wellness Coordinator Agent.
    Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
    1. First, ascertain whether or not you have the user's necessary personal information to provide customized fitness and nutrition advice. Use the `retrieve_userinfo` tool to do so.
    2. If you lack any information, call the `WellnessIntakeAgent` tool to craft questions to obtain the necessary personal information.
    3. Use the `save_userinfo` tool to save personal information about the user over the course of your conversation.
    4. Once you have sufficient information, call the `WellnessSystem` tool to create a wellness plan for the user.
    5. Present the results of the wellness plan to the user.
    """,
    tools=[
        save_userinfo,
        retrieve_userinfo,
        AgentTool(intake_agent),
        AgentTool(sequential_wellness)
    ],
)

# %%
# App with Events Compaction enabled
wellness_app_compacting = App(
    name="wellness_app_compacting",
    root_agent=root_agent,
    plugins=[LoggingPlugin()], 
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=2, # Trigger compaction every 2 invocations
        overlap_size=1, # Keep 1 previous turn for context
    ),
)
# Out:
# /var/folders/cq/hp5s_vtn1h3d3ty23tdyfdrc0000gn/T/ipykernel_69694/3334778997.py:6: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %%
wellness_runner_compacting = Runner(app=wellness_app_compacting, session_service=session_service)

# %%
await run_session(
    wellness_runner_compacting,
    [
        """Hello! My name is Hector.
        """
    ],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > Hello! My name is Hector.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-91f53097-9dfe-4cd8-ac33-8babe70e2f06
# [logging_plugin]    Session ID: test-db-session-01
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'Hello! My name is Hector.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-91f53097-9dfe-4cd8-ac33-8babe70e2f06
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-91f53097-9dfe-4cd8-ac33-8babe70e2f06
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Token Usage - Input: 648, Output: 11
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2b1f273d-9b06-404f-a43c-93a7d6aa054e
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['retrieve_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-531873b4-07c6-4e7d-89a1-cf3f80676e7e
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-531873b4-07c6-4e7d-89a1-cf3f80676e7e
# [logging_plugin]    Result: {'status': 'success', 'user_name': 'User name not found', 'age': 'User age not found', 'height': 'User height not found', 'weight': 'User weight not found', 'gender': 'User gender not found', 'dietary_preferences': 'User dietary preferences not found', 'current_fitness_level': 'User current fitness ...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0ebccd71-b375-448e-baf1-d419d2db5cbf
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Token Usage - Input: 774, Output: 114
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2216bf0b-c04e-4b5c-bcb4-a0945e614938
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['save_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-e0194a97-eb0c-476b-ada6-dc6eb3faa211
# [logging_plugin]    Arguments: {'user_dietary_preferences': 'User dietary preferences not found', 'user_age': 'User age not found', 'user_fitness_goals': 'User fitness goals not found', 'user_weight': 'User weight not found', 'user_injury_history': 'User injury history not found', 'user_name': 'Hector', 'user_height': 'User heigh...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-e0194a97-eb0c-476b-ada6-dc6eb3faa211
# [logging_plugin]    Result: {'status': 'success'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 8307aa29-22c1-4970-b664-4806997feb84
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['save_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessIntakeAgent
# [logging_plugin]    Token Usage - Input: 904, Output: 39
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d36bed30-96b3-4ad7-9584-9454be212a14
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessIntakeAgent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['WellnessIntakeAgent']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: WellnessIntakeAgent
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-260e7ca3-7e05-4ebf-addd-f1947f9489bc
# [logging_plugin]    Arguments: {'request': 'Please provide your age, height, weight, gender, dietary preferences, current fitness level, fitness goals, and injury history.'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-2ed6bc78-f49b-49de-9d0e-045cf11e7877
# [logging_plugin]    Session ID: 96b2044c-a093-4956-8cb8-8db1a0a620a2
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessIntakeAgent
# [logging_plugin]    User Content: text: 'Please provide your age, height, weight, gender, dietary preferences, current fitness level, fitness goals, and injury history.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-2ed6bc78-f49b-49de-9d0e-045cf11e7877
# [logging_plugin]    Starting Agent: WellnessIntakeAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessIntakeAgent
# [logging_plugin]    Invocation ID: e-2ed6bc78-f49b-49de-9d0e-045cf11e7877
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    System Instruction: 'You are an expert wellness assistant agent with concise yet kind verbiage.
#     Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about t...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Token Usage - Input: 156, Output: 11
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e054666a-0ea8-40f1-86e0-c3c826572318
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['retrieve_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Function Call ID: adk-153a2390-cf94-4f8a-991f-0575036eaaa0
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Function Call ID: adk-153a2390-cf94-4f8a-991f-0575036eaaa0
# [logging_plugin]    Result: {'status': 'success', 'user_name': 'Hector', 'age': 'User age not found', 'height': 'User height not found', 'weight': 'User weight not found', 'gender': 'User gender not found', 'dietary_preferences': 'User dietary preferences not found', 'current_fitness_level': 'User current fitness level not fou...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ff00aaf2-13c6-47c7-a4ff-13dccf386e15
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: function_response: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    System Instruction: 'You are an expert wellness assistant agent with concise yet kind verbiage.
#     Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about t...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Content: text: 'Thank you for reaching out, Hector! To provide you with the best fitness and nutrition advice, I'll need a bit more information about you. Could you please share your age, height, weight, gender, diet...'
# [logging_plugin]    Token Usage - Input: 279, Output: 58
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9505a8cd-690d-4c1c-a69c-5a38d19b110b
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: text: 'Thank you for reaching out, Hector! To provide you with the best fitness and nutrition advice, I'll need a bit more information about you. Could you please share your age, height, weight, gender, diet...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessIntakeAgent
# [logging_plugin]    Invocation ID: e-2ed6bc78-f49b-49de-9d0e-045cf11e7877
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-2ed6bc78-f49b-49de-9d0e-045cf11e7877
# [logging_plugin]    Final Agent: WellnessIntakeAgent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: WellnessIntakeAgent
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-260e7ca3-7e05-4ebf-addd-f1947f9489bc
# [logging_plugin]    Result: Thank you for reaching out, Hector! To provide you with the best fitness and nutrition advice, I'll need a bit more information about you. Could you please share your age, height, weight, gender, dietary preferences, current fitness level, fitness goals, and any injury history?
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d0f16dda-4fa8-44fe-aa0a-f869d6f2376b
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: WellnessIntakeAgent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['WellnessIntakeAgent']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Thank you for reaching out, Hector! To provide you with the best fitness and nutrition advice, I'll need a bit more information about you. Could you please share your age, height, weight, gender, diet...'
# [logging_plugin]    Token Usage - Input: 1016, Output: 58
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4f276dcf-a6eb-412d-806a-429c6ae0457e
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Thank you for reaching out, Hector! To provide you with the best fitness and nutrition advice, I'll need a bit more information about you. Could you please share your age, height, weight, gender, diet...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite >  Thank you for reaching out, Hector! To provide you with the best fitness and nutrition advice, I'll need a bit more information about you. Could you please share your age, height, weight, gender, dietary preferences, current fitness level, fitness goals, and any injury history?
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-91f53097-9dfe-4cd8-ac33-8babe70e2f06
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-91f53097-9dfe-4cd8-ac33-8babe70e2f06
# [logging_plugin]    Final Agent: WellnessCoordinatorAgent

# %%
await run_session(
    wellness_runner_compacting,
    [
        """I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
        I am currently sedentary but have prior powerlifting experience (about 7 years ago).
        I have no particular dietary preferences or restrictions.
        I tore my left rotator cuff and had it surgically repaired.
        I wish to lose weight and build muscle.
        """
    ],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
#         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#         I have no particular dietary preferences or restrictions.
#         I tore my left rotator cuff and had it surgically repaired.
#         I wish to lose weight and build muscle.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-54c59f74-cd9b-4d53-805e-80dec0ad751d
# [logging_plugin]    Session ID: test-db-session-01
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
#         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#         I have no particular dietary prefere...'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-54c59f74-cd9b-4d53-805e-80dec0ad751d
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-54c59f74-cd9b-4d53-805e-80dec0ad751d
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessSystem
# [logging_plugin]    Token Usage - Input: 1450, Output: 85
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 269619d4-3ad5-4cf2-ac55-3ca9019990f9
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessSystem
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['WellnessSystem']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: WellnessSystem
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-0a850e22-05f4-4c8e-8345-2a1087d0b26d
# [logging_plugin]    Arguments: {'request': 'Hector is a 30-year-old male, 5\'6" and 170 lbs. He is currently sedentary but has prior powerlifting experience (about 7 years ago). He has no particular dietary preferences or restrictions. He tore his left rotator cuff and had it surgically repaired. His fitness goals are to lose wei...}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin]    Session ID: f56a7dc0-17e5-40ed-962a-49352527b860
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_compacting
# [logging_plugin]    Root Agent: WellnessSystem
# [logging_plugin]    User Content: text: 'Hector is a 30-year-old male, 5'6" and 170 lbs. He is currently sedentary but has prior powerlifting experience (about 7 years ago). He has no particular dietary preferences or restrictions. He tore h...'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin]    Starting Agent: WellnessSystem
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessSystem
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ParallelWellnessTeam
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: FitnessTrainer
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin]    Branch: ParallelWellnessTeam.FitnessTrainer
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: FitnessTrainer
# [logging_plugin]    System Instruction: 'You are an expert fitness trainer with deep knowledge of human physiology.
#     Please provide a detailed fitness training plan for the user
#     that is customized for the user's personal wellness info...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: Nutritionist
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin]    Branch: ParallelWellnessTeam.Nutritionist
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    System Instruction: 'You are an expert nutritionist with deep knowledge of diet and human metabolism.
#     Please provide a detailed nutrition plan for the user that is customized
#     for the user's personal wellness infor...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    Content: text: 'Hello Hector,
#
# It's great that you're focusing on your health and fitness goals! Combining weight loss with muscle building is definitely achievable with the right nutrition and training plan. Your pr...' | function_call: retrieve_userinfo
# [logging_plugin]    Token Usage - Input: 197, Output: 93
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 8bb00db4-5adc-4d3e-9c73-67e7771cbae7
# [logging_plugin]    Author: Nutritionist
# [logging_plugin]    Content: text: 'Hello Hector,
#
# It's great that you're focusing on your health and fitness goals! Combining weight loss with muscle building is definitely achievable with the right nutrition and training plan. Your pr...' | function_call: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['retrieve_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    Function Call ID: adk-e959e9b4-9e8a-46a7-949d-c4f0bdf7c00c
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    Function Call ID: adk-e959e9b4-9e8a-46a7-949d-c4f0bdf7c00c
# [logging_plugin]    Result: {'status': 'success', 'user_name': 'Hector', 'age': '30', 'height': '5 foot 6 inches', 'weight': '170 pounds', 'gender': 'male', 'dietary_preferences': 'no particular dietary preferences or restrictions', 'current_fitness_level': 'sedentary with prior powerlifting experience', 'fitness_goals': 'lose...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: dd27c848-ed73-46cd-8cb2-0f86bb60430f
# [logging_plugin]    Author: Nutritionist
# [logging_plugin]    Content: function_response: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    System Instruction: 'You are an expert nutritionist with deep knowledge of diet and human metabolism.
#     Please provide a detailed nutrition plan for the user that is customized
#     for the user's personal wellness infor...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    Content: text: 'Thanks, Hector! I have your information now.
#
# Here is a comprehensive nutrition plan tailored to your goals of losing weight and building muscle, while also considering your past injury:
#
# **1. Caloric...'
# [logging_plugin]    Token Usage - Input: 404, Output: 1866
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: bb188f33-152b-4a9f-a043-9a50f57c8cdb
# [logging_plugin]    Author: Nutritionist
# [logging_plugin]    Content: text: 'Thanks, Hector! I have your information now.
#
# Here is a comprehensive nutrition plan tailored to your goals of losing weight and building muscle, while also considering your past injury:
#
# **1. Caloric...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: Nutritionist
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: FitnessTrainer
# [logging_plugin]    Content: text: 'Hello Hector, it's great that you're getting back into fitness! I understand you're looking to lose weight and build muscle, keeping in mind your past rotator cuff injury. Your previous powerlifting e...'
# [logging_plugin]    Token Usage - Input: 178, Output: 2137
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 47058e37-3a43-47e5-9caa-6232c2772126
# [logging_plugin]    Author: FitnessTrainer
# [logging_plugin]    Content: text: 'Hello Hector, it's great that you're getting back into fitness! I understand you're looking to lose weight and build muscle, keeping in mind your past rotator cuff injury. Your previous powerlifting e...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: FitnessTrainer
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ParallelWellnessTeam
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessAggregator
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: WellnessAggregator
# [logging_plugin]    System Instruction: 'Combine the fitness plan and nutrition plan into a single wellness plan tailored for the user.
#     Focus on the synergy between the fitness and nutrition aspects to maximize the user's health and well...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessAggregator
# [logging_plugin]    Content: text: 'Hello Hector,
#
# It's fantastic that you're ready to embark on a journey to lose weight and build muscle, especially with your prior powerlifting experience. Your commitment to health is commendable, an...'
# [logging_plugin]    Token Usage - Input: 8422, Output: 2259
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c42aa50a-1767-465c-b6e1-d5e9d9bb8ab6
# [logging_plugin]    Author: WellnessAggregator
# [logging_plugin]    Content: text: 'Hello Hector,
#
# It's fantastic that you're ready to embark on a journey to lose weight and build muscle, especially with your prior powerlifting experience. Your commitment to health is commendable, an...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessAggregator
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessSystem
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-a90a6b5d-e4b3-4639-b5ff-c44c3f961a12
# [logging_plugin]    Final Agent: WellnessSystem
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: WellnessSystem
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-0a850e22-05f4-4c8e-8345-2a1087d0b26d
# [logging_plugin]    Result: Hello Hector,
#
# It's fantastic that you're ready to embark on a journey to lose weight and build muscle, especially with your prior powerlifting experience. Your commitment to health is commendable, and we'll create a plan that leverages your strengths while carefully managing your past rotator cuff ...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d77ee2d0-0fb0-47d0-b658-90f412bedd95
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: WellnessSystem
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['WellnessSystem']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Hello Hector,
#
# It's fantastic that you're ready to embark on a journey to lose weight and build muscle, especially with your prior powerlifting experience. Your commitment to health is commendable, an...'
# [logging_plugin]    Token Usage - Input: 3905, Output: 2259
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 886270c7-f32d-4123-a190-202dca736678
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Hello Hector,
#
# It's fantastic that you're ready to embark on a journey to lose weight and build muscle, especially with your prior powerlifting experience. Your commitment to health is commendable, an...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite >  Hello Hector,
#
# It's fantastic that you're ready to embark on a journey to lose weight and build muscle, especially with your prior powerlifting experience. Your commitment to health is commendable, and we'll create a plan that leverages your strengths while carefully managing your past rotator cuff injury.
#
# This wellness plan integrates both fitness and nutrition to create synergy, ensuring you achieve your goals safely and effectively.
#
# ## Hector's Integrated Wellness Plan
#
# **Core Principles:**
#
# 1.  **Prioritize Shoulder Health:** Every aspect of this plan will be designed with your rotator cuff recovery in mind. We'll focus on controlled movements, gradual progression, and listening to your body.
# 2.  **Synergistic Approach:** Nutrition and fitness work hand-in-hand. The right fuel will support your workouts and recovery, while your training will help create the caloric deficit needed for fat loss and the stimulus for muscle growth.
# 3.  **Consistency and Patience:** Building muscle and losing fat takes time and dedication. Focus on consistent effort, and trust the process.
#
# ---
#
# ### **Fitness Plan: Rebuilding Strength and Stamina**
#
# **Goals:** Weight Loss & Muscle Building (Hypertrophy), with emphasis on shoulder safety.
#
# **Training Schedule (4 Days/Week):**
#
# *   **Day 1:** Lower Body & Core
# *   **Day 2:** Upper Body (Push) & Core
# *   **Day 3:** Rest
# *   **Day 4:** Lower Body & Core
# *   **Day 5:** Upper Body (Pull) & Core
# *   **Day 6:** Rest
# *   **Day 7:** Active Recovery / Rest
#
# **Key Considerations for Your Rotator Cuff:**
#
# *   **Start Light:** Prioritize form over weight, especially in the initial weeks.
# *   **Controlled Movements:** Avoid jerky or explosive movements, particularly with upper body exercises.
# *   **Listen to Your Body:** **Crucially, if any exercise causes pain or discomfort in your shoulder, stop immediately.** Consult with a physical therapist or healthcare professional before continuing.
# *   **Shoulder-Specific Warm-ups:** These are vital before any upper body workout to prepare and protect your shoulder.
#
# **Workout Details:**
#
# *   **Warm-up (5-10 minutes before each workout):** Light cardio (e.g., brisk walk, cycling) followed by dynamic stretching relevant to the day's workout.
#     *   **Upper Body Days:** Include specific shoulder warm-ups:
#         *   Resistance band external rotations (light band, 15-20 reps)
#         *   Band pull-aparts (15-20 reps) - focus on squeezing shoulder blades together.
#         *   Controlled arm circles (forward and backward).
# *   **Strength Training:** Focus on controlled eccentric (lowering) and concentric (lifting) phases.
#     *   **Day 1 & 4: Lower Body & Core**
#         *   Barbell Squats: 3 sets of 8-12 reps. Focus on depth and form. (Consider goblet squats or front squats if barbell squats strain your shoulders or knees).
#         *   Romanian Deadlifts (RDLs): 3 sets of 10-15 reps. Maintain a neutral spine.
#         *   Leg Press: 3 sets of 10-15 reps.
#         *   Walking Lunges: 3 sets of 10-12 reps per leg.
#         *   Calf Raises (Seated or Standing): 3 sets of 15-20 reps.
#         *   Core: Plank (3 sets, 30-60 sec hold), Russian Twists (3 sets, 15-20 reps/side), Leg Raises (3 sets, 15-20 reps).
#     *   **Day 2: Upper Body (Push) & Core**
#         *   **Bench Press (Dumbbell or Barbell):** 3 sets of 8-12 reps. **Start very light. Prioritize shoulder safety by keeping shoulder blades retracted and down.** If barbell causes discomfort, use dumbbells.
#         *   **Overhead Press (Dumbbell or Machine):** 3 sets of 8-12 reps. **Begin extremely light. If overhead pressing is painful, substitute with Arnold presses or a machine shoulder press.**
#         *   Incline Dumbbell Press: 3 sets of 10-15 reps.
#         *   Triceps Pushdowns (Cable): 3 sets of 12-15 reps.
#         *   Dips (Assisted or Bench Dips): 3 sets of AMRAP (As Many Reps As Possible) with good form. Focus on bench dips if chest dips aggravate your shoulder.
#         *   Core: As per Day 1.
#     *   **Day 5: Upper Body (Pull) & Core**
#         *   **Pull-ups (Assisted or Lat Pulldowns):** 3 sets of 8-12 reps. Focus on squeezing your back muscles.
#         *   Barbell Rows or Dumbbell Rows: 3 sets of 8-12 reps. Maintain a neutral spine.
#         *   **Face Pulls:** 3 sets of 15-20 reps. **Excellent for shoulder health and upper back.** Use a rope attachment on a cable machine.
#         *   Bicep Curls (Barbell or Dumbbell): 3 sets of 10-15 reps.
#         *   Hammer Curls: 3 sets of 10-15 reps.
#         *   Core: As per Day 1.
# *   **Cool-down (5 minutes):** Static stretching for the muscles worked.
#
# **Progressive Overload:**
#
# *   Gradually increase weight, reps, or sets as you get stronger, ensuring form remains perfect.
# *   Focus on the mind-muscle connection, especially for your back and shoulders.
#
# **Cardio:**
#
# *   Incorporate 2-3 sessions of 20-30 minutes of moderate-intensity cardio per week (e.g., brisk walking, cycling, elliptical) to support fat loss and cardiovascular health.
#
# ---
#
# ### **Nutrition Plan: Fueling Recovery and Growth**
#
# **Goals:** Weight Loss (moderate deficit) & Muscle Building.
#
# **Caloric and Macronutrient Targets (approx. 1700-1800 kcal/day):**
#
# *   **Protein:** 140-170g/day (30-35% of calories) - Crucial for muscle repair and growth.
# *   **Fats:** 47-60g/day (25-30% of calories) - Essential for hormone function and overall health.
# *   **Carbohydrates:** 140-170g/day (35-40% of calories) - Provides energy for workouts.
#
# **Key Nutritional Strategies:**
#
# 1.  **Prioritize Protein:** Distribute protein intake evenly across 4-5 meals/snacks throughout the day to optimize muscle protein synthesis.
# 2.  **Pre- & Post-Workout Nutrition:**
#     *   **Pre-workout (1-2 hours before):** A meal with complex carbs and some protein for sustained energy.
#     *   **Post-workout (within 1-2 hours after):** Focus on protein and carbohydrates to kickstart recovery and replenish glycogen stores.
# 3.  **Hydration:** Aim for at least 8-10 glasses (64-80 oz) of water daily, increasing around workouts. Proper hydration is vital for metabolism and recovery.
# 4.  **Micronutrient Focus for Recovery:**
#     *   **Vitamin C:** Supports collagen synthesis (citrus, berries, bell peppers).
#     *   **Omega-3 Fatty Acids:** Reduce inflammation (fatty fish, flaxseeds, walnuts).
#     *   **Zinc:** Aids wound healing (oysters, beef, pumpkin seeds).
#     *   **Magnesium:** Supports muscle function (leafy greens, nuts).
#     *   **Calcium & Vitamin D:** For bone health (dairy, fortified foods, leafy greens).
#
# **Sample Daily Meal Plan (approx. 1800 kcal):**
#
# *   **Meal 1 (Breakfast):** 1 cup cooked oatmeal with 1 scoop (30g) whey protein, 1/2 cup berries, 1 tbsp chia seeds.
# *   **Meal 2 (Lunch):** 4-5 oz grilled chicken breast or salmon, 1 cup quinoa or brown rice, large mixed green salad with 1 tbsp olive oil and vinegar dressing.
# *   **Meal 3 (Snack/Pre-Workout):** 1 medium apple with 1/4 cup almonds.
# *   **Meal 4 (Post-Workout/Dinner):** 4-5 oz lean ground turkey or lean beef stir-fry with 1-2 cups mixed vegetables (broccoli, bell peppers) and 1/2 cup cooked brown rice or sweet potato.
# *   **Meal 5 (Optional Evening Snack):** 1 cup Greek yogurt (0% or 2%) with 1/4 cup cottage cheese.
#
# ---
#
# ### **Synergy and Lifestyle Integration**
#
# *   **Sleep:** Aim for 7-9 hours of quality sleep per night. This is critical for muscle repair, hormone regulation, and overall recovery.
# *   **Active Recovery:** On rest days, engage in light activities like walking, gentle cycling, or yoga. This promotes blood flow to aid recovery without taxing your body.
# *   **Stress Management:** Chronic stress can hinder progress. Incorporate stress-reducing activities like meditation, deep breathing, or spending time outdoors.
# *   **Listen to Your Body:** This is paramount, especially with your shoulder injury. Pay attention to fatigue levels, hunger cues, and any discomfort. Adjust workouts and nutrition as needed.
# *   **Regular Assessment:** After 4-6 weeks, evaluate your progress. How are you feeling? Are you seeing strength gains? Is your weight changing as desired? Adjust the plan based on your feedback and results. If your shoulder feels robust, you can cautiously increase intensity.
#
# ---
#
# **Path Forward:**
#
# This integrated plan provides a strong foundation. Consistency in both your training and nutrition is key. Remember to celebrate small victories and stay patient. Your dedication, combined with this strategic approach, will lead you to your goals of weight loss and muscle gain while prioritizing your shoulder health.
#
# Please don't hesitate to ask questions or provide feedback as you progress. Let's get started!
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-54c59f74-cd9b-4d53-805e-80dec0ad751d
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-54c59f74-cd9b-4d53-805e-80dec0ad751d
# [logging_plugin]    Final Agent: WellnessCoordinatorAgent

# %%
# Final session state
final_session = await session_service.get_session(
    app_name=wellness_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="test-db-session-01",
)

found_summary = False
for event in final_session.events:
    if event.actions and event.actions.compaction:
        print("Found Compaction Event")
        print(f"\n Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print("\n No compaction event found.")
# Out:
# Found Compaction Event
#
#  Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='e626171a-022c-458f-a4d4-b0d1c2fad96c' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1764545247.199748, 'end_timestamp': 1764545306.356797, 'compacted_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'Hector, a 30-year-old male (5\'6", 170 lbs) with a history of a surgically repaired left rotator cuff and prior powerlifting experience, but currently sedentary, sought advice to lose weight and build muscle. He has no dietary restrictions.\n\nThe Wellness Coordinator Agent provided a detailed, integrated wellness plan focusing on weight loss and muscle building while prioritizing shoulder health.\n\n**Key Information & Decisions:**\n\n1.  **Fitness Plan (4 days/week):**\n    *   **Schedule:** A split routine (Lower Body & Core; Upper Body Push & Core; Lower Body & Core; Upper Body Pull & Core), with two rest days and one active recovery/rest day.\n    *   **Shoulder Safety:** Emphasized starting light, controlled movements, specific shoulder warm-ups (e.g., resistance band external rotations, band pull-aparts), and modifying exercises (e.g., dumbbell bench press, Arnold presses, face pulls) if discomfort occurs.\n    *   **Goals:** Focus on hypertrophy and strength, with progressive overload.\n    *   **Cardio:** 2-3 sessions/week of 20-30 minutes of moderate intensity.\n2.  **Nutrition Plan (approx. 1700-1800 kcal/day):**\n    *   **Macronutrients:** Targeted protein (140-170g), fats (47-60g), and carbohydrates (140-170g) to support a moderate caloric deficit for fat loss while fueling muscle growth and recovery.\n    *   **Strategies:** Prioritize protein, pre- and post-workout nutrition, hydration (8-10 glasses water), and micronutrients (Vitamin C, Omega-3, Zinc, Magnesium, Calcium & Vitamin D).\n    *   **Sample Meal Plan:** A 5-meal daily plan was provided as an example.\n3.  **Lifestyle Integration:** Stressed the importance of 7-9 hours of sleep, active recovery on rest days, stress management, and critically, listening to the body, especially concerning the shoulder injury.\n\n**Unresolved Questions or Tasks:**\n\n*   Hector is encouraged to provide feedback and ask questions as he progresses.\n*   The plan suggests a re-evaluation of progress after 4-6 weeks to make necessary adjustments, implying ongoing monitoring and potential modifications.', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}}, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='097c5945-0e34-4814-a4a9-c1c6a33fb6ae' timestamp=1764545321.785912

# %%
if os.path.exists("agentic_wellness_data.db"):
    os.remove("agentic_wellness_data.db")
print("Cleaned up old database files")
# Out:
# Cleaned up old database files
