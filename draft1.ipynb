# %%
import os

# %%
api_key = os.getenv("GEMINI_API_KEY")

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent, SequentialAgent, ParallelAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner, InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.adk.tools.tool_context import ToolContext
from google.adk.code_executors import BuiltInCodeExecutor
from google.genai import types

print("Sessions and context engineering (3a) and MAS (1b) and Tools (2a) ADK imports")
# Out:
# Sessions and context engineering (3a) and MAS (1b) and Tools (2a) ADK imports

# %%
APP_NAME = "Wellness Suite"
USER_ID = "Hector"
SESSION = "default"
# USER_PROFILE = {
#     "name": USER_ID,
#     "age": None,
#     "weight": None,
#     "height": None,
#     "goals": [],
#     "injuries": [],
#     "dietary_restrictions": []
# }

MODEL_NAME = "gemini-2.5-flash-lite"

# %%
retry_config = types.HttpRetryOptions(
    attempts=3,
    exp_base=7, # Delay multiplier
    initial_delay=1, # initial delay before first retry (seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
# Set up Session Management (stored in RAM)
session_service = InMemorySessionService()

# %%
# Helper functions for running a session
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")

# %%
# Specialist Agents

# Fitness Trainer Agent: focuses on fitness
fitness_trainer_agent = Agent(
    name="FitnessTrainer",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert fitness trainer with deep knowledge of human physiology.
    Please provide a detailed fitness training plan for the user that is customized for the following:
    1. Their current level of fitness
    2. To help them achieve their fitness goals
    3. Takes into consideration their injury history
    4. Sets realistic time frames for developing lifting technique and expertise
    """,
    tools=[],
    output_key="fitness_plan"
)

# Nutritionist Agent: focuses on nutrition
nutritionist_agent = Agent(
    name="Nutritionist",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert nutritionist with deep knowledge of diet and human metabolism.
    Please provide a detailed nutrition plan for the user that is customized for the following:
    1. Their dietary restrictions
    2. To help them achieve their weight and fitness goals
    3. Suggest meal plans that align with their preferences
    4. Ensure that the nutrition plan meets the macronutrient and micronutrient needs to achieve their goals
    """,
    tools=[],
    output_key="nutrition_plan"
)

# %%
# Aggregator Agent

aggregator_agent = Agent(
    name="WellnessAggregator",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""Combine the fitness plan and nutrition plan into a single wellness plan tailored for the user.
    Focus on the synergy between the fitness and nutrition aspects to maximize the user's health and wellness outcomes.

    **Fitness Plan:**
    {fitness_plan}

    **Nutrition Plan:**
    {nutrition_plan}

    Your final wellness plan should seamlessly integrate both components and provide clear, actionable recommendations.
    """,
    output_key="wellness_plan"
)

# %%
# Parallel Agent to run both specialists simultaneously
parallel_wellness_team = ParallelAgent(
    name="ParallelWellnessTeam",
    sub_agents=[fitness_trainer_agent, nutritionist_agent],
)

# %%
# Sequential Agent to run the parallel team first, then run the aggregator
root_agent = SequentialAgent(
    name="WellnessSystem",
    sub_agents=[parallel_wellness_team, aggregator_agent],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    """I am a 30 year old male who weighs 170 lbs and is 5 foot 6 inches tall.
    I have previous lifting and cardio experience but have fallen out of shape and would like to lose 20 lbs while gaining muscle.
    Please create a detailed wellness plan for me."""
)
# Out:
#  ### Created new session: debug_session_id
#
# User > I am a 30 year old male who weighs 170 lbs and is 5 foot 6 inches tall.
#     I have previous lifting and cardio experience but have fallen out of shape and would like to lose 20 lbs while gaining muscle.
#     Please create a detailed wellness plan for me.
# Nutritionist > It's great that you're looking to get back into shape and focus on both fat loss and muscle gain! This is a very achievable goal with a structured approach to nutrition and exercise. As your nutritionist, I'll craft a plan to help you reach your targets.
#
# First, let's establish some baseline information:
#
# *   **Age:** 30 years old
# *   **Sex:** Male
# *   **Weight:** 170 lbs
# *   **Height:** 5'6" (66 inches)
# *   **Goal:** Lose 20 lbs (target weight of 150 lbs) and gain muscle.
#
# **Understanding Your Needs:**
#
# To lose fat, you need to be in a calorie deficit. To gain muscle, you need adequate protein intake and resistance training. The key is to create a deficit that is not so severe that it hinders muscle growth or recovery.
#
# **1. Calorie and Macronutrient Targets:**
#
# We'll start by estimating your Basal Metabolic Rate (BMR) and then your Total Daily Energy Expenditure (TDEE).
#
# *   **BMR (Harris-Benedict Equation):**
#     *   For men: BMR = 88.362 + (13.397 × weight in kg) + (4.799 × height in cm) - (5.677 × age in years)
#     *   Weight in kg: 170 lbs / 2.20462 = 77.11 kg
#     *   Height in cm: 66 inches × 2.54 = 167.64 cm
#     *   BMR = 88.362 + (13.397 × 77.11) + (4.799 × 167.64) - (5.677 × 30)
#     *   BMR = 88.362 + 1033.21 + 804.55 - 170.31
#     *   **BMR ≈ 1755 calories**
#
# *   **TDEE (Total Daily Energy Expenditure):** This accounts for your activity level. Given your "previous lifting and cardio experience" and intention to get back into it, I'll estimate an **"Moderately Active"** level (exercise 3-5 days/week).
#     *   TDEE = BMR × Activity Factor
#     *   Activity Factor for Moderately Active: 1.55
#     *   TDEE ≈ 1755 × 1.55
#     *   **TDEE ≈ 2720 calories**
#
# *   **Calorie Target for Fat Loss and Muscle Gain:**
#     *   To lose approximately 1 lb of fat per week, you generally need a deficit of 500 calories per day. However, for muscle gain alongside fat loss, a more conservative deficit is recommended to preserve muscle mass and energy levels.
#     *   We'll aim for a deficit of **300-500 calories** per day.
#     *   **Target Calorie Intake: 2200 - 2400 calories per day.** Let's start with **2300 calories** as a good middle ground. We can adjust this based on your progress and how you feel.
#
# *   **Macronutrient Breakdown (for ~2300 calories):**
#     *   **Protein:** Crucial for muscle repair and growth, and helps with satiety. Aim for 0.8-1 gram per pound of body weight.
#         *   Target: 170 lbs × 1 g/lb = **170 grams of protein** (170g × 4 calories/g = 680 calories)
#     *   **Fats:** Essential for hormone production and overall health. Aim for 20-30% of your total calories.
#         *   Target: 2300 calories × 0.25 = 575 calories from fat (575 calories / 9 calories/g = **~64 grams of fat**)
#     *   **Carbohydrates:** Provide energy for workouts and daily activities. The remaining calories will come from carbs.
#         *   Calories remaining: 2300 - 680 (protein) - 575 (fat) = 1045 calories
#         *   Target: 1045 calories / 4 calories/g = **~261 grams of carbohydrates**
#
# **Summary of Daily Targets:**
# *   **Calories:** 2300
# *   **Protein:** 170g
# *   **Fat:** 64g
# *   **Carbohydrates:** 261g
#
# **2. Dietary Restrictions & Preferences:**
#
# You haven't specified any dietary restrictions (e.g., vegetarian, vegan, allergies, intolerances) or strong preferences. For now, I will assume a standard omnivore diet. If you have any, please let me know, and I will adjust the plan accordingly.
#
# **3. Meal Plan Example (Omnivore, balanced, focus on whole foods):**
#
# This plan prioritizes lean proteins, complex carbohydrates, healthy fats, and plenty of fruits and vegetables. It's structured around 3 main meals and 2 snacks to help manage hunger and provide sustained energy.
#
# **Meal 1: Breakfast (Approx. 450-500 calories)**
# *   **Option 1:**
#     *   Scrambled Eggs: 3 whole eggs + 2 egg whites
#     *   Oatmeal: 1/2 cup dry rolled oats cooked with water or unsweetened almond milk
#     *   Berries: 1/2 cup mixed berries
#     *   Nuts: 1 tbsp chopped almonds or walnuts
# *   **Option 2:**
#     *   Greek Yogurt: 1 cup plain, non-fat Greek yogurt
#     *   Protein Powder: 1 scoop (whey or plant-based) mixed into yogurt (optional, for extra protein)
#     *   Fruit: 1 medium banana or 1 apple, sliced
#     *   Seeds: 1 tbsp chia seeds or flax seeds
#
# **Meal 2: Lunch (Approx. 550-600 calories)**
# *   **Option 1:**
#     *   Grilled Chicken Breast: 5-6 oz
#     *   Quinoa or Brown Rice: 1 cup cooked
#     *   Mixed Greens Salad: Large portion with cucumber, tomatoes, bell peppers
#     *   Dressing: 1-2 tbsp olive oil and vinegar or a light vinaigrette
# *   **Option 2:**
#     *   Tuna Salad (made with Greek yogurt or light mayo): 1 can (5 oz) tuna
#     *   Whole Wheat Bread: 2 slices
#     *   Avocado: 1/4 medium, sliced
#     *   Side of Carrots and Celery sticks
#
# **Meal 3: Dinner (Approx. 600-650 calories)**
# *   **Option 1:**
#     *   Baked Salmon or Lean Beef Steak: 5-6 oz
#     *   Sweet Potato: 1 medium, baked or roasted
#     *   Steamed Broccoli or Asparagus: 1.5 cups
# *   **Option 2:**
#     *   Lentil Soup or Chili (lean ground turkey or beef): Large bowl (approx. 2 cups)
#     *   Whole Wheat Roll or Small Side Salad
#
# **Snack 1: Mid-Morning/Pre-Workout (Approx. 200-250 calories)**
# *   **Option 1:**
#     *   Apple slices with 2 tbsp peanut butter or almond butter
# *   **Option 2:**
#     *   Rice cakes (2) with cottage cheese (1/2 cup) and a sprinkle of cinnamon
#
# **Snack 2: Mid-Afternoon/Post-Workout (Approx. 200-250 calories)**
# *   **Option 1:**
#     *   Protein Shake: 1 scoop protein powder with water or unsweetened almond milk
# *   **Option 2:**
#     *   Hard-boiled eggs (2) and a small handful of almonds
#
# **Important Notes for Meal Planning:**
#
# *   **Hydration:** Drink at least 8-10 glasses (64-80 oz) of water throughout the day. More if you're sweating heavily during workouts.
# *   **Fiber:** Aim for 25-35 grams of fiber daily from fruits, vegetables, and whole grains.
# *   **Variety:** Feel free to swap out similar foods to keep things interesting. For example, chicken breast for turkey breast, salmon for cod, quinoa for brown rice, broccoli for green beans, etc.
# *   **Portion Control:** Use measuring cups and a food scale initially to ensure you're hitting your targets accurately.
# *   **Listen to Your Body:** If you're feeling excessively hungry or low on energy, we may need to slightly increase calories or adjust macronutrient distribution.
#
# **4. Micronutrient Needs:**
#
# By focusing on whole, unprocessed foods, you'll naturally obtain a wide range of vitamins and minerals.
#
# *   **Calcium & Vitamin D:** Important for bone health, especially with resistance training. Found in dairy (if consumed), fortified plant milks, leafy greens, and fatty fish.
# *   **Iron:** Crucial for energy and oxygen transport. Found in red meat, poultry, fish, beans, and leafy greens.
# *   **Magnesium:** Involved in muscle function and energy production. Found in leafy greens, nuts, seeds, and whole grains.
# *   **Potassium:** Important for fluid balance and muscle contractions. Found in bananas, sweet potatoes, spinach, and beans.
# *   **Vitamins A, C, E:** Antioxidants that support overall health and recovery. Abundant in fruits and vegetables.
# *   **B Vitamins:** Essential for energy metabolism. Found in whole grains, lean meats, eggs, and dairy.
#
# **Supplementation (Optional, but can be beneficial):**
#
# *   **Whey Protein/Plant-Based Protein:** Convenient for hitting protein targets, especially post-workout.
# *   **Creatine Monohydrate:** Well-researched supplement proven to improve strength, power, and muscle mass. 5g per day is a standard dose.
# *   **Multivitamin:** A good insurance policy to cover any potential micronutrient gaps, especially during a calorie deficit.
# *   **Omega-3 Fatty Acids (Fish Oil):** Can help with inflammation and overall cardiovascular health.
#
# **5. Exercise Recommendation (Crucial for Muscle Gain):**
#
# This nutrition plan is designed to support your fitness goals. To effectively lose 20 lbs and gain muscle, you'll need a structured exercise routine.
#
# *   **Resistance Training:** Aim for 3-5 sessions per week, focusing on compound movements (squats, deadlifts, bench press, overhead press, rows). This is key for stimulating muscle protein synthesis.
# *   **Cardio:** Incorporate 2-3 sessions of moderate-intensity cardio per week (e.g., brisk walking, cycling, elliptical) or 1-2 sessions of High-Intensity Interval Training (HIIT) to aid fat burning.
# *   **Progressive Overload:** Consistently challenge your muscles by increasing weight, reps, or sets over time.
# *   **Rest and Recovery:** Allow at least one full rest day per week. Ensure you're getting 7-9 hours of quality sleep per night, as this is when muscle repair and growth occur.
#
# **Monitoring and Adjustments:**
#
# *   **Weigh Yourself:** Once a week, at the same time (ideally morning, after using the restroom, before eating or drinking).
# *   **Take Measurements:** Monthly, measure your waist, chest, arms, and thighs.
# *   **Track Your Progress:** Keep a log of your workouts (weights, reps, sets).
# *   **Listen to Your Body:** Pay attention to energy levels, hunger, recovery, and mood.
#
# **Example Weekly Schedule (Adaptable):**
#
# *   **Monday:** Strength Training (Upper Body Push Focus) + Light Cardio
# *   **Tuesday:** Strength Training (Lower Body Focus)
# *   **Wednesday:** Active Recovery (e.g., walking, stretching) or Light Cardio
# *   **Thursday:** Strength Training (Upper Body Pull Focus)
# *   **Friday:** Strength Training (Full Body or Accessory Work) or HIIT Cardio
# *   **Saturday:** Longer Cardio session or Recreational Activity
# *   **Sunday:** Rest
#
# **Next Steps:**
#
# 1.  **Confirm Dietary Restrictions:** Please let me know if you have any specific food allergies, intolerances, or preferences (e.g., vegetarian, pescatarian, dislike of certain foods).
# 2.  **Start the Plan:** Begin with the 2300 calorie target and the sample meal plan.
# 3.  **Track and Observe:** Monitor your progress for the first 2-3 weeks.
# 4.  **Adjust as Needed:** Based on your results and how you feel, we can fine-tune the calorie and macronutrient targets. For example, if you're not losing weight, we might slightly decrease calories. If you're feeling too fatigued or losing muscle, we might slightly increase them.
#
# This is a comprehensive starting point. I'm here to support you throughout this journey. Let me know your thoughts and any questions you have!
# FitnessTrainer > Hello! It's great you're looking to get back into a fitness routine. Your goal of losing 20 lbs of fat while gaining muscle is ambitious but definitely achievable with a structured and consistent approach. Given your history of lifting and cardio, you have a solid foundation to build upon.
#
# Let's outline a comprehensive wellness plan for you. This plan will focus on progressive overload in your strength training, strategic cardiovascular exercise for fat loss, and nutrition to support muscle gain and fat loss simultaneously.
#
# ---
#
# ## Comprehensive Wellness Plan: Fat Loss & Muscle Gain
#
# **User Profile:**
# *   **Age:** 30
# *   **Sex:** Male
# *   **Weight:** 170 lbs
# *   **Height:** 5'6"
# *   **Goal:** Lose 20 lbs of fat, gain muscle.
# *   **Fitness History:** Previous lifting and cardio experience, currently out of shape.
# *   **Injury History:** (Please provide details about any specific injuries you've had. This is crucial for tailoring exercises and ensuring safety. For now, I'll assume no current, debilitating injuries but will err on the side of caution with exercise selection.)
#
# ---
#
# ### Phase 1: Foundation & Technique Refinement (Weeks 1-6)
#
# This phase is critical for re-establishing proper movement patterns, building a base level of strength and endurance, and assessing your body's response to training. We'll focus on compound movements and gradual progression.
#
# **A. Strength Training:**
#
# *   **Frequency:** 3 days per week, with at least one rest day between sessions (e.g., Monday, Wednesday, Friday).
# *   **Focus:** Full-body workouts to maximize muscle activation and recovery. Emphasis on mastering the form of compound lifts.
# *   **Rep Range:** Primarily in the 8-12 rep range for hypertrophy (muscle growth) and moderate strength.
# *   **Rest:** 60-90 seconds between sets.
# *   **Progressive Overload:** Focus on increasing reps within the target range first, then gradually increasing the weight.
#
# **Workout Structure (Example):**
#
# *   **Warm-up (5-10 minutes):**
#     *   Light cardio (jogging in place, jumping jacks, dynamic stretching like arm circles, leg swings, torso twists).
#     *   Dynamic stretches specific to the day's workout (e.g., bodyweight squats before squatting).
# *   **Workout:**
#     *   **Lower Body:**
#         *   **Goblet Squats:** 3 sets of 8-12 reps. (Excellent for learning squat mechanics with less stress on the lower back initially.)
#         *   **Romanian Deadlifts (RDLs):** 3 sets of 10-15 reps. (Focus on hamstring and glute engagement, keeping the back straight. Use dumbbells or a light barbell.)
#         *   **Walking Lunges (Bodyweight or Light Dumbbells):** 3 sets of 10-12 reps per leg. (Improves balance and unilateral leg strength.)
#     *   **Upper Body (Push):**
#         *   **Incline Dumbbell Press:** 3 sets of 8-12 reps. (Easier on the shoulders than flat bench for many.)
#         *   **Overhead Dumbbell Press (Seated or Standing):** 3 sets of 8-12 reps. (Focus on controlled movement.)
#         *   **Push-ups (Knee or Full):** 3 sets to near failure (aim for 8-15 reps). (Scale as needed.)
#     *   **Upper Body (Pull):**
#         *   **Assisted Pull-ups or Lat Pulldowns:** 3 sets of 8-12 reps. (If you can't do unassisted pull-ups yet, use an assist machine or bands.)
#         *   **Seated Cable Rows or Dumbbell Rows:** 3 sets of 10-15 reps. (Focus on squeezing shoulder blades together.)
#     *   **Core:**
#         *   **Plank:** 3 sets, hold for 30-60 seconds.
#         *   **Bird-Dog:** 3 sets of 10-12 reps per side.
# *   **Cool-down (5 minutes):** Static stretching, holding each stretch for 30 seconds (quads, hamstrings, chest, back).
#
# **Technique Focus:**
# *   **Squat:** Chest up, back straight, descend until thighs are parallel to the floor (or as deep as comfortable with good form), drive through heels.
# *   **RDL:** Slight bend in knees, hinge at hips, keep back flat, feel stretch in hamstrings.
# *   **Deadlift (Introduce later):** For now, RDLs are safer for technique building. When ready for conventional deadlifts, start with very light weight and focus on the setup, hip hinge, and keeping the bar close to the body.
# *   **Pressing:** Controlled descent, maintain a stable shoulder.
# *   **Pulling:** Engage back muscles, not just arms.
#
# **Time Frame for Technique Expertise:**
# *   **Phase 1 (Weeks 1-6):** Focus on understanding and performing the basic movements correctly with lighter weights. You should feel confident with the form of the exercises listed.
# *   **Phase 2 (Weeks 7-12):** Introduce slightly more complex variations or increase weight more significantly, building upon the foundation. By the end of this phase, you should have a solid grasp of the primary compound lifts.
#
# **B. Cardiovascular Exercise:**
#
# *   **Frequency:** 3-4 days per week, ideally on non-lifting days or after lifting sessions if time is a constraint.
# *   **Focus:** Moderate-intensity steady-state (MISS) cardio to burn calories and improve cardiovascular health without excessively taxing recovery.
# *   **Duration:** 30-40 minutes.
# *   **Intensity:** Aim for a heart rate zone of 60-70% of your maximum heart rate (roughly 220 - age). You should be able to hold a conversation, but it should require some effort.
# *   **Examples:** Brisk walking, cycling, elliptical, jogging at a comfortable pace.
#
# **C. Nutrition:**
#
# *   **Caloric Intake:** To lose fat and gain muscle simultaneously, a slight caloric deficit is needed. Aim for a deficit of **300-500 calories below your Total Daily Energy Expenditure (TDEE)**.
#     *   **Estimating TDEE:** For a 30-year-old male, 170 lbs, 5'6" with a sedentary job and exercising 3-4 times a week, your TDEE might be around 2300-2600 calories.
#     *   **Target Intake:** Aim for approximately **1800-2100 calories per day**. This is a starting point; monitor your progress and adjust.
# *   **Macronutrient Split:**
#     *   **Protein:** Crucial for muscle repair and growth. Aim for **0.8-1 gram of protein per pound of body weight** (approx. 135-170g).
#     *   **Fats:** Essential for hormone production. Aim for **20-30% of your total calories** (approx. 40-70g).
#     *   **Carbohydrates:** Fuel for workouts and recovery. Fill the remaining calories with complex carbohydrates.
# *   **Key Principles:**
#     *   **Prioritize Whole Foods:** Lean proteins (chicken breast, fish, lean beef, eggs, Greek yogurt), complex carbs (oats, brown rice, quinoa, sweet potatoes, fruits, vegetables), healthy fats (avocado, nuts, seeds, olive oil).
#     *   **Hydration:** Drink plenty of water throughout the day (aim for at least 0.5 oz per pound of body weight, so 85 oz+).
#     *   **Meal Timing:** Distribute protein intake throughout the day. Consume carbs before and after workouts for energy and recovery.
#     *   **Limit Processed Foods:** Reduce intake of sugary drinks, fried foods, excessive sweets, and refined grains.
#
# **D. Recovery:**
#
# *   **Sleep:** Aim for 7-9 hours of quality sleep per night. This is when muscle repair and growth occur.
# *   **Rest Days:** Essential for muscle recovery and preventing burnout.
# *   **Active Recovery (Optional):** Light activities like walking or stretching on rest days can aid blood flow.
#
# ---
#
# ### Phase 2: Progression & Intensity Increase (Weeks 7-12)
#
# Once you've established good form and a baseline of fitness, we'll start pushing your limits safely.
#
# **A. Strength Training:**
#
# *   **Frequency:** 3-4 days per week. You can continue with full-body or consider an upper/lower split or push/pull/legs split if you feel ready and have more time for recovery. Let's stick with **3 days of full-body for simplicity and effectiveness in this phase.**
# *   **Focus:** Increase weight and intensity. Introduce slightly more challenging exercise variations.
# *   **Rep Range:** Continue with 8-12 reps for most exercises, but you can introduce some sets in the 6-8 rep range for primary compound lifts to build more strength.
# *   **Rest:** 60-90 seconds.
#
# **Workout Structure (Example - building on Phase 1):**
#
# *   **Warm-up:** Same as Phase 1.
# *   **Workout:**
#     *   **Lower Body:**
#         *   **Barbell Back Squats:** 3 sets of 6-10 reps. (Focus on depth and controlled movement. Start light to ensure form.)
#         *   **Conventional Deadlifts:** 1-2 sets of 5 reps (after warm-up sets). **Crucial to watch videos and possibly get a trainer to check form.** If not confident, stick with RDLs or Sumo Deadlifts with lighter weight.
#         *   **Bulgarian Split Squats:** 3 sets of 8-10 reps per leg. (More challenging unilateral exercise.)
#         *   **Hamstring Curls (Machine):** 3 sets of 10-15 reps.
#     *   **Upper Body (Push):**
#         *   **Barbell Bench Press:** 3 sets of 6-10 reps. (If comfortable with form. Otherwise, continue with dumbbell press.)
#         *   **Overhead Barbell Press (Standing):** 3 sets of 6-10 reps. (More core engagement than seated.)
#         *   **Dips (Assisted or Bodyweight):** 3 sets to near failure (aim for 6-12 reps).
#     *   **Upper Body (Pull):**
#         *   **Pull-ups (Weighted if possible, or continue assisted/lat pulldowns):** 3 sets of 6-10 reps.
#         *   **Barbell Rows or T-Bar Rows:** 3 sets of 8-12 reps.
#         *   **Face Pulls:** 3 sets of 15-20 reps. (Excellent for shoulder health and rear deltoids.)
#     *   **Core:**
#         *   **Hanging Leg Raises:** 3 sets of 10-15 reps.
#         *   **Russian Twists (with weight):** 3 sets of 15-20 reps per side.
# *   **Cool-down:** Same as Phase 1.
#
# **Progressive Overload:**
# *   **Increase Weight:** Once you can comfortably hit the higher end of the rep range for all sets with good form, increase the weight by the smallest increment possible (e.g., 2.5-5 lbs for upper body, 5-10 lbs for lower body).
# *   **Increase Reps:** If you can't increase weight yet, try to get one or two extra reps on a set.
# *   **Increase Sets:** Occasionally add an extra set if you feel your recovery is good.
# *   **Decrease Rest:** Shorter rest periods increase intensity.
#
# **B. Cardiovascular Exercise:**
#
# *   **Frequency:** 3-4 days per week.
# *   **Focus:** Introduce **High-Intensity Interval Training (HIIT)** 1-2 times per week. This is more time-efficient for fat burning and can boost metabolism. Keep 2-3 sessions as MISS.
# *   **HIIT Protocol (Example - Treadmill or Bike):**
#     *   Warm-up: 5 minutes easy pace.
#     *   Intervals: 30 seconds sprint (85-95% max effort) followed by 60-90 seconds active recovery (light jog/walk). Repeat for 8-12 rounds.
#     *   Cool-down: 5 minutes easy pace.
# *   **Duration:** HIIT sessions are shorter (around 20-25 minutes including warm-up/cool-down), while MISS sessions remain 30-40 minutes.
# *   **Intensity:** HIIT should feel challenging, pushing your cardiovascular limits.
#
# **C. Nutrition:**
#
# *   **Monitor and Adjust:** Continue tracking your food intake and weight. If you're not losing about 1-2 lbs per week, you may need to slightly decrease your caloric intake by another 100-200 calories or increase cardio. If you're losing weight too quickly or feeling extremely fatigued, increase calories slightly.
# *   **Refeed Days (Optional):** Once every 1-2 weeks, you might consider a higher-carb, slightly higher-calorie day to help with leptin levels and metabolism, especially if you're feeling plateaued or low on energy. This should be strategically planned around your heaviest training days.
#
# **D. Recovery:**
#
# *   **Listen to Your Body:** Pay close attention to fatigue, soreness, and potential pain. Don't push through sharp or joint pain.
# *   **Mobility Work:** Incorporate dynamic mobility exercises daily or on rest days.
# *   **Foam Rolling:** Can help alleviate muscle soreness.
#
# ---
#
# ### Injury History Consideration
#
# This is the most critical piece of information I'm missing. Please provide details on any past injuries (e.g., knee pain, shoulder impingement, back issues, disc problems, tendonitis).
#
# **General Guidelines based on potential common issues:**
#
# *   **Knee Pain:** Focus on proper squat and deadlift form. Avoid deep squats if they cause pain. Consider alternatives like leg press with controlled depth or focus more on RDLs and glute-focused exercises. Ensure strong glutes and hamstrings.
# *   **Shoulder Pain:** Be cautious with overhead pressing. Incline dumbbell press is often better tolerated. Ensure good scapular retraction and depression during pressing and pulling. Face pulls and rear delt exercises are crucial.
# *   **Lower Back Pain:** **Deadlifts and heavy squats require extreme caution.** Master the hip hinge with RDLs first. Consider lower-impact variations like trap bar deadlifts if conventional ones are problematic. Focus on core strength (planks, bird-dogs, anti-rotation exercises). Never round your back under load.
#
# **If you have specific injuries, please tell me so I can modify specific exercises and provide safer alternatives.**
#
# ---
#
# ### Realistic Time Frames for Goals
#
# *   **Lifting Technique & Expertise:**
#     *   **Initial Mastery (Phase 1 - Weeks 1-6):** You should feel comfortable and confident with the basic form of compound movements.
#     *   **Intermediate Proficiency (Phase 2 - Weeks 7-12):** You'll be able to handle heavier weights with good form and understand how to progress.
#     *   **Advanced Mastery:** This takes years of consistent practice and attention to detail. After 12 weeks, you'll be well on your way to developing a solid foundation.
# *   **Fat Loss (20 lbs):**
#     *   A healthy rate of fat loss is **1-2 lbs per week.**
#     *   Losing 20 lbs could realistically take **10-20 weeks (2.5 to 5 months)**, depending on adherence to nutrition and training. Trying to lose it faster often leads to muscle loss and is unsustainable.
# *   **Muscle Gain:**
#     *   Muscle gain is a slower process than fat loss, especially when in a caloric deficit.
#     *   In Phase 1 and 2, your focus is on *preserving* muscle while losing fat and building a base. Significant "visible" muscle gain while in a deficit is harder.
#     *   After the initial 12 weeks, you might have built a noticeable amount of strength and potentially a small amount of lean muscle.
#     *   True muscle building (hypertrophy) is best achieved in a slight caloric surplus. Once you reach your fat loss goal or are happy with your body composition, you can transition to a "lean bulk" phase.
#     *   **Realistic Muscle Gain Goal:** Over the first 3-6 months, aiming for 0.5-1 lb of muscle gain per month is excellent for someone in your situation.
#
# ---
#
# ### Summary & Next Steps
#
# 1.  **Provide Injury Details:** Please share your injury history so I can fine-tune the exercise selection.
# 2.  **Start Phase 1:** Begin the program as outlined, focusing heavily on learning and executing movements with perfect form.
# 3.  **Track Everything:**
#     *   **Workouts:** Log your exercises, sets, reps, and weights.
#     *   **Nutrition:** Use a food tracking app (MyFitnessPal, Cronometer) to monitor calorie and macronutrient intake.
#     *   **Body Weight:** Weigh yourself 2-3 times per week (morning, fasted) and take a weekly average.
#     *   **Measurements:** Take waist, hip, chest, and arm measurements every 2-4 weeks.
#     *   **Progress Photos:** Take photos every 4 weeks in the same lighting and pose.
# 4.  **Be Patient & Consistent:** Progress isn't always linear. There will be good weeks and challenging weeks. Consistency is the most important factor.
# 5.  **Listen to Your Body:** Recovery and injury prevention are paramount.
#
# This is a comprehensive blueprint to get you started. As you progress, we can make adjustments based on your results and how you're feeling. Let's get to work!
# WellnessAggregator > ## Comprehensive Wellness Plan: Fat Loss & Muscle Gain
#
# This plan is designed for you, a 30-year-old male, 5'6" and 170 lbs, aiming to lose 20 lbs of fat while building muscle. It synergizes nutrition and fitness to maximize your results.
#
# ---
#
# ### **Your Foundation & Goals**
#
# *   **Age:** 30
# *   **Sex:** Male
# *   **Weight:** 170 lbs
# *   **Height:** 5'6"
# *   **Primary Goal:** Lose 20 lbs of fat, gain muscle.
# *   **Target Weight:** 150 lbs
# *   **Fitness History:** Previous experience with lifting and cardio, currently out of shape.
# *   **Injury History:** **Crucial Information Needed:** Please provide details about any past injuries (e.g., knee pain, shoulder impingement, back issues, etc.) so specific exercise modifications can be made for safety.
#
# ---
#
# ### **Phase 1: Foundation & Technique Refinement (Weeks 1-6)**
#
# This phase focuses on re-establishing proper movement patterns, building a base of strength and cardiovascular fitness, and optimizing your nutrition for fat loss and muscle preservation.
#
# **A. Strength Training (3 Days/Week, e.g., Mon, Wed, Fri)**
#
# *   **Focus:** Full-body workouts to maximize muscle activation and recovery. Emphasis on mastering compound lift form.
# *   **Rep Range:** 8-12 reps (hypertrophy & strength endurance).
# *   **Rest:** 60-90 seconds between sets.
# *   **Progressive Overload:** Prioritize increasing reps within the target range first, then gradually increasing weight.
#
# **Workout Structure (Example):**
#
# *   **Warm-up (5-10 min):** Light cardio, dynamic stretching (arm circles, leg swings, torso twists), movement-specific warm-ups (e.g., bodyweight squats before goblet squats).
# *   **The Workout:**
#     *   **Lower Body:**
#         *   Goblet Squats: 3 sets x 8-12 reps
#         *   Romanian Deadlifts (RDLs): 3 sets x 10-15 reps (Focus on form, hinge at hips)
#         *   Walking Lunges (Bodyweight or light DBs): 3 sets x 10-12 reps per leg
#     *   **Upper Body (Push):**
#         *   Incline Dumbbell Press: 3 sets x 8-12 reps
#         *   Overhead Dumbbell Press (Seated/Standing): 3 sets x 8-12 reps
#         *   Push-ups (Knee or Full): 3 sets to near failure (8-15 reps)
#     *   **Upper Body (Pull):**
#         *   Assisted Pull-ups or Lat Pulldowns: 3 sets x 8-12 reps
#         *   Seated Cable Rows or Dumbbell Rows: 3 sets x 10-15 reps (Focus on squeezing shoulder blades)
#     *   **Core:**
#         *   Plank: 3 sets, hold 30-60 seconds
#         *   Bird-Dog: 3 sets x 10-12 reps per side
# *   **Cool-down (5 min):** Static stretching (hold each 30 sec).
#
# **Technique Emphasis:**
# *   **Squats:** Chest up, neutral spine, descend to parallel or below with good form.
# *   **RDLs:** Maintain a flat back, hinge at the hips, feel stretch in hamstrings.
# *   **Pressing:** Controlled movement, stable shoulders.
# *   **Pulling:** Engage back muscles, not just arms.
#
# **B. Cardiovascular Exercise (3-4 Days/Week)**
#
# *   **Focus:** Moderate-Intensity Steady-State (MISS) cardio for fat burning and cardiovascular health without hindering recovery.
# *   **Duration:** 30-40 minutes.
# *   **Intensity:** 60-70% of your maximum heart rate (able to converse with some effort).
# *   **Examples:** Brisk walking, cycling, elliptical, light jogging.
#
# **C. Nutrition (Daily Target: ~2300 Calories)**
#
# *   **Caloric Intake:** A target of **2300 calories** per day, representing a moderate deficit (approx. 400 calories below TDEE) to support fat loss while preserving muscle.
# *   **Macronutrient Split:**
#     *   **Protein:** 170g (approx. 30% of calories) - Crucial for muscle repair and satiety.
#     *   **Fats:** 64g (approx. 25% of calories) - Essential for hormone function and overall health.
#     *   **Carbohydrates:** 261g (approx. 45% of calories) - Fuel for workouts and recovery.
# *   **Key Principles:**
#     *   **Prioritize Whole Foods:** Lean proteins (chicken breast, fish, lean beef, eggs, Greek yogurt), complex carbs (oats, brown rice, quinoa, sweet potatoes, fruits, vegetables), healthy fats (avocado, nuts, seeds, olive oil).
#     *   **Hydration:** Drink at least 85 oz of water daily.
#     *   **Meal Structure:** Aim for 3 main meals and 2 snacks to distribute protein intake and manage hunger.
#     *   **Limit Processed Foods:** Minimize sugary drinks, fried foods, and refined grains.
#
# **Sample Daily Meal Plan (Approx. 2300 Calories):**
#
# *   **Breakfast (450-500 kcal):** 3 whole eggs + 2 egg whites scrambled, 1/2 cup dry oats cooked with water/almond milk, 1/2 cup berries, 1 tbsp almonds.
# *   **Lunch (550-600 kcal):** 5-6 oz grilled chicken breast, 1 cup cooked quinoa, large mixed greens salad with 1-2 tbsp olive oil & vinegar dressing.
# *   **Dinner (600-650 kcal):** 5-6 oz baked salmon, 1 medium sweet potato (baked/roasted), 1.5 cups steamed broccoli.
# *   **Snack 1 (Mid-Morning/Pre-Workout - 200-250 kcal):** Apple slices with 2 tbsp peanut butter.
# *   **Snack 2 (Mid-Afternoon/Post-Workout - 200-250 kcal):** Protein shake (1 scoop protein powder with water/almond milk).
#
# **D. Recovery**
#
# *   **Sleep:** Aim for 7-9 hours of quality sleep per night.
# *   **Rest Days:** Crucial for muscle repair and preventing burnout.
# *   **Active Recovery:** Light walks or stretching on rest days can aid circulation.
#
# ---
#
# ### **Phase 2: Progression & Intensity Increase (Weeks 7-12)**
#
# Build upon your foundation with increased intensity and more challenging exercises.
#
# **A. Strength Training (3 Days/Week)**
#
# *   **Focus:** Increase weight and intensity. Introduce slightly more complex exercises.
# *   **Rep Range:** Continue 8-12 reps, but introduce 6-8 reps for primary compound lifts.
# *   **Progressive Overload:** Focus on increasing weight once rep targets are met.
#
# **Workout Structure (Example - building on Phase 1):**
#
# *   **Warm-up:** As per Phase 1.
# *   **The Workout:**
#     *   **Lower Body:**
#         *   Barbell Back Squats: 3 sets x 6-10 reps
#         *   Conventional Deadlifts: 1-2 sets x 5 reps (Focus on form!) OR continue with RDLs.
#         *   Bulgarian Split Squats: 3 sets x 8-10 reps per leg
#         *   Hamstring Curls (Machine): 3 sets x 10-15 reps
#     *   **Upper Body (Push):**
#         *   Barbell Bench Press: 3 sets x 6-10 reps OR continue with DB Press.
#         *   Overhead Barbell Press (Standing): 3 sets x 6-10 reps
#         *   Dips (Assisted/Bodyweight): 3 sets x 6-12 reps
#     *   **Upper Body (Pull):**
#         *   Pull-ups (Weighted if possible): 3 sets x 6-10 reps OR continue Lat Pulldowns.
#         *   Barbell Rows or T-Bar Rows: 3 sets x 8-12 reps
#         *   Face Pulls: 3 sets x 15-20 reps
#     *   **Core:**
#         *   Hanging Leg Raises: 3 sets x 10-15 reps
#         *   Russian Twists (with weight): 3 sets x 15-20 reps per side
# *   **Cool-down:** As per Phase 1.
#
# **B. Cardiovascular Exercise (3-4 Days/Week)**
#
# *   **Focus:** Incorporate **High-Intensity Interval Training (HIIT)** 1-2 times per week. Keep 2-3 sessions as MISS.
# *   **HIIT Protocol (Example):** 5 min warm-up, 8-12 rounds of 30 sec sprint / 60-90 sec active recovery, 5 min cool-down.
# *   **Duration:** HIIT sessions ~20-25 min; MISS sessions 30-40 min.
#
# **C. Nutrition**
#
# *   **Monitor & Adjust:** If fat loss stalls (<1 lb/week), slightly decrease calories by 100-200 or increase cardio. If fatigue is high, slightly increase calories.
# *   **Refeed Days (Optional):** Consider 1 refeed day every 1-2 weeks (higher carb, slightly higher calories) if you experience plateaus or low energy.
#
# **D. Recovery**
#
# *   **Listen to Your Body:** Prioritize rest and avoid pushing through sharp pain.
# *   **Mobility Work:** Incorporate daily or on rest days.
# *   **Foam Rolling:** Can help with muscle soreness.
#
# ---
#
# ### **Important Considerations & Next Steps**
#
# 1.  **Injury History:** **Provide your injury details.** This is crucial for modifying exercises and ensuring safety.
# 2.  **Consistency is Key:** Adhere to the plan as consistently as possible.
# 3.  **Track Your Progress:**
#     *   **Workouts:** Log exercises, sets, reps, and weights.
#     *   **Nutrition:** Use a food tracking app (MyFitnessPal, Cronometer) to monitor intake.
#     *   **Body Weight:** Weigh yourself 2-3 times/week (weekly average).
#     *   **Measurements:** Take key body measurements (waist, chest, etc.) every 2-4 weeks.
#     *   **Progress Photos:** Take photos every 4 weeks.
# 4.  **Patience:** Fat loss and muscle gain take time. A healthy rate of fat loss is 1-2 lbs per week, meaning reaching your 20 lb goal may take 10-20 weeks. Muscle gain is slower, especially in a deficit.
# 5.  **Supplementation (Optional):** Consider Whey Protein, Creatine Monohydrate, a Multivitamin, and Omega-3s.
#
# This plan provides a robust framework. We will adjust as you progress and provide more personalized recommendations once your injury history is shared. Let's get started!

# %%
runner_session = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

# %%
await run_session(
    runner_session,
    [
        """I am a 30 year old male who weighs 170 lbs and is 5 foot 6 inches tall.
    I have previous lifting and cardio experience but have fallen out of shape and would like to lose 20 lbs while gaining muscle.
    Please create a detailed wellness plan for me.
        """
    ],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > I am a 30 year old male who weighs 170 lbs and is 5 foot 6 inches tall.
#     I have previous lifting and cardio experience but have fallen out of shape and would like to lose 20 lbs while gaining muscle.
#     Please create a detailed wellness plan for me.
#
# gemini-2.5-flash-lite >  It's great you're looking to get back into shape and achieve your goals! Losing 20 lbs while gaining muscle is a common and achievable objective with the right approach. This plan will focus on a sustainable nutrition strategy and provide guidance on how to structure your training.
#
# Let's break down your needs:
#
# **1. Calculating Your Baseline Needs:**
#
# First, we need to estimate your Basal Metabolic Rate (BMR) and Total Daily Energy Expenditure (TDEE).
#
# *   **BMR (Harris-Benedict Equation - Revised):**
#     *   For men: BMR = 88.362 + (13.397 \* weight in kg) + (4.799 \* height in cm) - (5.677 \* age in years)
#     *   Weight in kg: 170 lbs / 2.205 = 77.1 kg
#     *   Height in cm: 5 ft 6 in = (5 \* 12 + 6) \* 2.54 = 66 inches \* 2.54 = 167.64 cm
#     *   BMR = 88.362 + (13.397 \* 77.1) + (4.799 \* 167.64) - (5.677 \* 30)
#     *   BMR = 88.362 + 1033.01 + 804.61 - 170.31
#     *   BMR ≈ 1755 calories
#
# *   **TDEE (Total Daily Energy Expenditure):** This accounts for your activity level. Since you have previous experience and plan to resume, we'll start with a moderately active multiplier.
#     *   Sedentary (little to no exercise): BMR x 1.2
#     *   Lightly active (exercise 1-3 days/week): BMR x 1.375
#     *   **Moderately active (exercise 3-5 days/week): BMR x 1.55**
#     *   Very active (exercise 6-7 days/week): BMR x 1.725
#     *   Extra active (very intense exercise & physical job): BMR x 1.9
#     *   TDEE = 1755 \* 1.55 ≈ 2720 calories
#
# **2. Calorie and Macronutrient Goals for Fat Loss and Muscle Gain:**
#
# To lose fat, you need to be in a calorie deficit. To gain muscle, you need sufficient protein and a stimulus from resistance training.
#
# *   **Calorie Target:** A deficit of 500 calories per day typically leads to about 1 lb of fat loss per week. To lose 20 lbs, this would take approximately 20 weeks. We can aim for a slightly more aggressive deficit initially, but sustainability is key.
#     *   **Target Calorie Intake: 2200 - 2300 calories per day.** This creates a deficit of around 400-500 calories, allowing for fat loss while supporting muscle building. We will adjust this based on your progress.
#
# *   **Macronutrient Breakdown:**
#     *   **Protein:** Crucial for muscle repair and growth, and it's also very satiating. Aim for 1.6-2.2 grams per kilogram of body weight.
#         *   77.1 kg \* 1.8 g/kg = 138.8 g
#         *   **Protein Target: 140-160 grams per day** (This is approximately 25-30% of your calories)
#     *   **Fats:** Essential for hormone production and overall health. Aim for 20-30% of your total calories.
#         *   2250 calories \* 0.25 = 562.5 calories
#         *   562.5 calories / 9 calories per gram = 62.5 g
#         *   **Fat Target: 60-70 grams per day** (This is approximately 25% of your calories)
#     *   **Carbohydrates:** Provide energy for your workouts and daily activities. The remaining calories will come from carbs.
#         *   Calories from Protein: 150g \* 4 cal/g = 600 calories
#         *   Calories from Fat: 65g \* 9 cal/g = 585 calories
#         *   Remaining calories for Carbs: 2250 - 600 - 585 = 1065 calories
#         *   1065 calories / 4 calories per gram = 266.25 g
#         *   **Carbohydrate Target: 250-280 grams per day** (This is approximately 45-50% of your calories)
#
# **Summary of Daily Targets:**
#
# *   **Calories:** 2200-2300
# *   **Protein:** 140-160g
# *   **Fats:** 60-70g
# *   **Carbohydrates:** 250-280g
#
# **3. Dietary Restrictions & Preferences:**
#
# You haven't mentioned any specific dietary restrictions (e.g., vegetarian, vegan, gluten-free, allergies). Please let me know if you have any, and I will adjust the meal plans accordingly. For now, I'll assume a general omnivore diet.
#
# **4. Nutrition Plan & Meal Examples:**
#
# This plan focuses on whole, unprocessed foods that are nutrient-dense and provide sustained energy. It emphasizes lean protein sources, complex carbohydrates, healthy fats, and plenty of fruits and vegetables.
#
# **Key Principles:**
#
# *   **Prioritize Protein:** Include a protein source with every meal and snack.
# *   **Complex Carbohydrates:** Opt for whole grains, vegetables, and fruits for sustained energy release.
# *   **Healthy Fats:** Incorporate sources like avocados, nuts, seeds, and olive oil.
# *   **Hydration:** Drink plenty of water throughout the day (aim for at least 2-3 liters).
# *   **Fiber:** Aim for 25-30 grams of fiber daily from fruits, vegetables, and whole grains.
# *   **Nutrient Timing:** While not as critical as total daily intake, consuming protein and carbs around your workouts can be beneficial.
#
# **Sample Daily Meal Plan (Approx. 2250 Calories):**
#
# **Meal 1: Breakfast (Approx. 450 Calories)**
# *   **Option 1:**
#     *   1 cup (cooked) Oatmeal (rolled oats)
#     *   1 scoop (30g) Whey Protein Isolate mixed in or on the side
#     *   1/2 cup Berries (strawberries, blueberries)
#     *   1 tbsp Chia Seeds
# *   **Option 2:**
#     *   3 Scrambled Eggs + 2 Egg Whites
#     *   1 slice Whole Wheat Toast
#     *   1/2 Avocado
#     *   Small Spinach Salad with 1 tsp Olive Oil dressing
#
# **Meal 2: Mid-Morning Snack (Approx. 250 Calories)**
# *   **Option 1:**
#     *   1 cup Greek Yogurt (plain, non-fat)
#     *   1/4 cup Almonds
#     *   1 Small Apple
# *   **Option 2:**
#     *   1 scoop Whey Protein Isolate mixed with water or unsweetened almond milk
#     *   1 Banana
#
# **Meal 3: Lunch (Approx. 550 Calories)**
# *   **Option 1:**
#     *   6 oz Grilled Chicken Breast or Salmon
#     *   1 cup Quinoa or Brown Rice (cooked)
#     *   Large Mixed Green Salad with 2 tbsp Vinaigrette (olive oil & vinegar based)
#     *   1 cup Steamed Broccoli or Asparagus
# *   **Option 2:**
#     *   Large Tuna Salad (made with 5 oz canned tuna in water, 1 tbsp Greek yogurt/light mayo, celery, onion)
#     *   2 slices Whole Wheat Bread or served over a bed of lettuce
#     *   1 side of Baby Carrots
#
# **Meal 4: Pre-Workout Snack (Optional - if training in the afternoon/evening - Approx. 200 Calories)**
# *   **Option 1:**
#     *   1 Banana
#     *   1 tbsp Peanut Butter
# *   **Option 2:**
#     *   Rice Cakes (2) with 1 tbsp Jam or Honey
#
# **Meal 5: Post-Workout Meal/Dinner (Approx. 700 Calories)**
# *   **Option 1:**
#     *   6 oz Lean Ground Turkey or Beef (93% lean) stir-fry with mixed vegetables (bell peppers, onions, snap peas)
#     *   1.5 cups Brown Rice or Sweet Potato (cooked)
#     *   1 tbsp Soy Sauce or Tamari (low sodium)
#     *   1 tsp Sesame Oil
# *   **Option 2:**
#     *   6 oz Baked Cod or Tilapia
#     *   1.5 cups Roasted Sweet Potatoes or Roasted Potatoes
#     *   Large portion of Green Beans or Brussels Sprouts with 1 tsp Olive Oil
#
# **Meal 6: Evening Snack (Optional - if needed for hunger or protein target - Approx. 150 Calories)**
# *   **Option 1:**
#     *   1 cup Cottage Cheese (low-fat)
#     *   Small handful of berries
# *   **Option 2:**
#     *   Casein Protein Shake (slow-digesting protein before bed)
#
# **Important Considerations for Meal Variety:**
#
# *   **Protein Sources:** Chicken breast, turkey, lean beef, fish (salmon, tuna, cod, tilapia), eggs, Greek yogurt, cottage cheese, tofu, tempeh, lentils, beans.
# *   **Carbohydrate Sources:** Oats, quinoa, brown rice, sweet potatoes, potatoes, whole wheat bread/pasta, fruits (berries, apples, bananas, oranges), vegetables (broccoli, spinach, kale, carrots, bell peppers, zucchini, asparagus).
# *   **Healthy Fat Sources:** Avocados, nuts (almonds, walnuts, cashews), seeds (chia, flax, sunflower), olive oil, coconut oil.
#
# **5. Micronutrient Needs:**
#
# By focusing on a varied diet rich in whole foods, you'll naturally cover most of your micronutrient needs. However, some key micronutrients to be mindful of for energy metabolism, muscle function, and overall health include:
#
# *   **B Vitamins:** Crucial for energy production. Found in whole grains, lean meats, eggs, leafy greens.
# *   **Iron:** Important for oxygen transport. Found in lean red meats, beans, spinach.
# *   **Magnesium:** Involved in muscle function and energy. Found in leafy greens, nuts, seeds, whole grains.
# *   **Zinc:** Supports immune function and muscle repair. Found in lean meats, nuts, seeds, dairy.
# *   **Vitamin D:** Important for bone health and muscle function. Sunlight exposure is the primary source, but fatty fish and fortified foods also contribute. Consider a supplement if deficient.
# *   **Calcium:** Essential for bone health and muscle contractions. Found in dairy products, leafy greens, fortified plant milks.
#
# **6. Fitness Component (Crucial for Muscle Gain & Fat Loss):**
#
# This nutrition plan is designed to support your fitness goals, but the training itself is paramount.
#
# *   **Resistance Training:** Aim for 3-4 full-body workouts or a split routine (e.g., push/pull/legs) per week. Focus on compound exercises that work multiple muscle groups:
#     *   Squats
#     *   Deadlifts
#     *   Bench Press
#     *   Overhead Press
#     *   Rows (barbell, dumbbell, or cable)
#     *   Pull-ups/Lat Pulldowns
# *   **Progressive Overload:** Consistently challenge your muscles by increasing weight, reps, sets, or decreasing rest times over weeks and months.
# *   **Cardio:** Incorporate 2-3 sessions of moderate-intensity cardio (e.g., brisk walking, jogging, cycling) for 30-45 minutes per week. This will aid fat loss and cardiovascular health. High-Intensity Interval Training (HIIT) can also be effective but should be used strategically to avoid overtraining.
# *   **Rest and Recovery:** Aim for 7-9 hours of quality sleep per night. Allow at least one full rest day per week. Listen to your body and don't push through significant pain.
#
# **7. Monitoring and Adjustments:**
#
# *   **Track Your Progress:** Weigh yourself 1-2 times per week (same day, same time, preferably in the morning before eating). Take progress photos every 4-6 weeks.
# *   **Listen to Your Body:** Pay attention to your energy levels, hunger, and recovery.
# *   **Adjust as Needed:**
#     *   **Not losing weight:** If you're not seeing consistent fat loss (0.5-1 lb per week) after 2-3 weeks, slightly reduce your calorie intake by 100-150 calories, primarily from carbohydrates or fats.
#     *   **Losing weight too fast or feeling drained:** Increase calories slightly (100-150), particularly from complex carbs and protein.
#     *   **Plateauing:** Ensure you're consistently applying progressive overload in your training. You might also need to adjust your calorie intake or training volume.
#
# **Disclaimer:** This is a general nutrition and wellness plan based on the information provided. It is always recommended to consult with a registered dietitian or a healthcare professional before making significant changes to your diet or exercise routine, especially if you have any underlying health conditions.
#
# Let me know your specific dietary restrictions, food preferences, or any questions you have, and I can further refine this plan for you!
# gemini-2.5-flash-lite >  It's great you're looking to get back into a fitness routine! Losing 20 lbs and gaining muscle is an achievable goal, and with your previous experience, we can build a solid plan. Let's break down a comprehensive wellness program tailored to you.
#
# ### Understanding Your Starting Point & Goals
#
# *   **Age:** 30 years old
# *   **Weight:** 170 lbs
# *   **Height:** 5'6"
# *   **BMI:** Approximately 27.5 (classified as overweight)
# *   **Goals:**
#     *   Lose 20 lbs (target weight: 150 lbs)
#     *   Gain muscle
#     *   Improve overall fitness and get back into shape
# *   **Experience:** Previous lifting and cardio experience. This is a huge advantage as you likely have some foundational movement patterns and understanding.
# *   **Injury History:** **This is a critical piece of information that is currently missing.** To create the safest and most effective plan, I need to know about any past or current injuries. Please provide details on:
#     *   What kind of injuries? (e.g., knee pain, shoulder impingement, back strain, etc.)
#     *   When did they occur?
#     *   How were they treated?
#     *   Are there any movements that currently cause you pain or discomfort?
#     *   Are there any specific exercises you should avoid or modify?
#
# **Without this information, I will provide a general plan. However, it's crucial that you listen to your body and adjust exercises based on any pain or discomfort you experience. Consulting a physical therapist or doctor for a pre-exercise assessment is highly recommended, especially if you have a significant injury history.**
#
# ### Physiological Principles for Your Goals
#
# *   **Weight Loss (Fat Loss):** This is achieved through a caloric deficit. You need to expend more calories than you consume.
# *   **Muscle Gain (Hypertrophy):** This requires progressive overload (gradually increasing the demand on your muscles), adequate protein intake, and sufficient recovery.
# *   **Body Recomposition:** The goal of losing fat and gaining muscle simultaneously is known as body recomposition. This is most feasible for individuals returning to training or those new to resistance training. It requires a careful balance of nutrition and training.
# *   **Metabolic Rate:** Building muscle increases your resting metabolic rate, meaning you burn more calories even at rest, which aids in long-term weight management.
#
# ### Estimated Time Frames (General Guidance)
#
# *   **Lifting Technique Mastery:**
#     *   **Foundational Lifts (Squat, Deadlift, Bench Press, Overhead Press, Rows):** With consistent practice and proper guidance (even from videos and self-correction), you can develop *competent* technique within **4-8 weeks**. Achieving *expertise* and true mastery takes **months to years** of dedicated practice and refinement.
#     *   **Accessory Lifts:** Technique for these can be learned more quickly, often within **1-4 weeks** of focused effort.
# *   **Muscle Gain:** Visible muscle gain can start to be noticed within **4-8 weeks** of consistent training. Significant muscle development takes **months to years**.
# *   **Fat Loss:** Losing 20 lbs is a reasonable goal over **3-5 months**, aiming for a safe and sustainable loss of 1-2 lbs per week. Some weeks might be more, some less.
#
# ---
#
# ## Detailed Wellness Plan
#
# This plan is structured as a 4-week cycle, with progressive adjustments. It assumes you are cleared for general exercise and have no major contraindications.
#
# ### Phase 1: Foundation & Re-Acclimation (Weeks 1-4)
#
# The focus here is on re-establishing good movement patterns, rebuilding a base level of strength and cardiovascular fitness, and establishing consistent habits.
#
# #### 1. Nutrition Strategy
#
# The cornerstone of fat loss and muscle gain is nutrition. You'll need to be in a slight caloric deficit.
#
# *   **Caloric Target:**
#     *   **Basal Metabolic Rate (BMR) Estimate (using Mifflin-St Jeor Equation):** (10 * weight in kg) + (6.25 * height in cm) - (5 * age in years) + 5
#         *   Weight: 170 lbs / 2.205 = 77.1 kg
#         *   Height: 5'6" = (5 * 12 + 6) inches = 66 inches * 2.54 = 167.6 cm
#         *   BMR = (10 * 77.1) + (6.25 * 167.6) - (5 * 30) + 5 = 771 + 1047.5 - 150 + 5 = **1673.5 calories**
#     *   **Total Daily Energy Expenditure (TDEE) Estimate:** BMR * Activity Factor. Let's assume a moderately active lifestyle (exercising 3-5 days/week). Activity Factor: 1.55
#         *   TDEE = 1673.5 * 1.55 = **2594 calories** (approximate maintenance calories)
#     *   **Caloric Deficit for Fat Loss:** To lose ~1 lb per week, aim for a deficit of 500 calories/day.
#         *   **Target Daily Calories:** 2594 - 500 = **2094 calories**. Let's round this to **2100 calories per day**.
#         *   **Flexibility:** If you feel excessively fatigued or are losing weight too quickly (more than 2 lbs/week), increase calories slightly (e.g., to 2200-2300). If weight loss stalls, you might need to slightly reduce intake or increase activity.
# *   **Macronutrient Breakdown:**
#     *   **Protein:** Crucial for muscle repair and satiety. Aim for 0.8-1 gram per pound of body weight.
#         *   Target: 150-170 grams per day.
#     *   **Fats:** Essential for hormone production and overall health. Aim for 20-30% of total calories.
#         *   Target: (2100 * 0.25) / 9 calories per gram = ~58 grams per day.
#     *   **Carbohydrates:** Fuel for workouts and daily function. Fill the remaining calories.
#         *   Target: 2100 (total) - (160g protein * 4 cal/g) - (60g fat * 9 cal/g) = 2100 - 640 - 540 = 920 calories.
#         *   920 calories / 4 calories per gram = **230 grams of carbohydrates per day**.
# *   **Food Quality:**
#     *   **Lean Protein Sources:** Chicken breast, turkey, lean beef, fish (salmon, tuna), eggs, Greek yogurt, tofu, lentils, beans.
#     *   **Complex Carbohydrates:** Oats, brown rice, quinoa, whole-wheat bread/pasta, sweet potatoes, fruits, vegetables.
#     *   **Healthy Fats:** Avocados, nuts, seeds, olive oil, fatty fish.
#     *   **Hydration:** Drink plenty of water throughout the day (aim for 1 gallon).
# *   **Meal Timing:** Distribute protein intake evenly across meals (3-5 meals/snacks) to optimize muscle protein synthesis. Consume carbs around your workouts for energy.
#
# #### 2. Strength Training Program (3 Days/Week - Full Body or Upper/Lower Split)
#
# This phase focuses on compound movements and building a solid foundation. Prioritize form over weight.
#
# *   **Frequency:** 3 non-consecutive days per week (e.g., Monday, Wednesday, Friday).
# *   **Warm-up (5-10 minutes):**
#     *   Light cardio (jogging in place, jumping jacks, dynamic stretching).
#     *   Dynamic stretches: Arm circles, leg swings, torso twists, hip circles, cat-cow, bird-dog.
# *   **Workout Structure:** Focus on compound exercises that work multiple muscle groups.
#     *   **Sets & Reps:** 3 sets of 8-12 repetitions for most exercises. This range is good for both hypertrophy and building muscular endurance.
#     *   **Rest:** 60-90 seconds between sets.
# *   **Exercise Selection (Focus on Form!)**
#
#     **Workout A (Example)**
#     1.  **Goblet Squat:** 3 sets x 10 reps (Excellent for learning squat mechanics)
#     2.  **Dumbbell Romanian Deadlift (RDL):** 3 sets x 10 reps (Focus on hinge, not squatting. Keep back straight, slight bend in knees.)
#     3.  **Push-ups:** 3 sets x As Many Reps As Possible (AMRAP) (If full push-ups are too hard, do them on your knees or against a wall. If too easy, add pauses or tempo.)
#     4.  **Dumbbell Rows (Single Arm):** 3 sets x 10 reps per arm (Focus on squeezing the shoulder blade.)
#     5.  **Overhead Press (Dumbbell or Barbell - light):** 3 sets x 10 reps (Focus on core stability, avoid arching back.)
#     6.  **Plank:** 3 sets x 30-60 second hold
#     7.  **Bicep Curls (Dumbbell):** 2 sets x 12 reps
#     8.  **Triceps Extensions (Dumbbell, overhead or lying):** 2 sets x 12 reps
#
#     **Workout B (Example - Introduce slight variations or progression)**
#     1.  **Dumbbell Lunges (alternating legs):** 3 sets x 10 reps per leg
#     2.  **Glute Bridges:** 3 sets x 15 reps (Focus on glute squeeze)
#     3.  **Incline Dumbbell Press:** 3 sets x 10 reps (Slight incline for upper chest focus)
#     4.  **Lat Pulldowns (or Band Pull-Aparts if no machine):** 3 sets x 10-12 reps
#     5.  **Face Pulls (with band or cable):** 3 sets x 15 reps (Great for shoulder health and upper back)
#     6.  **Bird-Dog:** 3 sets x 10 reps per side (Focus on core control)
#     7.  **Hammer Curls (Dumbbell):** 2 sets x 12 reps
#     8.  **Triceps Pushdowns (cable or band):** 2 sets x 12 reps
#
# *   **Progression within Phase 1:**
#     *   **Week 1-2:** Focus entirely on learning and executing movements with perfect form. Use very light weights or even just bodyweight/empty bar.
#     *   **Week 3-4:** If form is good, start to gradually increase the weight slightly. You should feel challenged by the last 1-2 reps but still maintain good form. If you can do more than 12 reps easily, increase the weight. If you can't reach 8 reps with good form, the weight is too heavy.
#
# #### 3. Cardiovascular Training (2-3 Days/Week)
#
# *   **Frequency:** 2-3 days per week, ideally on non-lifting days or after lifting.
# *   **Type:** Low-to-moderate intensity steady-state (LISS) cardio. This is great for fat burning and recovery.
#     *   Examples: Brisk walking, cycling, elliptical, swimming.
# *   **Duration:** 30-40 minutes.
# *   **Intensity:** You should be able to hold a conversation. (Zone 2 heart rate, approx. 60-70% of max heart rate).
# *   **Progression:** Gradually increase duration by 5 minutes each week, or slightly increase intensity if desired.
#
# #### 4. Active Recovery & Flexibility
#
# *   **Daily:** Light stretching, foam rolling, walking.
# *   **Focus:** Areas that feel tight or sore. Aim for 10-15 minutes daily.
#
# #### 5. Sleep & Stress Management
#
# *   **Sleep:** Aim for 7-9 hours of quality sleep per night. This is crucial for muscle recovery, hormone regulation, and overall well-being.
# *   **Stress:** Find healthy ways to manage stress (meditation, deep breathing, hobbies). High stress can negatively impact hormones related to fat loss and muscle gain.
#
# ---
#
# ### Phase 2: Building Strength & Volume (Weeks 5-8)
#
# As your technique improves and your body adapts, we'll increase the challenge.
#
# #### 1. Nutrition Strategy
#
# *   **Caloric Target:** You may need to adjust slightly based on your progress. If weight loss has stalled for 2 weeks, consider a small reduction (e.g., to 2000 calories) OR an increase in cardio. If you're feeling very low energy, increase slightly (e.g., to 2150-2200).
# *   **Protein:** Continue to prioritize 150-170 grams.
# *   **Hydration:** Maintain high fluid intake.
#
# #### 2. Strength Training Program (3-4 Days/Week - Upper/Lower Split or Full Body)
#
# You can continue with full body 3x/week, or switch to an Upper/Lower split for more focused work.
#
# *   **Frequency:** 3-4 days per week.
# *   **Workout Structure:**
#     *   **Sets & Reps:**
#         *   Compound Lifts (Squats, Deadlifts, Bench, OHP, Rows): 3-4 sets of 6-10 reps. This range allows for heavier lifting while still providing a good hypertrophy stimulus.
#         *   Accessory Lifts: 3 sets of 10-15 reps.
#     *   **Rest:** 90-120 seconds for compound lifts, 60-75 seconds for accessory lifts.
# *   **Exercise Selection & Progression:**
#     *   **Introduce Barbell Lifts (if comfortable and form is solid):**
#         *   **Barbell Back Squat:** 3x8
#         *   **Barbell Bench Press:** 3x8
#         *   **Barbell Overhead Press:** 3x8
#         *   **Barbell Rows:** 3x8
#         *   **Conventional or Sumo Deadlift:** 1-2 sets of 5 reps (focus on explosiveness and form, deadlifts are taxing).
#     *   **Continue with:** Dumbbell variations, lunges, RDLs, push-ups, pull-ups (if possible), rows, accessory shoulder work, core exercises.
#     *   **Progressive Overload:**
#         *   Increase weight when you can comfortably hit the upper end of the rep range for all sets with good form.
#         *   Consider adding a set for key compound lifts.
#         *   Tempo training (e.g., slower eccentric/lowering phase) can be introduced.
#
#     **Example Upper/Lower Split (4 days/week):**
#
#     *   **Day 1: Lower Body**
#         1.  Barbell Back Squat: 3x8
#         2.  Romanian Deadlift (Barbell or Dumbbell): 3x10
#         3.  Leg Press (or Lunges): 3x12
#         4.  Hamstring Curls: 3x12
#         5.  Calf Raises: 3x15
#         6.  Plank Variations: 3 sets
#
#     *   **Day 2: Upper Body**
#         1.  Barbell Bench Press: 3x8
#         2.  Barbell Rows: 3x8
#         3.  Overhead Press (Barbell or Dumbbell): 3x8
#         4.  Lat Pulldowns / Pull-ups: 3xAMRAP (or 8-10)
#         5.  Incline Dumbbell Press: 3x10
#         6.  Face Pulls: 3x15
#         7.  Bicep Curls: 3x12
#         8.  Triceps Extensions: 3x12
#
#     *   **Day 3: Rest or Active Recovery**
#
#     *   **Day 4: Lower Body (Volume or Variation)**
#         1.  Deadlift (Conventional/Sumo): 1-2x5 (focus on form, use weight that allows for perfect execution)
#         2.  Front Squat (Dumbbell or Barbell - lighter): 3x10
#         3.  Glute Bridges / Hip Thrusts: 3x12
#         4.  Leg Extensions: 3x12
#         5.  Calf Raises: 3x15
#         6.  Hanging Leg Raises: 3 sets
#
#     *   **Day 5: Upper Body (Volume or Variation)**
#         1.  Dumbbell Bench Press: 3x10
#         2.  Dumbbell Rows (Single Arm): 3x10 per arm
#         3.  Lateral Raises: 3x12
#         4.  Cable Rows (Seated): 3x10
#         5.  Push-ups (or variation): 3xAMRAP
#         6.  Bicep Curls (Hammer or Concentration): 3x12
#         7.  Triceps Pushdowns: 3x12
#
#     *   **Day 6 & 7: Rest or Active Recovery**
#
# #### 3. Cardiovascular Training (3 Days/Week)
#
# *   **Option 1: Continue LISS:** 30-45 minutes, 3x/week.
# *   **Option 2: Introduce Interval Training (HIIT):** 1-2 sessions per week, replacing one LISS session.
#     *   **Format:** Short bursts of very high intensity followed by short recovery periods.
#     *   **Example:**
#         *   Warm-up (5 mins)
#         *   Sprint on bike/treadmill for 30 seconds
#         *   Rest or light jog for 60-90 seconds
#         *   Repeat 6-10 times.
#         *   Cool-down (5 mins)
#     *   **Caution:** HIIT is demanding. Start with fewer intervals and ensure good recovery. Don't do HIIT on consecutive days or the day before a heavy leg day.
#
# ---
#
# ### Phase 3: Peaking & Refinement (Weeks 9 onwards)
#
# By this point, you should have a good grasp of the exercises, be consistently losing weight, and feeling stronger.
#
# #### 1. Nutrition Strategy
#
# *   **Monitor & Adjust:** Continue to track weight loss. If you're consistently losing 1-2 lbs/week, keep your calories the same. If it stalls, re-evaluate your intake and expenditure. You might be eating more unconsciously.
# *   **Listen to Your Body:** If energy levels are consistently low, consider a slight increase in carbs or calories, especially around workouts.
#
# #### 2. Strength Training Program
#
# *   **Continue Progressive Overload:** Focus on lifting heavier weights for your target rep ranges, increasing volume, or improving workout density (doing more work in the same amount of time).
# *   **Consider Advanced Techniques (if desired and form is perfect):**
#     *   Drop sets
#     *   Supersets
#     *   Rest-pause sets
# *   **Exercise Variation:** Introduce new exercises or variations to keep training stimulating and challenge muscles in new ways.
# *   **Periodization:** Consider cycling through different rep ranges (e.g., a few weeks focusing on strength with lower reps 4-6, followed by weeks focusing on hypertrophy 8-15).
#
# #### 3. Cardiovascular Training
#
# *   **Variety:** Mix LISS and HIIT based on your preferences and recovery.
# *   **Intensity:** Push yourself during HIIT sessions.
#
# ---
#
# ## Important Considerations & Injury Prevention
#
# 1.  **Listen to Your Body:** This cannot be stressed enough. Pain is a signal. Differentiate between muscle soreness (DOMS - Delayed Onset Muscle Soreness) and joint pain or sharp, acute pain. If you feel joint pain, stop the exercise and assess.
# 2.  **Proper Form:** **Always** prioritize form over lifting heavy. Watch reputable videos, record yourself, and consider hiring a trainer for a few sessions to assess your form on key lifts.
# 3.  **Warm-up:** Don't skip it. It prepares your muscles and joints for exercise, reducing injury risk.
# 4.  **Cool-down:** Aids in recovery and helps bring your heart rate down gradually.
# 5.  **Progressive Overload:** Without it, your muscles won't adapt and grow. However, introduce it gradually.
# 6.  **Nutrition is Key:** You cannot out-train a bad diet, especially for fat loss.
# 7.  **Rest and Recovery:** Muscles grow when you are resting, not when you are training.
# 8.  **Consistency:** Adherence is more important than perfection. If you miss a workout, don't beat yourself up; just get back on track for the next one.
# 9.  **Seek Professional Help:** If you have pre-existing conditions or significant pain, consult a doctor or physical therapist.
#
# ---
#
# ## Addressing Your Specific Injury History (Crucial Step!)
#
# **Please, provide details about your injury history.** Once I have this information, I can modify the plan significantly. For example:
#
# *   **Knee Pain:** We might substitute barbell squats for Goblet Squats or Leg Press initially, focus on hamstring and glute strength, and avoid deep lunges or high-impact plyometrics.
# *   **Shoulder Impingement:** We might limit overhead pressing, focus on external rotation and posterior chain exercises, and perform bench presses with a narrower grip or focus on dumbbell variations with a more natural range of motion.
# *   **Lower Back Pain:** We would place extreme emphasis on core bracing, deadlift variations (like RDLs or trap bar deadlifts) with perfect form, and potentially avoid conventional barbell deadlifts until core strength is significantly improved. Hip thrusts and glute work become paramount.
#
# ---
#
# This plan provides a solid framework. Remember to be patient with yourself, stay consistent, and celebrate your progress along the way. Good luck!
# gemini-2.5-flash-lite >  Here is your comprehensive wellness plan, integrating both nutrition and fitness strategies to help you achieve your goals of losing 20 lbs and gaining muscle. This plan is designed to work synergistically, ensuring your nutrition fuels your workouts and recovery, and your training supports your body composition goals.
#
# ## Your Integrated Wellness Plan
#
# This plan is structured as a 4-week cycle, with progressive adjustments, focusing on re-establishing good habits, building a foundation, and then gradually increasing the challenge.
#
# ### Understanding Your Starting Point & Goals
#
# *   **Age:** 30 years old
# *   **Weight:** 170 lbs
# *   **Height:** 5'6"
# *   **BMI:** Approx. 27.5 (Overweight)
# *   **Goals:**
#     *   Lose 20 lbs (Target Weight: 150 lbs)
#     *   Gain Muscle
#     *   Improve overall fitness
# *   **Experience:** Previous lifting and cardio experience.
# *   **Injury History:** **Crucial Information Missing!** Please provide details on any past or current injuries (type, when, treatment, current pain/limitations, exercises to avoid/modify). Without this, the plan is general, and you *must* listen to your body and adjust as needed. Consulting a physical therapist or doctor is highly recommended.
#
# ### Core Principles for Synergy
#
# *   **Caloric Deficit for Fat Loss:** You need to consume fewer calories than you burn.
# *   **Adequate Protein for Muscle Gain & Satiety:** Protein is essential for muscle repair and growth, and helps you feel full, aiding fat loss.
# *   **Strength Training for Muscle Growth & Metabolism:** Building muscle increases your resting metabolic rate, helping burn more calories even at rest, and shapes your physique.
# *   **Carbohydrates for Energy:** Fuel your workouts and daily activities with quality carbs.
# *   **Healthy Fats for Hormones & Health:** Essential for overall well-being and hormone production.
# *   **Consistent Recovery (Sleep & Stress Management):** Muscle repair and growth happen during rest. Poor recovery sabotages progress.
#
# ---
#
# ## Phase 1: Foundation & Re-Acclimation (Weeks 1-4)
#
# This phase is about re-establishing consistent habits, mastering movement patterns, and building a base level of fitness.
#
# ### 1. Nutrition Strategy: Lean Fuel & Muscle Support
#
# *   **Target Daily Calories:** **~2100-2200 calories**
#     *   *Rationale:* This creates a moderate caloric deficit (approx. 500-600 calories below your estimated TDEE of 2720) to promote ~1-1.2 lbs of fat loss per week, while providing enough energy to support muscle building and recovery. Adjust based on your progress and energy levels.
# *   **Macronutrient Breakdown:**
#     *   **Protein:** **140-170 grams** (approx. 640-680 calories)
#         *   *Focus:* Lean meats, poultry, fish, eggs, dairy, legumes, tofu. Distribute evenly across meals (3-5 servings/day).
#     *   **Fats:** **60-70 grams** (approx. 540-630 calories)
#         *   *Focus:* Avocados, nuts, seeds, olive oil, fatty fish.
#     *   **Carbohydrates:** **230-270 grams** (approx. 920-1080 calories)
#         *   *Focus:* Whole grains, fruits, vegetables, legumes. Time a good portion around your workouts.
# *   **Hydration:** Aim for 1 gallon (approx. 3.8 liters) of water daily.
# *   **Sample Daily Meal Plan (Approx. 2200 Calories):**
#     *   **Meal 1 (Breakfast):** 1 cup cooked Oatmeal + 1 scoop Whey Protein + 1/2 cup Berries + 1 tbsp Chia Seeds
#     *   **Meal 2 (Mid-Morning Snack):** 1 cup Greek Yogurt + 1/4 cup Almonds + 1 Small Apple
#     *   **Meal 3 (Lunch):** 6 oz Grilled Chicken Breast + 1 cup Quinoa + Large Salad with 2 tbsp Vinaigrette + 1 cup Steamed Broccoli
#     *   **Meal 4 (Pre-Workout Snack - if needed):** 1 Banana + 1 tbsp Peanut Butter
#     *   **Meal 5 (Dinner):** 6 oz Lean Ground Turkey Stir-fry with Mixed Vegetables + 1.5 cups Brown Rice + Low-Sodium Soy Sauce
#     *   **Meal 6 (Evening Snack - optional):** 1 cup Cottage Cheese
#
# ### 2. Strength Training: Rebuilding the Foundation (3 Days/Week)
#
# Focus on compound movements and mastering form.
#
# *   **Schedule:** 3 non-consecutive days (e.g., Mon/Wed/Fri).
# *   **Warm-up (5-10 min):** Light cardio, dynamic stretches (arm circles, leg swings, torso twists).
# *   **Workout Structure:**
#     *   **Sets & Reps:** 3 sets of 8-12 repetitions.
#     *   **Rest:** 60-90 seconds between sets.
# *   **Exercise Selection (Prioritize Form!):**
#
#     **Workout A:**
#     1.  Goblet Squat: 3x10
#     2.  Dumbbell Romanian Deadlift (RDL): 3x10
#     3.  Push-ups (or Knee/Wall Push-ups): 3xAMRAP
#     4.  Dumbbell Rows (Single Arm): 3x10 per arm
#     5.  Dumbbell Overhead Press: 3x10
#     6.  Plank: 3x30-60 sec hold
#     7.  Dumbbell Bicep Curls: 2x12
#     8.  Dumbbell Triceps Extensions: 2x12
#
#     **Workout B:**
#     1.  Dumbbell Lunges (alternating): 3x10 per leg
#     2.  Glute Bridges: 3x15
#     3.  Incline Dumbbell Press: 3x10
#     4.  Lat Pulldowns (or Band Pull-Aparts): 3x10-12
#     5.  Face Pulls (Band/Cable): 3x15
#     6.  Bird-Dog: 3x10 per side
#     7.  Hammer Curls: 2x12
#     8.  Triceps Pushdowns: 2x12
#
# *   **Progression (Weeks 1-4):** Focus solely on perfect form. Gradually increase weight in Weeks 3-4 only if form remains excellent and you can complete reps with good control.
#
# ### 3. Cardiovascular Training (2-3 Days/Week)
#
# *   **Type:** Low-to-Moderate Intensity Steady-State (LISS) Cardio.
# *   **Duration:** 30-40 minutes.
# *   **Intensity:** Able to hold a conversation (Zone 2).
# *   **Examples:** Brisk walking, cycling, elliptical, swimming.
# *   **Schedule:** On non-lifting days or after lifting.
#
# ### 4. Active Recovery & Flexibility
#
# *   **Daily:** 10-15 minutes of light stretching, foam rolling, or walking. Focus on areas that feel tight.
#
# ### 5. Sleep & Stress Management
#
# *   **Sleep:** Aim for 7-9 hours of quality sleep nightly.
# *   **Stress:** Implement 5-10 minutes of deep breathing or meditation daily.
#
# ---
#
# ## Phase 2: Building Strength & Volume (Weeks 5-8)
#
# Your foundation is set. Now we increase the challenge to stimulate muscle growth and continue fat loss.
#
# ### 1. Nutrition Strategy: Fine-Tuning
#
# *   **Target Daily Calories:** **~2100-2200 calories** (Maintain or slightly adjust based on Phase 1 progress).
#     *   *Adjustment:* If weight loss stalls for 2 weeks, reduce calories by 100-150 (primarily from carbs/fats). If consistently losing >2 lbs/week or feeling depleted, increase by 100-150.
# *   **Macronutrient Ratios:** Maintain similar ratios, ensuring protein remains high (140-170g).
# *   **Hydration:** Continue aiming for 1 gallon/day.
#
# ### 2. Strength Training: Progressive Overload (3-4 Days/Week)
#
# Introduce barbell basics and increase intensity/volume.
#
# *   **Schedule:** 3-4 days/week. Consider an Upper/Lower split.
# *   **Warm-up:** As before.
# *   **Workout Structure:**
#     *   **Compound Lifts:** 3-4 sets of 6-10 reps.
#     *   **Accessory Lifts:** 3 sets of 10-15 reps.
#     *   **Rest:** 90-120 seconds for compounds, 60-75 seconds for accessories.
# *   **Exercise Selection & Progression:**
#
#     **Example Upper/Lower Split (4 Days/Week):**
#     *   **Day 1: Lower Body**
#         1.  Barbell Back Squat: 3x8
#         2.  Dumbbell Romanian Deadlift (RDL): 3x10
#         3.  Leg Press (or Walking Lunges): 3x12
#         4.  Hamstring Curls: 3x12
#         5.  Calf Raises: 3x15
#         6.  Plank Variations: 3 sets
#     *   **Day 2: Upper Body**
#         1.  Barbell Bench Press: 3x8
#         2.  Barbell Rows: 3x8
#         3.  Overhead Press (Barbell/Dumbbell): 3x8
#         4.  Lat Pulldowns / Assisted Pull-ups: 3xAMRAP (or 8-10)
#         5.  Incline Dumbbell Press: 3x10
#         6.  Face Pulls: 3x15
#         7.  Bicep Curls: 3x12
#         8.  Triceps Extensions: 3x12
#     *   **Day 3: Rest / Active Recovery**
#     *   **Day 4: Lower Body (Volume Focus)**
#         1.  Deadlift (Conventional/Sumo - focus on form!): 1-2x5
#         2.  Front Squats (Dumbbell/Light Barbell): 3x10
#         3.  Hip Thrusts / Glute Bridges: 3x12
#         4.  Leg Extensions: 3x12
#         5.  Calf Raises: 3x15
#         6.  Hanging Leg Raises: 3 sets
#     *   **Day 5: Upper Body (Volume Focus)**
#         1.  Dumbbell Bench Press: 3x10
#         2.  Dumbbell Rows (Single Arm): 3x10 per arm
#         3.  Lateral Raises: 3x12
#         4.  Seated Cable Rows: 3x10
#         5.  Push-ups: 3xAMRAP
#         6.  Hammer Curls: 3x12
#         7.  Triceps Pushdowns: 3x12
#     *   **Day 6 & 7: Rest / Active Recovery**
# *   **Progressive Overload:** Aim to increase the weight on compound lifts weekly or bi-weekly as you hit the top of your rep range.
#
# ### 3. Cardiovascular Training (3 Days/Week)
#
# *   **Option 1:** Continue LISS (30-45 minutes).
# *   **Option 2:** Introduce 1-2 sessions of High-Intensity Interval Training (HIIT) per week, replacing one LISS session.
#     *   **HIIT Example:** 5 min warm-up, 8 rounds of 30s max effort sprint / 60s rest, 5 min cool-down.
#     *   *Caution:* Perform HIIT only when feeling well-recovered.
#
# ---
#
# ## Phase 3: Peaking & Refinement (Weeks 9 onwards)
#
# Consolidate progress, focus on consistency, and introduce advanced techniques if desired.
#
# ### 1. Nutrition Strategy: Consistency is Key
#
# *   **Target Daily Calories:** **Maintain ~2100-2200 calories** (or adjust based on ongoing progress towards 150 lbs).
# *   **Focus:** Adherence to the established plan. Continue prioritizing protein and whole foods.
# *   **Monitor:** Track weight, body measurements, and how you feel. Make small adjustments as needed.
#
# ### 2. Strength Training: Continued Progression
#
# *   **Focus:** Continue applying progressive overload. Consider incorporating techniques like:
#     *   **Tempo Training:** Slowing down the eccentric (lowering) phase of lifts.
#     *   **Drop Sets:** Performing a set to failure, then immediately reducing the weight and doing more reps.
#     *   **Supersets:** Performing two exercises back-to-back with minimal rest.
# *   **Exercise Variation:** Swap accessory exercises every 4-6 weeks to provide new stimuli.
# *   **Periodization:** Consider cycling rep ranges (e.g., a block of 4-6 weeks focusing on 4-6 reps for strength, followed by 8-15 reps for hypertrophy).
#
# ### 3. Cardiovascular Training
#
# *   **Mix:** Alternate between LISS and HIIT based on energy levels and preferences. Ensure at least one LISS session per week for active recovery.
#
# ---
#
# ## Crucial Overarching Considerations
#
# 1.  **Injury History:** **This is paramount.** If you have ANY injury history, consult a medical professional or physical therapist. Modifications to exercises (e.g., substituting barbell squats with leg press or goblet squats if knee issues exist) may be necessary. **Listen to your body above all else.** Differentiate between muscle soreness and joint pain.
# 2.  **Proper Form:** Always prioritize form over lifting heavier weight. Watch reputable instructional videos, record yourself, and consider a few sessions with a qualified trainer.
# 3.  **Warm-up & Cool-down:** Never skip these. They prepare your body and aid recovery.
# 4.  **Consistency:** Adherence is more important than perfection. Missed a workout? Get back on track with the next one. Skipped a meal? Make up for it nutritionally later.
# 5.  **Patience & Realistic Expectations:** Losing 20 lbs and gaining muscle takes time. Aim for sustainable progress (1-2 lbs fat loss per week). Visible muscle gain takes consistent effort over weeks and months.
# 6.  **Sleep:** Non-negotiable for recovery and hormone balance. Aim for 7-9 hours.
# 7.  **Stress Management:** Chronic stress hinders progress. Find healthy outlets.
#
# ---
#
# This integrated plan provides a roadmap. Remember to stay adaptable, listen to your body's signals, and celebrate your progress along the way! Good luck!
