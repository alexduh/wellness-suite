# %%
import logging
import os

# Clean up any previous logs
for log_file in ["logger.log", "web.log", "tunnel.log"]:
    if os.path.exists(log_file):
        os.remove(log_file)
        print(f"🧹 Cleaned up {log_file}")

# Configure logging with DEBUG log level.
logging.basicConfig(
    filename="logger.log",
    level=logging.DEBUG,
    format="%(filename)s:%(lineno)s %(levelname)s:%(message)s",
)

print("✅ Logging configured")
# Out:
# 🧹 Cleaned up logger.log
# ✅ Logging configured

# %%
api_key = os.getenv("GEMINI_API_KEY")

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent, SequentialAgent, ParallelAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner, InMemoryRunner
from google.adk.plugins.logging_plugin import (LoggingPlugin)
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.adk.tools.tool_context import ToolContext
from google.adk.code_executors import BuiltInCodeExecutor
from google.genai import types

print("Sessions and context engineering (3a) and MAS (1b) and Tools (2a) ADK imports")
# Out:
# Sessions and context engineering (3a) and MAS (1b) and Tools (2a) ADK imports

# %%
APP_NAME = "Wellness Suite"
USER_ID = "default"
SESSION = "default"

MODEL_NAME = "gemini-2.5-flash-lite"

# %%
retry_config = types.HttpRetryOptions(
    attempts=3,
    exp_base=7, # Delay multiplier
    initial_delay=1, # initial delay before first retry (seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
# Create a SQLite database with DatabaseSessionService
db_url = "sqlite:///agentic_wellness_data.db"

# Set up Session Management
session_service = DatabaseSessionService(db_url=db_url)

# %%
# Helper functions for running a session
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")

# %%
# Session state management tools
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")

# 'user:' prefix indicates the following is user-specific data
def save_userinfo(
    tool_context: ToolContext, user_name: str, user_height: str, user_weight: str, user_gender: str, user_dietary_preferences: str,
    user_current_fitness_level: str, user_fitness_goals: str, user_injury_history: str,
) -> Dict[str, Any]:
    """
    Tool to record and save user personal wellness information in session state.

    Args:
        user_name: The username to store in session state
        user_height: The user's height to store in session state
        user_weight: The user's weight to store in session state
        user_gender: The user's gender to store in session state
        user_dietary_preferences: The user's dietary preferences to store in session state
        user_current_fitness_level: The user's current fitness level to store in session state
        user_fitness_goals: The user's fitness goals to store in session state
        user_injury_history: The user's injury history to store in session state
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:height"] = user_height
    tool_context.state["user:weight"] = user_weight
    tool_context.state["user:gender"] = user_gender
    tool_context.state["user:dietary_preferences"] = user_dietary_preferences
    tool_context.state["user:current_fitness_level"] = user_current_fitness_level
    tool_context.state["user:fitness_goals"] = user_fitness_goals
    tool_context.state["user:injury_history"] = user_injury_history

    return {"status": "success"}

# tools can read from session state. example:
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name from session state.
    """

    user_name = tool_context.state.get("user:name", "User name not found")
    user_height = tool_context.state.get("user:height", "User height not found")
    user_weight = tool_context.state.get("user:weight", "User weight not found")
    user_gender = tool_context.state.get("user:gender", "User gender not found")
    user_dietary_preferences = tool_context.state.get("user:dietary_preferences", "User dietary preferences not found")
    user_current_fitness_level = tool_context.state.get("user:current_fitness_level", "User current fitness level not found")
    user_fitness_goals = tool_context.state.get("user:fitness_goals", "User fitness goals not found")
    user_injury_history = tool_context.state.get("user:injury_history", "User injury history not found")

    return {"status": "success", "user_name": user_name, "height": user_height, "weight": user_weight, "gender": user_gender,
            "dietary_preferences": user_dietary_preferences, "current_fitness_level": user_current_fitness_level,
            "fitness_goals": user_fitness_goals, "injury_history": user_injury_history}

# %%
# Specialist Agents

# Fitness Trainer Agent: focuses on fitness
fitness_trainer_agent = LlmAgent(
    name="FitnessTrainer",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert fitness trainer with deep knowledge of human physiology.
    Please provide a detailed fitness training plan for the user that is customized for the following:
    1. The user's personal wellness information
    2. Their current level of fitness
    3. To help them achieve their fitness goals
    4. Takes into consideration their injury history
    5. Sets realistic time frames for developing lifting technique and expertise
    """,
    tools=[retrieve_userinfo],
    output_key="fitness_plan"
)

# Nutritionist Agent: focuses on nutrition
nutritionist_agent = LlmAgent(
    name="Nutritionist",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert nutritionist with deep knowledge of diet and human metabolism.
    Please provide a detailed nutrition plan for the user that is customized for the following:
    1. The user's personal wellness information
    2. Their dietary restrictions
    3. To help them achieve their weight and fitness goals
    4. Suggest meal plans that align with their preferences
    5. Ensure that the nutrition plan meets the macronutrient and micronutrient needs to achieve their goals
    """,
    tools=[retrieve_userinfo],
    output_key="nutrition_plan"
)

# %%
# Aggregator Agent

aggregator_agent = LlmAgent(
    name="WellnessAggregator",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""Combine the fitness plan and nutrition plan into a single wellness plan tailored for the user.
    Focus on the synergy between the fitness and nutrition aspects to maximize the user's health and wellness outcomes.

    **Fitness Plan:**
    {fitness_plan}

    **Nutrition Plan:**
    {nutrition_plan}

    Your final wellness plan should seamlessly integrate both components and provide clear, actionable recommendations.
    """,
    tools=[retrieve_userinfo],
    output_key="wellness_plan"
)

# %%
# Parallel Agent to run both specialists simultaneously
parallel_wellness_team = ParallelAgent(
    name="ParallelWellnessTeam",
    sub_agents=[fitness_trainer_agent, nutritionist_agent],
)

# %%
# Sequential Agent to run the parallel team first, then run the aggregator
sequential_wellness = SequentialAgent(
    name="WellnessSystem",
    sub_agents=[parallel_wellness_team, aggregator_agent],
)

# %%
# Intake Agent

intake_agent = LlmAgent(
    name="WellnessIntakeAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert wellness assistant agent with concise yet kind verbiage.
    Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about their health.
    Craft your questions to collect the most essential information (e.g. weight, height, dietary preferences, injury history, general fitness level).
    """,
    tools=[retrieve_userinfo],
    output_key="intake_questions",
)

# %%
# Centralized root Wellness Coordinator Agent to provide holistic wellness plan

root_agent = LlmAgent(
    name="WellnessCoordinatorAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are the Wellness Coordinator Agent.
    Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
    1. First, ascertain whether or not you have the user's necessary personal information to provide customized fitness and nutrition advice.
    2. If not, call the `intake_agent` tool to craft questions to obtain the necessary personal information.
    3. Once you have sufficient information, call the `wellness_pipeline` tool to create a wellness plan for the user.
    4. Present the results of the wellness plan to the user.
    """,
    tools=[
        save_userinfo,
        retrieve_userinfo,
        AgentTool(intake_agent),
        AgentTool(sequential_wellness)
    ],
)

# %%
# App with Events Compaction enabled
wellness_app_compacting = App(
    name="wellness_app_compacting",
    root_agent=root_agent,
    plugins=[LoggingPlugin()], 
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=2, # Trigger compaction every 2 invocations
        overlap_size=1, # Keep 1 previous turn for context
    ),
)
# Out:
# /var/folders/p1/bgzqkn9s51lc2t_bx4c0djmr0000gn/T/ipykernel_5318/2613804162.py:6: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %%
wellness_runner_compacting = Runner(app=wellness_app_compacting, session_service=session_service)

# %%
await run_session(
    wellness_runner_compacting,
    [
        """Hello! My name is Hector.
        """
    ],
    "test-db-session-02",
)
# Out:
#  ### Session: test-db-session-02
#
# User > Hello! My name is Hector.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-2d62d7bd-0249-4e6c-ab90-47a157736664
# [logging_plugin]    Session ID: test-db-session-02
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_coompacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'Hello! My name is Hector.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-2d62d7bd-0249-4e6c-ab90-47a157736664
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-2d62d7bd-0249-4e6c-ab90-47a157736664
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Token Usage - Input: 575, Output: 11
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e5943baa-e02d-4d0d-8b77-1a487a62a176
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['retrieve_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-a13e35c8-21a3-4ecf-adf9-ac0b8b2f777c
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-a13e35c8-21a3-4ecf-adf9-ac0b8b2f777c
# [logging_plugin]    Result: {'status': 'success', 'user_name': 'User name not found', 'height': 'User height not found', 'weight': 'User weight not found', 'gender': 'User gender not found', 'dietary_preferences': 'User dietary preferences not found', 'current_fitness_level': 'User current fitness level not found', 'fitness_go...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 358de221-a042-4bf8-938a-9faca2863662
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Hello Hector! To help you create a personalized wellness plan, I need a little more information. Could you please tell me about your:
#
# *   Height
# *   Weight
# *   Gender
# *   Dietary preferences (e.g., v...'
# [logging_plugin]    Token Usage - Input: 692, Output: 100
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0df45f15-460a-40db-9011-5d37324dae40
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Hello Hector! To help you create a personalized wellness plan, I need a little more information. Could you please tell me about your:
#
# *   Height
# *   Weight
# *   Gender
# *   Dietary preferences (e.g., v...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite >  Hello Hector! To help you create a personalized wellness plan, I need a little more information. Could you please tell me about your:
#
# *   Height
# *   Weight
# *   Gender
# *   Dietary preferences (e.g., vegetarian, vegan, no restrictions)
# *   Current fitness level (e.g., beginner, intermediate, advanced)
# *   Fitness goals (e.g., lose weight, build muscle, improve endurance)
# *   Any injury history?
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-2d62d7bd-0249-4e6c-ab90-47a157736664
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-2d62d7bd-0249-4e6c-ab90-47a157736664
# [logging_plugin]    Final Agent: WellnessCoordinatorAgent

# %%
await run_session(
    wellness_runner_compacting,
    [
        """I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
        I am currently sedentary but have prior powerlifting experience (about 7 years ago).
        I have no particular dietary preferences or restrictions.
        I tore my left rotator cuff and had it surgically repaired.
        I wish to lose weight and build muscle.
        """
    ],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
#         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#         I have no particular dietary preferences or restrictions.
#         I tore my left rotator cuff and had it surgically repaired.
#         I wish to lose weight and build muscle.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-403c1353-6471-4dbe-9e25-7d60d1be4ada
# [logging_plugin]    Session ID: test-db-session-01
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_coompacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'I am male, 30 years old, 5 foot 6 inches tall, and 170 pounds.
#         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#         I have no particular dietary prefere...'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-403c1353-6471-4dbe-9e25-7d60d1be4ada
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-403c1353-6471-4dbe-9e25-7d60d1be4ada
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Token Usage - Input: 648, Output: 108
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 3fa8f207-2309-48f7-b5c3-08cd3b7d6c31
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['save_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-a1074637-a315-49a6-838d-8e23c13dd2ab
# [logging_plugin]    Arguments: {'user_injury_history': 'left rotator cuff tear, surgically repaired', 'user_dietary_preferences': 'no particular dietary preferences or restrictions', 'user_name': 'John Doe', 'user_gender': 'male', 'user_weight': '170 pounds', 'user_current_fitness_level': 'sedentary with prior powerlifting experi...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-a1074637-a315-49a6-838d-8e23c13dd2ab
# [logging_plugin]    Result: {'status': 'success'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 581a124b-8bc0-4b8a-9f20-0b2374d1cf0b
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['save_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'It looks like I do not have your name yet, could you please provide it so I can make sure your wellness plan is properly personalized?'
# [logging_plugin]    Token Usage - Input: 772, Output: 28
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 56a6f235-2f35-45ab-968b-3d3e5eb92394
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'It looks like I do not have your name yet, could you please provide it so I can make sure your wellness plan is properly personalized?'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite >  It looks like I do not have your name yet, could you please provide it so I can make sure your wellness plan is properly personalized?
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-403c1353-6471-4dbe-9e25-7d60d1be4ada
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-403c1353-6471-4dbe-9e25-7d60d1be4ada
# [logging_plugin]    Final Agent: WellnessCoordinatorAgent

# %%
await run_session(
    wellness_runner_compacting,
    [
        """My name is Hector.
        """
    ],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > My name is Hector.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-97aa6be5-d9b8-488b-a16d-93099446bc74
# [logging_plugin]    Session ID: test-db-session-01
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_coompacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'My name is Hector.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-97aa6be5-d9b8-488b-a16d-93099446bc74
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-97aa6be5-d9b8-488b-a16d-93099446bc74
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Token Usage - Input: 809, Output: 107
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 94315124-1c0f-4852-8d3d-e684c142ad6c
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['save_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-532a0284-9a3f-4293-8e33-712ec9ced0a1
# [logging_plugin]    Arguments: {'user_height': '5 foot 6 inches', 'user_current_fitness_level': 'sedentary with prior powerlifting experience', 'user_weight': '170 pounds', 'user_dietary_preferences': 'no particular dietary preferences or restrictions', 'user_gender': 'male', 'user_injury_history': 'left rotator cuff tear, surgic...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-532a0284-9a3f-4293-8e33-712ec9ced0a1
# [logging_plugin]    Result: {'status': 'success'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ecac40ef-2c76-414c-9ab6-bfb033664f0a
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['save_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Token Usage - Input: 932, Output: 11
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 2bafe3dc-d174-472f-9f48-ca6c5511b950
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['retrieve_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-fb792305-3202-4140-abfd-053e74fe32bc
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-fb792305-3202-4140-abfd-053e74fe32bc
# [logging_plugin]    Result: {'status': 'success', 'user_name': 'Hector', 'height': '5 foot 6 inches', 'weight': '170 pounds', 'gender': 'male', 'dietary_preferences': 'no particular dietary preferences or restrictions', 'current_fitness_level': 'sedentary with prior powerlifting experience', 'fitness_goals': 'lose weight and b...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4976a3ce-68d2-45c3-9b17-1bb97290646f
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessSystem
# [logging_plugin]    Token Usage - Input: 1049, Output: 81
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 6c2a1398-57ff-4dd6-9a57-ada3d1b2428a
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessSystem
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['WellnessSystem']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: WellnessSystem
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-8c0b97a4-215d-48d7-a71f-0ceba42b59ad
# [logging_plugin]    Arguments: {'request': 'Hector is a 30-year-old male, 5 foot 6 inches tall, and 170 pounds. He is currently sedentary but has prior powerlifting experience. He has no particular dietary preferences or restrictions. He has a history of a surgically repaired left rotator cuff tear. Hector wishes to lose weight a...}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin]    Session ID: 974c9f72-1313-4b3e-b3d9-5e0b992f23cd
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_coompacting
# [logging_plugin]    Root Agent: WellnessSystem
# [logging_plugin]    User Content: text: 'Hector is a 30-year-old male, 5 foot 6 inches tall, and 170 pounds. He is currently sedentary but has prior powerlifting experience. He has no particular dietary preferences or restrictions. He has a ...'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin]    Starting Agent: WellnessSystem
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessSystem
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ParallelWellnessTeam
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: FitnessTrainer
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin]    Branch: ParallelWellnessTeam.FitnessTrainer
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: FitnessTrainer
# [logging_plugin]    System Instruction: 'You are an expert fitness trainer with deep knowledge of human physiology.
#     Please provide a detailed fitness training plan for the user that is customized for the following:
#     1. The user's pers...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: Nutritionist
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin]    Branch: ParallelWellnessTeam.Nutritionist
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    System Instruction: 'You are an expert nutritionist with deep knowledge of diet and human metabolism.
#     Please provide a detailed nutrition plan for the user that is customized for the following:
#     1. The user's perso...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    Content: text: 'Hello! Based on the information you've provided about Hector, here is a nutrition plan designed to help him lose weight and build muscle, while also considering his previous shoulder injury.
#
# **1. Und...'
# [logging_plugin]    Token Usage - Input: 218, Output: 1612
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 873ef18d-8a76-4231-9f71-aad6699f30ca
# [logging_plugin]    Author: Nutritionist
# [logging_plugin]    Content: text: 'Hello! Based on the information you've provided about Hector, here is a nutrition plan designed to help him lose weight and build muscle, while also considering his previous shoulder injury.
#
# **1. Und...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: Nutritionist
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: FitnessTrainer
# [logging_plugin]    Content: text: 'Hello Hector, it's great to hear from you! I understand you're looking to lose weight and build muscle. With your prior powerlifting experience and a history of a rotator cuff tear, we'll create a pla...'
# [logging_plugin]    Token Usage - Input: 209, Output: 1678
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: c22ed441-81fc-4e73-addb-dab6778e4b47
# [logging_plugin]    Author: FitnessTrainer
# [logging_plugin]    Content: text: 'Hello Hector, it's great to hear from you! I understand you're looking to lose weight and build muscle. With your prior powerlifting experience and a history of a rotator cuff tear, we'll create a pla...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: FitnessTrainer
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ParallelWellnessTeam
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessAggregator
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: WellnessAggregator
# [logging_plugin]    System Instruction: 'Combine the fitness plan and nutrition plan into a single wellness plan tailored for the user.
#     Focus on the synergy between the fitness and nutrition aspects to maximize the user's health and well...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessAggregator
# [logging_plugin]    Content: text: 'Here is a combined wellness plan for Hector, integrating both fitness and nutrition strategies to help him achieve his goals of weight loss and muscle gain, while carefully considering his previous ro...'
# [logging_plugin]    Token Usage - Input: 6797, Output: 1567
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: b66ad906-32a2-4e60-b858-8caf468dacba
# [logging_plugin]    Author: WellnessAggregator
# [logging_plugin]    Content: text: 'Here is a combined wellness plan for Hector, integrating both fitness and nutrition strategies to help him achieve his goals of weight loss and muscle gain, while carefully considering his previous ro...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessAggregator
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessSystem
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-8e9b979d-d781-442d-8a9f-58f1a5ead2e3
# [logging_plugin]    Final Agent: WellnessSystem
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: WellnessSystem
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-8c0b97a4-215d-48d7-a71f-0ceba42b59ad
# [logging_plugin]    Result: Here is a combined wellness plan for Hector, integrating both fitness and nutrition strategies to help him achieve his goals of weight loss and muscle gain, while carefully considering his previous rotator cuff injury:
#
# **Overall Wellness Plan for Hector**
#
# **Goals:** Lose weight and build muscle.
# *...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 7ee99c47-f7a1-4e24-b5b5-7fee8369303f
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: WellnessSystem
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['WellnessSystem']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Here is a combined wellness plan for Hector, integrating both fitness and nutrition strategies to help him achieve his goals of weight loss and muscle gain, while carefully considering his previous ro...'
# [logging_plugin]    Token Usage - Input: 2748, Output: 1567
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0a5a177a-4095-4fb2-bb4a-de8575089583
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Here is a combined wellness plan for Hector, integrating both fitness and nutrition strategies to help him achieve his goals of weight loss and muscle gain, while carefully considering his previous ro...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite >  Here is a combined wellness plan for Hector, integrating both fitness and nutrition strategies to help him achieve his goals of weight loss and muscle gain, while carefully considering his previous rotator cuff injury:
#
# **Overall Wellness Plan for Hector**
#
# **Goals:** Lose weight and build muscle.
# **Client Profile:** 30-year-old male, 5'6", 170 lbs, currently sedentary with prior powerlifting experience. History of surgically repaired left rotator cuff tear. No dietary restrictions.
#
# **I. Fitness Plan: Strength, Conditioning, and Injury Prevention**
#
# This plan balances muscle building with cardiovascular health and prioritizes safety for your shoulder.
#
# *   **Frequency:** Aim for 3-4 strength training days and 3-4 cardio sessions per week, allowing for rest and recovery.
# *   **Strength Training (3-4 days/week):**
#     *   **Focus:** Compound movements with a mindful approach to your shoulder.
#     *   **Structure:** Alternate muscle groups for adequate recovery (e.g., Upper Body Push, Lower Body, Upper Body Pull, Full Body/Lower Body focus).
#     *   **Exercise Examples:**
#         *   **Lower Body:** Goblet Squats, Romanian Deadlifts, Lunges, Leg Press, Hamstring Curls, Calf Raises.
#         *   **Upper Body (Push):** Dumbbell Bench Press, Dumbbell Overhead Press (controlled), Incline Dumbbell Press, Triceps Pushdowns.
#         *   **Upper Body (Pull):** Assisted Pull-ups/Lat Pulldowns, Dumbbell Rows, Face Pulls.
#         *   **Rotator Cuff Specific:** Incorporate into warm-ups/cool-downs: Banded external rotations, internal rotations, scaption with light resistance.
#     *   **Sets & Reps:** 3-4 sets of 8-12 reps for hypertrophy.
#     *   **Rest:** 60-90 seconds between sets.
# *   **Cardiovascular Training (3-4 days/week):**
#     *   **Goal:** Calorie expenditure for weight loss and cardiovascular health.
#     *   **Types:**
#         *   **Steady-State:** 30-45 minutes of moderate intensity (brisk walking, cycling, elliptical).
#         *   **HIIT:** 1-2 sessions/week, 15-20 minutes (short intense bursts followed by recovery).
#     *   **Placement:** Can be done on rest days or after strength training.
# *   **Warm-up (10-15 mins before each workout):**
#     *   Light cardio, dynamic stretching, and **crucially, shoulder-specific exercises** with light resistance bands (external rotations, internal rotations, face pulls).
# *   **Cool-down (10-15 mins after each workout):**
#     *   Static stretching and foam rolling.
# *   **Rotator Cuff Considerations:**
#     *   **Prioritize form:** Strict form over heavy weight, especially for shoulder and chest exercises.
#     *   **Controlled movements:** Avoid jerky motions.
#     *   **Listen to your body:** Stop or modify if you feel sharp shoulder pain.
#     *   **Consistency:** Regularly perform rotator cuff prehab/rehab exercises.
# *   **Getting Started:**
#     1.  **Medical Clearance:** Consult your doctor before starting.
#     2.  **Technique Focus:** Start with lighter weights to master form. Consider a few sessions with a trainer.
#     3.  **Consistency is Key:** Adhere to the plan as closely as possible.
#     4.  **Track Progress:** Log workouts and monitor body weight/measurements.
#
# **II. Nutrition Plan: Fueling Fat Loss and Muscle Gain**
#
# This plan supports your fitness goals while providing nutrients for recovery and overall health.
#
# *   **Caloric Intake:** Target **1700-1800 calories per day** to create a sustainable deficit for weight loss.
# *   **Macronutrient Breakdown:**
#     *   **Protein:** 140-150g per day (crucial for muscle repair and satiety).
#     *   **Fat:** 48-54g per day (essential for hormones and health).
#     *   **Carbohydrates:** ~180g per day (focus on complex carbs for energy).
# *   **Micronutrient Focus:**
#     *   **Anti-inflammatory:** Increase intake of Omega-3s (fatty fish, flaxseeds, walnuts) to aid recovery.
#     *   **Bone Health:** Ensure adequate Vitamin D and Calcium (dairy, fortified foods, leafy greens).
#     *   **Muscle Function:** Include sources of Magnesium (leafy greens, nuts, seeds).
#     *   **Tissue Repair:** Ensure sufficient Zinc (lean meats, seafood, legumes).
# *   **Meal Structure (Example - adjust portions as needed):**
#     *   **Breakfast (~400 kcal, 30g Protein):** 3 scrambled eggs, 1/2 cup oats, 1/2 cup berries, almonds.
#     *   **Lunch (~500 kcal, 45g Protein):** 5 oz grilled chicken/salmon, 1 cup quinoa/brown rice, large mixed greens salad with olive oil dressing.
#     *   **Snack (Pre/Post-Workout ~250 kcal, 25g Protein):** 1 cup Greek yogurt with 1 scoop whey protein, or a protein shake with a small banana.
#     *   **Dinner (~500 kcal, 40g Protein):** 5 oz lean ground turkey/beef, 1 medium sweet potato, 1.5 cups steamed broccoli/asparagus.
#     *   **Optional Snack (~100 kcal, 10g Protein):** 1/2 cup low-fat cottage cheese or a small handful of nuts.
# *   **Hydration:** Drink 3-4 liters of water daily, increasing around workouts.
# *   **Nutritional Considerations for Injury:**
#     *   Prioritize lean protein to support muscle repair.
#     *   Incorporate anti-inflammatory foods to help manage any lingering inflammation.
#     *   Pay attention to how your body responds to foods.
# *   **Flexibility:** Swap similar foods for variety. Adjust portion sizes based on hunger and fullness cues.
# *   **Monitoring:** Track your weight, energy levels, and workout performance. Adjust your intake as needed.
#
# **Synergy Between Fitness and Nutrition:**
#
# *   **Muscle Growth:** Adequate protein intake from your nutrition plan provides the building blocks for muscle, while the strength training stimulates muscle protein synthesis.
# *   **Weight Loss:** The calorie deficit from your nutrition plan, combined with the increased calorie expenditure from your cardio and strength training, will drive fat loss.
# *   **Energy Levels:** Complex carbohydrates in your diet will fuel your workouts, allowing you to train effectively.
# *   **Recovery:** Both proper nutrition (protein, healthy fats, micronutrients) and a structured fitness plan (rest days, proper warm-ups/cool-downs, rotator cuff specific exercises) are vital for recovery and preventing re-injury.
#
# This integrated plan provides a roadmap for Hector. Consistency, mindful execution of exercises, and attention to nutritional targets will be key to success. Remember to listen to your body, especially concerning your shoulder, and make adjustments as needed.
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-97aa6be5-d9b8-488b-a16d-93099446bc74
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-97aa6be5-d9b8-488b-a16d-93099446bc74
# [logging_plugin]    Final Agent: WellnessCoordinatorAgent

# %%
# Final session state
final_session = await session_service.get_session(
    app_name=wellness_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="test-db-session-01",
)

found_summary = False
for event in final_session.events:
    if event.actions and event.actions.compaction:
        print("Found Compaction Event")
        print(f"\n Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print("\n No compaction event found.")
# Out:
# Found Compaction Event
#
#  Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='989a8973-a966-4b18-929e-06b7b8352d2c' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1764282368.27571, 'end_timestamp': 1764282433.491149, 'compacted_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'The user, Hector (30M, 5\'6", 170 lbs), an ex-powerlifter with a surgically repaired left rotator cuff, sought assistance to lose weight and build muscle. He also mentioned no dietary preferences or restrictions.\n\nThe AI agent, a Wellness Coordinator, provided Hector with a comprehensive, personalized wellness plan.\n\n**Key components of the plan include:**\n\n1.  **Fitness Plan:**\n    *   **Frequency:** 3-4 strength training days and 3-4 cardio sessions per week.\n    *   **Strength:** Focus on compound movements (lower body, push, pull splits), 3-4 sets of 8-12 reps. Specific exercises were provided with a strong emphasis on controlled movements and form due to the rotator cuff injury. Rotator cuff specific exercises (banded rotations, face pulls) were integrated into warm-ups.\n    *   **Cardio:** Mix of steady-state and HIIT.\n    *   **Injury Prevention:** Strict form, light weights initially, listening to the body, and consistent rotator cuff exercises were highlighted.\n    *   **Starting Advice:** Medical clearance, technique focus (potentially with a trainer), consistency, and progress tracking.\n\n2.  **Nutrition Plan:**\n    *   **Caloric Intake:** Target of 1700-1800 calories per day for weight loss.\n    *   **Macronutrients:** High protein (140-150g), moderate fat (48-54g), and complex carbohydrates (~180g).\n    *   **Micronutrients:** Emphasis on anti-inflammatory foods (Omega-3s) and nutrients for bone/tissue repair (Vit D, Calcium, Magnesium, Zinc).\n    *   **Structure:** Example meal plan provided with suggested calorie and protein breakdowns per meal.\n    *   **Hydration:** 3-4 liters of water daily.\n\n**Unresolved Questions/Tasks:**\nThe immediate conversation is complete, with Hector having received his initial plan. However, the plan itself includes pending tasks for Hector:\n*   Consulting his doctor for medical clearance before starting.\n*   Potentially seeking a few sessions with a personal trainer to master form.\n*   Consistently tracking his progress and making adjustments as needed.', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}}, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='1c039f06-fd51-470a-811d-12771bde7b8b' timestamp=1764282444.135972

# %%
if os.path.exists("agentic_wellness_data.db"):
    os.remove("agentic_wellness_data.db")
print("Cleaned up old database files")
# Out:
# Cleaned up old database files
