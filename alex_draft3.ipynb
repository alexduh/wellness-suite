# %%
import logging
import os

# Clean up any previous logs
for log_file in ["logger.log", "web.log", "tunnel.log"]:
    if os.path.exists(log_file):
        os.remove(log_file)
        print(f"🧹 Cleaned up {log_file}")

# Configure logging with DEBUG log level.
logging.basicConfig(
    filename="logger.log",
    level=logging.DEBUG,
    format="%(filename)s:%(lineno)s %(levelname)s:%(message)s",
)

print("✅ Logging configured")
# Out:
# ✅ Logging configured

# %%
api_key = os.getenv("GEMINI_API_KEY")

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent, SequentialAgent, ParallelAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner, InMemoryRunner
from google.adk.plugins.logging_plugin import (LoggingPlugin)
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.adk.tools.tool_context import ToolContext
from google.adk.code_executors import BuiltInCodeExecutor
from google.genai import types

print("Sessions and context engineering (3a) and MAS (1b) and Tools (2a) ADK imports")
# Out:
# Sessions and context engineering (3a) and MAS (1b) and Tools (2a) ADK imports

# %%
APP_NAME = "Wellness Suite"
USER_ID = "default"
SESSION = "default"
# USER_PROFILE = {
#     "name": USER_ID,
#     "age": None,
#     "weight": None,
#     "height": None,
#     "goals": [],
#     "injuries": [],
#     "dietary_restrictions": []
# }

MODEL_NAME = "gemini-2.5-flash-lite"

# %%
retry_config = types.HttpRetryOptions(
    attempts=3,
    exp_base=7, # Delay multiplier
    initial_delay=1, # initial delay before first retry (seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
# Create a SQLite database with DatabaseSessionService
db_url = "sqlite:///agentic_wellness_data.db"

# Set up Session Management
session_service = DatabaseSessionService(db_url=db_url)

# %%
# Helper functions for running a session
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")

# %%
# Session state management tools
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")

# 'user:' prefix indicates the following is user-specific data
def save_userinfo(
    tool_context: ToolContext, user_name: str
) -> Dict[str, Any]:
    """
    Tool to record and save user name in session state.

    Args:
        user_name: The username to store in session state
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name

    return {"status": "success"}

# tools can read from session state. example:
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name from session state.
    """

    user_name = tool_context.state.get("user:name", "Username not found")

    return {"status": "success", "user_name": user_name}

# %%
# Specialist Agents

# Fitness Trainer Agent: focuses on fitness
fitness_trainer_agent = LlmAgent(
    name="FitnessTrainer",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert fitness trainer with deep knowledge of human physiology.
    Please provide a detailed fitness training plan for the user that is customized for the following:
    1. Their current level of fitness
    2. To help them achieve their fitness goals
    3. Takes into consideration their injury history
    4. Sets realistic time frames for developing lifting technique and expertise
    """,
    tools=[],
    output_key="fitness_plan"
)

# Nutritionist Agent: focuses on nutrition
nutritionist_agent = LlmAgent(
    name="Nutritionist",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert nutritionist with deep knowledge of diet and human metabolism.
    Please provide a detailed nutrition plan for the user that is customized for the following:
    1. Their dietary restrictions
    2. To help them achieve their weight and fitness goals
    3. Suggest meal plans that align with their preferences
    4. Ensure that the nutrition plan meets the macronutrient and micronutrient needs to achieve their goals
    """,
    tools=[],
    output_key="nutrition_plan"
)

# %%
# Aggregator Agent

aggregator_agent = LlmAgent(
    name="WellnessAggregator",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""Combine the fitness plan and nutrition plan into a single wellness plan tailored for the user.
    Focus on the synergy between the fitness and nutrition aspects to maximize the user's health and wellness outcomes.

    **Fitness Plan:**
    {fitness_plan}

    **Nutrition Plan:**
    {nutrition_plan}

    Your final wellness plan should seamlessly integrate both components and provide clear, actionable recommendations.
    """,
    tools=[retrieve_userinfo],
    output_key="wellness_plan"
)

# %%
# Parallel Agent to run both specialists simultaneously
parallel_wellness_team = ParallelAgent(
    name="ParallelWellnessTeam",
    sub_agents=[fitness_trainer_agent, nutritionist_agent],
)

# %%
# Sequential Agent to run the parallel team first, then run the aggregator
sequential_wellness = SequentialAgent(
    name="WellnessSystem",
    sub_agents=[parallel_wellness_team, aggregator_agent],
)

# %%
# Intake Agent

intake_agent = LlmAgent(
    name="WellnessIntakeAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert wellness assistant agent with concise yet kind verbiage.
    Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about their health.
    Craft your questions to collect the most essential information (e.g. weight, height, dietary preferences, injury history, general fitness level).
    """,
    tools=[retrieve_userinfo],
    output_key="intake_questions",
)

# %%
# Centralized root Wellness Coordinator Agent to provide holistic wellness plan

root_agent = LlmAgent(
    name="WellnessCoordinatorAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are the Wellness Coordinator Agent.
    Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
    1. First, ascertain whether or not you have the user's necessary personal information to provide customized fitness and nutrition advice.
    2. If not, call the `intake_agent` tool to craft questions to obtain the necessary personal information.
    3. Once you have sufficient information, call the `wellness_pipeline` tool to create a wellness plan for the user.
    4. Present the results of the wellness plan to the user.
    """,
    tools=[
        save_userinfo,
        retrieve_userinfo,
        AgentTool(intake_agent),
        AgentTool(sequential_wellness)
    ],
)

# %%
# App with Events Compaction enabled
wellness_app_compacting = App(
    name="wellness_app_coompacting",
    root_agent=root_agent,
    plugins=[LoggingPlugin()], 
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=2, # Trigger compaction every 2 invocations
        overlap_size=1, # Keep 1 previous turn for context
    ),
)
# Out:
# /var/folders/p1/bgzqkn9s51lc2t_bx4c0djmr0000gn/T/ipykernel_1564/2613804162.py:6: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %%
wellness_runner_compacting = Runner(app=wellness_app_compacting, session_service=session_service)

# %%
await run_session(
    wellness_runner_compacting,
    [
        """Hello! My name is Hector.
        """
    ],
    "test-db-session-02",
)
# Out:
#  ### Session: test-db-session-02
#
# User > Hello! My name is Hector.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-6e05e796-a206-44e2-87b0-61f5e8027454
# [logging_plugin]    Session ID: test-db-session-02
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_coompacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'Hello! My name is Hector.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-6e05e796-a206-44e2-87b0-61f5e8027454
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-6e05e796-a206-44e2-87b0-61f5e8027454
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Token Usage - Input: 318, Output: 18
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: a4a7d708-7138-440e-aeb2-183a6fe8cdfa
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['save_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-8da689ab-189c-4936-98be-320d3c3bf83f
# [logging_plugin]    Arguments: {'user_name': 'Hector'}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: save_userinfo
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-8da689ab-189c-4936-98be-320d3c3bf83f
# [logging_plugin]    Result: {'status': 'success'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 68aadebd-a56a-4538-9b3a-7419afd6ceef
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: save_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['save_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessIntakeAgent
# [logging_plugin]    Token Usage - Input: 352, Output: 29
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: b7f6e693-8e16-4927-81b4-09379110c2ef
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessIntakeAgent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['WellnessIntakeAgent']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: WellnessIntakeAgent
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-07c9e77f-ab5b-41d9-b5f9-9fc3467e5d7c
# [logging_plugin]    Arguments: {'request': 'I need to obtain necessary personal information to provide customized fitness and nutrition advice.'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-b9ed2099-c6d4-418b-aece-a174f0cb2bc0
# [logging_plugin]    Session ID: 665d69a2-f3d1-4cec-acc8-cb95f3d1851a
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_coompacting
# [logging_plugin]    Root Agent: WellnessIntakeAgent
# [logging_plugin]    User Content: text: 'I need to obtain necessary personal information to provide customized fitness and nutrition advice.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-b9ed2099-c6d4-418b-aece-a174f0cb2bc0
# [logging_plugin]    Starting Agent: WellnessIntakeAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessIntakeAgent
# [logging_plugin]    Invocation ID: e-b9ed2099-c6d4-418b-aece-a174f0cb2bc0
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    System Instruction: 'You are an expert wellness assistant agent with concise yet kind verbiage.
#     Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about t...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Content: text: 'Hello! I'd be happy to help you with personalized fitness and nutrition advice. To get started, could you please provide some information about yourself?
#
# To create the best plan for you, I'll need to...'
# [logging_plugin]    Token Usage - Input: 137, Output: 147
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4cdedef0-4900-48ee-ba11-d86f84ddac77
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: text: 'Hello! I'd be happy to help you with personalized fitness and nutrition advice. To get started, could you please provide some information about yourself?
#
# To create the best plan for you, I'll need to...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessIntakeAgent
# [logging_plugin]    Invocation ID: e-b9ed2099-c6d4-418b-aece-a174f0cb2bc0
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-b9ed2099-c6d4-418b-aece-a174f0cb2bc0
# [logging_plugin]    Final Agent: WellnessIntakeAgent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: WellnessIntakeAgent
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-07c9e77f-ab5b-41d9-b5f9-9fc3467e5d7c
# [logging_plugin]    Result: Hello! I'd be happy to help you with personalized fitness and nutrition advice. To get started, could you please provide some information about yourself?
#
# To create the best plan for you, I'll need to know your:
# *   **Weight** and **height**
# *   **Dietary preferences** (e.g., vegetarian, vegan, pesc...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9370e355-be0e-406f-b049-770e706dc240
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: WellnessIntakeAgent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['WellnessIntakeAgent']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Hello! I'd be happy to help you with personalized fitness and nutrition advice. To get started, could you please provide some information about yourself?
#
# To create the best plan for you, I'll need to...'
# [logging_plugin]    Token Usage - Input: 548, Output: 147
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 0ee8282d-2064-4063-9f4e-d499b15ec411
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Hello! I'd be happy to help you with personalized fitness and nutrition advice. To get started, could you please provide some information about yourself?
#
# To create the best plan for you, I'll need to...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite >  Hello! I'd be happy to help you with personalized fitness and nutrition advice. To get started, could you please provide some information about yourself?
#
# To create the best plan for you, I'll need to know your:
# *   **Weight** and **height**
# *   **Dietary preferences** (e.g., vegetarian, vegan, pescatarian, any allergies or dislikes)
# *   **Injury history** (any past or current injuries I should be aware of)
# *   **General fitness level** (e.g., beginner, intermediate, advanced, how often you currently exercise)
#
# Once I have this, I can start crafting a plan that's just right for you!
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-6e05e796-a206-44e2-87b0-61f5e8027454
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-6e05e796-a206-44e2-87b0-61f5e8027454
# [logging_plugin]    Final Agent: WellnessCoordinatorAgent

# %%
await run_session(
    wellness_runner_compacting,
    [
        """I am 30 years old, 5 foot 6 inches tall, and 170 pounds.
        I am currently sedentary but have prior powerlifting experience (about 7 years ago).
        I have no particular dietary preferences or restrictions.
        I tore my left rotator cuff and had it surgically repaired.
        """
    ],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > I am 30 years old, 5 foot 6 inches tall, and 170 pounds.
#         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#         I have no particular dietary preferences or restrictions.
#         I tore my left rotator cuff and had it surgically repaired.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-61b8f1fb-f142-48ea-a2bd-dbbbb1dff0bb
# [logging_plugin]    Session ID: test-db-session-01
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_coompacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'I am 30 years old, 5 foot 6 inches tall, and 170 pounds.
#         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#         I have no particular dietary preferences o...'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-61b8f1fb-f142-48ea-a2bd-dbbbb1dff0bb
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-61b8f1fb-f142-48ea-a2bd-dbbbb1dff0bb
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessIntakeAgent
# [logging_plugin]    Token Usage - Input: 378, Output: 60
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 406bfb0e-3dc8-4bdb-8daa-f35888fa80e1
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessIntakeAgent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['WellnessIntakeAgent']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: WellnessIntakeAgent
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-edf28860-abae-4c13-b714-4bb4081f72e3
# [logging_plugin]    Arguments: {'request': 'The user is 30 years old, 5\'6", 170 lbs, sedentary with prior powerlifting experience (7 years ago). They have no dietary preferences/restrictions and a surgically repaired left rotator cuff.'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-b9a22a54-e0f0-4526-82b4-8bf3cb09663e
# [logging_plugin]    Session ID: 4a990dbc-c260-46b8-85c9-f636d6b1c995
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_coompacting
# [logging_plugin]    Root Agent: WellnessIntakeAgent
# [logging_plugin]    User Content: text: 'The user is 30 years old, 5'6", 170 lbs, sedentary with prior powerlifting experience (7 years ago). They have no dietary preferences/restrictions and a surgically repaired left rotator cuff.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-b9a22a54-e0f0-4526-82b4-8bf3cb09663e
# [logging_plugin]    Starting Agent: WellnessIntakeAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessIntakeAgent
# [logging_plugin]    Invocation ID: e-b9a22a54-e0f0-4526-82b4-8bf3cb09663e
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    System Instruction: 'You are an expert wellness assistant agent with concise yet kind verbiage.
#     Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about t...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Token Usage - Input: 168, Output: 11
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 4b86560a-462f-4a6c-9054-568658f86b1e
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: function_call: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['retrieve_userinfo']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Function Call ID: adk-3aad5d28-2ed6-4b22-b52f-c41858215c72
# [logging_plugin]    Arguments: {}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: retrieve_userinfo
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Function Call ID: adk-3aad5d28-2ed6-4b22-b52f-c41858215c72
# [logging_plugin]    Result: {'status': 'success', 'user_name': 'Hector'}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 1d4371a9-938c-4b4f-a760-e687e81f79c9
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: function_response: retrieve_userinfo
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    System Instruction: 'You are an expert wellness assistant agent with concise yet kind verbiage.
#     Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about t...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessIntakeAgent
# [logging_plugin]    Content: text: 'Thank you for sharing, Hector! I appreciate you providing your information. To help me create the best plan for you, could you tell me a little more about your current fitness goals?'
# [logging_plugin]    Token Usage - Input: 203, Output: 37
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 623acde9-b13d-4404-b6fb-413de7a650b2
# [logging_plugin]    Author: WellnessIntakeAgent
# [logging_plugin]    Content: text: 'Thank you for sharing, Hector! I appreciate you providing your information. To help me create the best plan for you, could you tell me a little more about your current fitness goals?'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessIntakeAgent
# [logging_plugin]    Invocation ID: e-b9a22a54-e0f0-4526-82b4-8bf3cb09663e
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-b9a22a54-e0f0-4526-82b4-8bf3cb09663e
# [logging_plugin]    Final Agent: WellnessIntakeAgent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: WellnessIntakeAgent
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-edf28860-abae-4c13-b714-4bb4081f72e3
# [logging_plugin]    Result: Thank you for sharing, Hector! I appreciate you providing your information. To help me create the best plan for you, could you tell me a little more about your current fitness goals?
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: fa461dba-79bb-42ec-868b-34ed1137e90b
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: WellnessIntakeAgent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['WellnessIntakeAgent']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Thank you for sharing, Hector! I appreciate you providing your information. To help me create the best plan for you, could you tell me a little more about your current fitness goals?'
# [logging_plugin]    Token Usage - Input: 490, Output: 37
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 5797208e-6367-4e4b-9c83-a0ceec8efe90
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Thank you for sharing, Hector! I appreciate you providing your information. To help me create the best plan for you, could you tell me a little more about your current fitness goals?'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite >  Thank you for sharing, Hector! I appreciate you providing your information. To help me create the best plan for you, could you tell me a little more about your current fitness goals?
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-61b8f1fb-f142-48ea-a2bd-dbbbb1dff0bb
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-61b8f1fb-f142-48ea-a2bd-dbbbb1dff0bb
# [logging_plugin]    Final Agent: WellnessCoordinatorAgent

# %%
await run_session(
    wellness_runner_compacting,
    [
        """I wish to improve my overall fitness by losing weight while maintaining or building muscle mass and strength.
        """
    ],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > I wish to improve my overall fitness by losing weight while maintaining or building muscle mass and strength.
#
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-f16df921-80c5-4aec-84d1-2bf43ebcbbae
# [logging_plugin]    Session ID: test-db-session-01
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_coompacting
# [logging_plugin]    Root Agent: WellnessCoordinatorAgent
# [logging_plugin]    User Content: text: 'I wish to improve my overall fitness by losing weight while maintaining or building muscle mass and strength.'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-f16df921-80c5-4aec-84d1-2bf43ebcbbae
# [logging_plugin]    Starting Agent: WellnessCoordinatorAgent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-f16df921-80c5-4aec-84d1-2bf43ebcbbae
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessSystem
# [logging_plugin]    Token Usage - Input: 550, Output: 93
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: e078c115-dc9c-42ea-be0a-2d595ff8563b
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_call: WellnessSystem
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['WellnessSystem']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: WellnessSystem
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-d59a3f35-012e-4d34-bbbb-ab96f2ce9b3b
# [logging_plugin]    Arguments: {'request': 'The user is 30 years old, 5\'6" tall, and 170 pounds. They are currently sedentary but have prior powerlifting experience (about 7 years ago). They have no particular dietary preferences or restrictions. They tore their left rotator cuff and had it surgically repaired. Their fitness goa...}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin]    Session ID: 405d9598-f9b6-4b8e-9c37-5bf7cf658371
# [logging_plugin]    User ID: default
# [logging_plugin]    App Name: wellness_app_coompacting
# [logging_plugin]    Root Agent: WellnessSystem
# [logging_plugin]    User Content: text: 'The user is 30 years old, 5'6" tall, and 170 pounds. They are currently sedentary but have prior powerlifting experience (about 7 years ago). They have no particular dietary preferences or restriction...'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin]    Starting Agent: WellnessSystem
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessSystem
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: ParallelWellnessTeam
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: FitnessTrainer
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin]    Branch: ParallelWellnessTeam.FitnessTrainer
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: FitnessTrainer
# [logging_plugin]    System Instruction: 'You are an expert fitness trainer with deep knowledge of human physiology.
#     Please provide a detailed fitness training plan for the user that is customized for the following:
#     1. Their current l...'
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: Nutritionist
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin]    Branch: ParallelWellnessTeam.Nutritionist
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    System Instruction: 'You are an expert nutritionist with deep knowledge of diet and human metabolism.
#     Please provide a detailed nutrition plan for the user that is customized for the following:
#     1. Their dietary re...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: FitnessTrainer
# [logging_plugin]    Content: text: 'Alright, let's get you back on track and stronger than ever! It's great that you have a powerlifting background – that means you understand the fundamentals of lifting, even if it's been a while. Your...'
# [logging_plugin]    Token Usage - Input: 175, Output: 4373
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: a426ab7f-ef5c-4d9e-b61f-f02306a2d45e
# [logging_plugin]    Author: FitnessTrainer
# [logging_plugin]    Content: text: 'Alright, let's get you back on track and stronger than ever! It's great that you have a powerlifting background – that means you understand the fundamentals of lifting, even if it's been a while. Your...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: FitnessTrainer
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: Nutritionist
# [logging_plugin]    Content: text: 'Hello! I'm Nutritionist, your AI-powered nutritionist. I understand you're looking for a comprehensive nutrition plan to help you achieve your fitness goals. Given your age, height, current weight, se...'
# [logging_plugin]    Token Usage - Input: 184, Output: 3338
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 93720031-510e-47e2-90ba-387ad1203c6a
# [logging_plugin]    Author: Nutritionist
# [logging_plugin]    Content: text: 'Hello! I'm Nutritionist, your AI-powered nutritionist. I understand you're looking for a comprehensive nutrition plan to help you achieve your fitness goals. Given your age, height, current weight, se...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: Nutritionist
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: ParallelWellnessTeam
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: WellnessAggregator
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: WellnessAggregator
# [logging_plugin]    System Instruction: 'Combine the fitness plan and nutrition plan into a single wellness plan tailored for the user.
#     Focus on the synergy between the fitness and nutrition aspects to maximize the user's health and well...'
# [logging_plugin]    Available Tools: ['retrieve_userinfo']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessAggregator
# [logging_plugin]    Content: text: 'Here is your integrated wellness plan, combining fitness and nutrition to support your goals of improving overall fitness, losing weight, and building muscle and strength, with a special focus on your...'
# [logging_plugin]    Token Usage - Input: 15651, Output: 2097
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: a41481b8-1e8d-4cbb-9ba2-22b8149ecb64
# [logging_plugin]    Author: WellnessAggregator
# [logging_plugin]    Content: text: 'Here is your integrated wellness plan, combining fitness and nutrition to support your goals of improving overall fitness, losing weight, and building muscle and strength, with a special focus on your...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessAggregator
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessSystem
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-61254598-4f6f-4b12-a49c-692508395580
# [logging_plugin]    Final Agent: WellnessSystem
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: WellnessSystem
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Function Call ID: adk-d59a3f35-012e-4d34-bbbb-ab96f2ce9b3b
# [logging_plugin]    Result: Here is your integrated wellness plan, combining fitness and nutrition to support your goals of improving overall fitness, losing weight, and building muscle and strength, with a special focus on your rotator cuff recovery.
#
# ## Your Integrated Wellness Plan
#
# This plan is structured in phases, priori...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: d4892785-1e91-49b5-b981-5721f84859fe
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: function_response: WellnessSystem
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['WellnessSystem']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    System Instruction: 'You are the Wellness Coordinator Agent.
#     Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
#     1. First, ascertain whether or not you have th...'
# [logging_plugin]    Available Tools: ['save_userinfo', 'retrieve_userinfo', 'WellnessIntakeAgent', 'WellnessSystem']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Here is your integrated wellness plan, combining fitness and nutrition to support your goals of improving overall fitness, losing weight, and building muscle and strength, with a special focus on your...'
# [logging_plugin]    Token Usage - Input: 2853, Output: 2097
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: ee59266a-1382-42b2-8c76-177aa527ff3e
# [logging_plugin]    Author: WellnessCoordinatorAgent
# [logging_plugin]    Content: text: 'Here is your integrated wellness plan, combining fitness and nutrition to support your goals of improving overall fitness, losing weight, and building muscle and strength, with a special focus on your...'
# [logging_plugin]    Final Response: True
# gemini-2.5-flash-lite >  Here is your integrated wellness plan, combining fitness and nutrition to support your goals of improving overall fitness, losing weight, and building muscle and strength, with a special focus on your rotator cuff recovery.
#
# ## Your Integrated Wellness Plan
#
# This plan is structured in phases, prioritizing your shoulder health and gradual progression.
#
# **Core Principles:**
#
# *   **Synergy:** Fitness and nutrition work hand-in-hand. Adequate protein supports muscle repair from training, while proper nutrient timing and overall intake fuel your workouts and recovery. A calorie deficit aids weight loss, but it must be managed to preserve muscle mass, which your higher protein intake will help with.
# *   **Shoulder Health First:** All fitness activities will be guided by your shoulder's recovery. Pain is a signal to stop and reassess.
# *   **Consistency is Key:** Adherence to both the fitness and nutrition plan is crucial for achieving your goals.
#
# ---
#
# ### **Phase 1: Foundation & Rehabilitation (Weeks 1-8)**
#
# **Focus:** Re-establishing movement, building an aerobic base, gently strengthening your shoulder, and re-introducing resistance training at light loads. Nutrition will focus on supporting tissue repair and a moderate calorie deficit.
#
# **Fitness:**
#
# *   **Strength Training (3 days/week, non-consecutive):**
#     *   **Warm-up:** 10-15 mins light cardio + dynamic stretches including arm circles, shoulder dislocations (with band/PVC), band pull-aparts, scapular retractions, cat-cow, thoracic rotations, bodyweight squats, walking lunges.
#     *   **Rehab/Prehab:** Crucial for rotator cuff. Include external/internal rotations (theraband/light dumbbell), scapular push-ups, and face pulls (light band). Focus on controlled movements.
#     *   **Main Lifts:** Focus on form with Goblet Squats (3x8-12), Dumbbell RDLs (3x8-12), Push-ups (on knees/incline, 3xAMRAP), Dumbbell Rows (3x10-15 per arm).
#     *   **Shoulder Caution:** For Dumbbell Overhead Press (3x10-15), start with very light weight or just arms. **Immediately stop if you feel pain.** Adjust range of motion or substitute if needed.
#     *   **Core:** Plank (3x30-60 sec).
#     *   **Cool-down:** 5 mins static stretching.
# *   **Cardiovascular Training (3-4 days/week):**
#     *   **Type:** Low-impact: brisk walking, cycling, elliptical, swimming (if cleared).
#     *   **Duration:** 20-30 minutes.
#     *   **Intensity:** Moderate (RPE 5-6).
# *   **Rest & Recovery:** Aim for 7-9 hours of sleep. Include active recovery like light walking. Listen to your body.
#
# **Nutrition:**
#
# *   **Calorie Target:** ~1600-1700 calories per day. This provides a moderate deficit for weight loss while prioritizing muscle and recovery.
# *   **Macronutrients:**
#     *   Protein: ~140g (Crucial for muscle repair and satiety)
#     *   Fats: ~45-50g (Focus on healthy fats for hormone function and anti-inflammatory benefits)
#     *   Carbohydrates: ~170g (Focus on complex carbs for sustained energy)
# *   **Key Nutrients for Healing:** Emphasize Vitamin C (citrus, berries, peppers), Zinc (lean meats, seeds), Omega-3s (fatty fish, flax, chia), Magnesium (leafy greens, nuts), and Vitamin D.
# *   **Sample Meal Plan:** Follow the provided 3-day sample plan focusing on whole foods, balanced meals, and adequate hydration.
# *   **Hydration:** Aim for at least 8-10 glasses of water daily.
#
# **Important Considerations for Phase 1:**
#
# *   **Medical Clearance:** Get approval from your doctor/physical therapist before starting.
# *   **Pain Monitoring:** **Never push through sharp shoulder pain.** Modify or skip exercises as needed.
# *   **Technique Focus:** Prioritize perfect form over lifting heavy weight.
#
# ---
#
# ### **Phase 2: Progression & Strength Building (Weeks 9-20)**
#
# **Focus:** Gradually increasing training intensity, introducing more compound barbell movements, and continuing fat loss. Nutrition will support increased activity and muscle building.
#
# **Fitness:**
#
# *   **Strength Training (3-4 days/week):**
#     *   **Warm-up:** Continue Phase 1, add movement-specific warm-ups for main lifts.
#     *   **Rehab/Prehab:** Continue Phase 1 exercises, potentially with slight resistance increase or focus on controlled eccentrics.
#     *   **Main Lifts (Introduce Barbells Gradually):**
#         *   Barbell Squats (3-4x5-8)
#         *   Dumbbell RDLs or Barbell RDLs/Trap Bar Deadlifts (1-2x3-6) - **Extreme caution with shoulder and back on deadlifts.**
#         *   Bench Press (Barbell or Dumbbell) (3-4x5-8) - **Focus on scapular retraction; adjust grip/variant if painful.**
#         *   Barbell Rows (3-4x6-10)
#         *   Overhead Press (Barbell or Dumbbell) (3-4x5-8) - **Continue conservative approach. Omit if painful.**
#     *   **Accessory Work:** Add 2-3 exercises like pull-ups/lat pulldowns, dips, leg press, hamstring curls, triceps/bicep extensions.
#     *   **Progression:** Implement linear progression (add small weight weekly) or rep range progression.
# *   **Cardiovascular Training (3-4 days/week):**
#     *   **Type:** Mix steady-state (30-45 min moderate) with potentially 1-2 days of HIIT (shoulder-friendly modality).
#     *   **Intensity:** Moderate for steady-state, high for intervals.
# *   **Rest & Recovery:** Continue prioritizing sleep and consider foam rolling.
#
# **Nutrition:**
#
# *   **Calorie Target:** May need slight increase due to higher activity. Monitor weight and adjust. Continue moderate deficit.
# *   **Macronutrients:** Maintain high protein (~0.8-1g/lb bodyweight). Adjust fats/carbs based on energy needs and recovery.
# *   **Nutrient Timing:** Consider protein/carb intake around workouts.
# *   **Continue:** Focus on whole foods, hydration, and key micronutrients for healing.
#
# **Important Considerations for Phase 2:**
#
# *   **Listen to Your Shoulder:** This is paramount. Any persistent pain means we regress or modify.
# *   **Technique Refinement:** Focus on mastering barbell lifts with proper form.
#
# ---
#
# ### **Phase 3: Strength Specialization & Maintenance (Weeks 21 onwards)**
#
# **Focus:** Consolidating strength, refining technique, and maintaining a strong physique. Nutrition will align with specific goals (continued fat loss, lean gain, or maintenance).
#
# **Fitness:**
#
# *   **Strength Training (3-4 days/week):**
#     *   **Focus:** Performance on main lifts (Squat, Bench, Deadlift) with varied rep ranges (3-5 for strength, 6-10 for hypertrophy).
#     *   **Technique:** Optimize technique for efficiency and safety.
#     *   **Overhead Press:** Include only if shoulder is consistently pain-free.
#     *   **Accessory Work:** Target weaknesses and support main lifts.
#     *   **Advanced Techniques (Optional):** Consider pause reps, tempo work, etc.
# *   **Cardiovascular Training (2-3 days/week):**
#     *   **Type:** Mix of steady-state and HIIT based on preference and recovery.
#     *   **Duration:** 20-30 minutes.
# *   **Rest & Recovery:** Continue prioritizing sleep, mobility, and active recovery.
#
# **Nutrition:**
#
# *   **Calorie Target:** Adjust based on whether the primary goal is fat loss, muscle gain (slight surplus), or maintenance.
# *   **Macronutrients:** Maintain high protein. Adjust fats/carbs to suit your goal.
# *   **Micronutrients:** Ensure a varied diet rich in fruits and vegetables.
#
# **Important Considerations for Phase 3:**
#
# *   **Long-Term Listening:** Your shoulder may always need attention. Continue prehab exercises as needed.
# *   **Adaptability:** Be prepared to adjust the plan based on your body's feedback and evolving goals.
#
# ---
#
# ### **Overall Recommendations & Next Steps:**
#
# 1.  **Medical Clearance:** **This is the absolute first step.** Ensure your doctor and/or physical therapist have cleared you for this type of activity and diet. They may have specific recommendations for your rotator cuff.
# 2.  **Track Progress:** Keep a training log (exercises, sets, reps, weight, RPE) and monitor your weight and measurements. This data is vital for making informed adjustments.
# 3.  **Be Patient:** Rebuilding strength and fitness, especially after surgery, takes time. Celebrate small victories and stay consistent.
# 4.  **Hydration:** Continue to drink plenty of water throughout the day.
# 5.  **Listen to Your Body:** This cannot be stressed enough, especially concerning your shoulder. Discomfort is okay; sharp pain is not.
#
# This integrated plan provides a roadmap for your fitness journey. By carefully balancing training, nutrition, and recovery, you can effectively work towards your goals while prioritizing your shoulder's long-term health. Let's begin!
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: WellnessCoordinatorAgent
# [logging_plugin]    Invocation ID: e-f16df921-80c5-4aec-84d1-2bf43ebcbbae
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-f16df921-80c5-4aec-84d1-2bf43ebcbbae
# [logging_plugin]    Final Agent: WellnessCoordinatorAgent

# %%
# Final session state
final_session = await session_service.get_session(
    app_name=wellness_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="test-db-session-01",
)

found_summary = False
for event in final_session.events:
    if event.actions and event.actions.compaction:
        print("Found Compaction Event")
        print(f"\n Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print("\n No compaction event found.")
# Out:
# Found Compaction Event
#
#  Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='998fe9aa-b2b7-4277-9af9-84766e8b2190' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1764281223.844339, 'end_timestamp': 1764281263.562783, 'compacted_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'The user, a 30-year-old male (5\'6", 170 lbs) with prior powerlifting experience but currently sedentary, and a history of a surgically repaired left rotator cuff, seeks to improve overall fitness, lose weight, and maintain/build muscle mass and strength.\n\nThe AI agent, WellnessCoordinatorAgent, provided a comprehensive, phased integrated wellness plan (fitness and nutrition) with core principles emphasizing synergy, shoulder health, and consistency.\n\n**Key aspects of the plan include:**\n\n*   **Phase 1 (Weeks 1-8 - Foundation & Rehabilitation):** Focuses on re-establishing movement, gentle shoulder strengthening, light resistance training (e.g., Goblet Squats, Push-ups on knees/incline), and low-impact cardio. Nutrition targets a moderate calorie deficit (~1600-1700 kcal) with high protein (~140g) to support tissue repair and weight loss.\n*   **Phase 2 (Weeks 9-20 - Progression & Strength Building):** Gradually increases training intensity, introduces compound barbell movements (e.g., Barbell Squats, Bench Press) with continued caution for the shoulder, and integrates HIIT. Calorie targets may slightly increase to support activity.\n*   **Phase 3 (Weeks 21+ - Strength Specialization & Maintenance):** Focuses on consolidating strength, refining technique, and adjusting nutrition based on evolving goals (fat loss, lean gain, or maintenance).\n\n**Key decisions and important considerations:**\n\n*   **Rotator Cuff Safety:** The plan heavily emphasizes prioritizing shoulder health, advising users to stop immediately if pain is felt, and to proceed with caution on shoulder-intensive exercises (e.g., Overhead Press, Deadlifts).\n*   **Gradual Progression:** Exercises and intensity increase progressively across phases.\n*   **Nutritional Focus:** High protein intake is consistent across all phases for muscle maintenance and repair, alongside a calorie deficit for weight loss and emphasis on nutrients for healing.\n\n**Unresolved questions or tasks:**\n\n*   **Medical Clearance:** The absolute first step is to obtain medical clearance from a doctor or physical therapist before starting the plan.\n*   The plan provides a framework, but the user needs to actively implement and track their progress, remain patient, prioritize hydration, and consistently listen to their body.', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}}, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='c5333c80-3bde-472e-a99e-aaa4925e8581' timestamp=1764281276.559222

# %%
if os.path.exists("agentic_wellness_data.db"):
    os.remove("agentic_wellness_data.db")
print("Cleaned up old database files")
# Out:
# Cleaned up old database files
