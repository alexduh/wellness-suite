# %%
import os

# %%
api_key = os.getenv("GEMINI_API_KEY")

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent, SequentialAgent, ParallelAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner, InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.adk.tools.tool_context import ToolContext
from google.adk.code_executors import BuiltInCodeExecutor
from google.genai import types

print("Sessions and context engineering (3a) and MAS (1b) and Tools (2a) ADK imports")
# Out:
# Sessions and context engineering (3a) and MAS (1b) and Tools (2a) ADK imports

# %%
APP_NAME = "Wellness Suite"
USER_ID = "Hector"
SESSION = "default"
# USER_PROFILE = {
#     "name": USER_ID,
#     "age": None,
#     "weight": None,
#     "height": None,
#     "goals": [],
#     "injuries": [],
#     "dietary_restrictions": []
# }

MODEL_NAME = "gemini-2.5-flash-lite"

# %%
retry_config = types.HttpRetryOptions(
    attempts=3,
    exp_base=7, # Delay multiplier
    initial_delay=1, # initial delay before first retry (seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
# Set up Session Management (stored in RAM)
session_service = InMemorySessionService()

# %%
# Helper functions for running a session
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")

# %%
# Specialist Agents

# Fitness Trainer Agent: focuses on fitness
fitness_trainer_agent = Agent(
    name="FitnessTrainer",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert fitness trainer with deep knowledge of human physiology.
    Please provide a detailed fitness training plan for the user that is customized for the following:
    1. Their current level of fitness
    2. To help them achieve their fitness goals
    3. Takes into consideration their injury history
    4. Sets realistic time frames for developing lifting technique and expertise
    """,
    tools=[],
    output_key="fitness_plan"
)

# Nutritionist Agent: focuses on nutrition
nutritionist_agent = Agent(
    name="Nutritionist",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert nutritionist with deep knowledge of diet and human metabolism.
    Please provide a detailed nutrition plan for the user that is customized for the following:
    1. Their dietary restrictions
    2. To help them achieve their weight and fitness goals
    3. Suggest meal plans that align with their preferences
    4. Ensure that the nutrition plan meets the macronutrient and micronutrient needs to achieve their goals
    """,
    tools=[],
    output_key="nutrition_plan"
)

# %%
# Aggregator Agent

aggregator_agent = Agent(
    name="WellnessAggregator",
    model=Gemini(
        model=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""Combine the fitness plan and nutrition plan into a single wellness plan tailored for the user.
    Focus on the synergy between the fitness and nutrition aspects to maximize the user's health and wellness outcomes.

    **Fitness Plan:**
    {fitness_plan}

    **Nutrition Plan:**
    {nutrition_plan}

    Your final wellness plan should seamlessly integrate both components and provide clear, actionable recommendations.
    """,
    output_key="wellness_plan"
)

# %%
# Parallel Agent to run both specialists simultaneously
parallel_wellness_team = ParallelAgent(
    name="ParallelWellnessTeam",
    sub_agents=[fitness_trainer_agent, nutritionist_agent],
)

# %%
# Sequential Agent to run the parallel team first, then run the aggregator
wellness_pipeline = SequentialAgent(
    name="WellnessSystem",
    sub_agents=[parallel_wellness_team, aggregator_agent],
)

# %%
# Intake Agent

intake_agent = Agent(
    name="WellnessIntakeAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are an expert wellness assistant agent with concise yet kind verbiage.
    Ensure that the user provides necessary personal information for fitness and nutrition advice by asking questions about their health.
    Craft your questions to collect the most essential information (e.g. weight, height, dietary preferences, injury history, general fitness level).
    """,
    tools=[],
    output_key="intake_questions",
)

# %%
# Centralized root Wellness Coordinator Agent to provide holistic wellness plan

root_agent = Agent(
    name="WellnessCoordinatorAgent",
    model=Gemini(
        model_name=MODEL_NAME,
        retry_options=retry_config
    ),
    instruction="""You are the Wellness Coordinator Agent.
    Your goal is to assist users in improving their overall wellness by orchestrating the following workflow.
    1. First, ascertain whether or not you have the user's necessary personal information to provide customized fitness and nutrition advice.
    2. If not, call the `intake_agent` tool to craft questions to obtain the necessary personal information.
    3. Once you have sufficient information, call the `wellness_pipeline` tool to create a wellness plan for the user.
    4. Present the results of the wellness plan to the user.
    """,
    tools=[
        AgentTool(intake_agent),
        AgentTool(wellness_pipeline)
    ],
)

# %%
runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

# %%
await run_session(
    runner,
    [
        """Hello! My name is Hector.
        """
    ],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > Hello! My name is Hector.
# Warning: there are non-text parts in the response: ['function_call', 'thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  Hello Hector! It's great to connect with you. To help me create the most effective and personalized wellness plan for you, I need a little more information.
#
# Could you please tell me:
#
# *   **Your age, height, and current weight?**
# *   **What's your general fitness level or how active are you typically?** (e.g., sedentary, moderately active, very active)
# *   **Do you have any dietary preferences or restrictions I should know about?** (e.g., vegetarian, gluten-free, allergies)
# *   **And finally, are there any past or current injuries that I should be aware of when designing your plan?**
#
# Once I have these details, I can start crafting something truly special for you!

# %%
await run_session(
    runner,
    [
        """I am 30 years old, 5 foot 6 inches tall, and 170 pounds.
        I am currently sedentary but have prior powerlifting experience (about 7 years ago).
        I have no particular dietary preferences or restrictions.
        I tore my left rotator cuff and had it surgically repaired.
        """
    ],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > I am 30 years old, 5 foot 6 inches tall, and 170 pounds.
#         I am currently sedentary but have prior powerlifting experience (about 7 years ago).
#         I have no particular dietary preferences or restrictions.
#         I tore my left rotator cuff and had it surgically repaired.
# Warning: there are non-text parts in the response: ['function_call', 'thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  Hector, this is fantastic news! I've put together a comprehensive wellness plan specifically tailored to your unique profile, taking into account your age, height, weight, prior powerlifting experience, current activity level, and most importantly, your surgically repaired left rotator cuff.
#
# This plan is all about a gradual and safe return to strength, rebuilding your muscles, improving your cardiovascular health, and ensuring your shoulder stays healthy. We'll be working towards achieving a healthier body composition together!
#
# Here's a snapshot of what your plan entails:
#
# *   **Nutritional Focus:** We're looking at approximately **2250 calories per day**, with a strong emphasis on protein (180-220g) to support muscle repair, good carbohydrates for fuel, and healthy fats for overall well-being. Hydration is key, so aim for at least a gallon of water daily.
# *   **Fitness Approach:** Your rotator cuff health is paramount! We'll start with foundational movements, slowly and deliberately increasing intensity. Your powerlifting background will be an asset, but we'll adapt movements to your current capacity.
#
# The plan is divided into three phases to ensure progressive adaptation and recovery:
#
# ### Phase 1: Foundation & Rehabilitation (Weeks 1-4)
# This phase focuses on re-establishing basic movement patterns, activating stabilizing muscles, and building a cardiovascular base, with a strong emphasis on shoulder mobility and strength. You'll have two full-body strength and mobility sessions per week, two light cardio and core sessions, and two active recovery days. We'll be doing crucial rehab exercises for your shoulder to ensure it's well-supported.
#
# ### Phase 2: Building Strength & Introducing Compound Lifts (Weeks 5-12)
# Here, we'll gradually increase resistance and introduce modified powerlifting movements. You'll have dedicated lower body, upper body (shoulder-conscious), and full-body strength days, alongside cardio and active recovery. We'll carefully integrate lifts like squats, Romanian deadlifts, and cautious upper body movements, always prioritizing your shoulder.
#
# ### Phase 3: Strength Progression & Refinement (Weeks 13+)
# This phase is about progressively increasing intensity and volume, refining your technique, and continuing to build muscle and cardiovascular fitness. We'll have specific lower body strength, upper body hypertrophy, and powerlifting-focused full-body sessions, alongside a mix of moderate and high-intensity cardio.
#
# **Throughout this journey, consistent monitoring and listening to your body will be crucial.** We'll be tracking your progress, noting how you feel, and adjusting as needed. If something hurts, we stop and modify. Patience is truly your best friend here, as rebuilding strength after surgery takes time. Celebrate every step forward, no matter how small!
#
# I'm incredibly excited for you to embark on this journey. By harmonizing your nutrition and fitness efforts and prioritizing your shoulder health, you are well-positioned to achieve your strength, conditioning, and body composition goals safely and effectively. Let's do this, Hector!

# %%
await run_session(
    runner,
    [
        """Can you go into detail about each of the phases of the wellness plan?
        """
    ],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > Can you go into detail about each of the phases of the wellness plan?
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  Absolutely, Hector! Let's break down each phase of your personalized wellness plan in detail.
#
# ---
#
# ### Phase 1: Foundation & Rehabilitation (Weeks 1-4)
#
# **Focus:** The primary goal here is to re-establish basic movement patterns, activate stabilizing muscles, improve both shoulder mobility and strength, and build a foundational cardiovascular base. This phase places a strong emphasis on **technique development and executing movements without pain.**
#
# **Weekly Schedule:**
#
# *   **Monday:** Full Body Strength & Mobility (Focus: Shoulder Health)
# *   **Tuesday:** Light Cardio & Core
# *   **Wednesday:** Active Recovery / Rest
# *   **Thursday:** Full Body Strength & Mobility (Focus: Shoulder Health)
# *   **Friday:** Light Cardio & Core
# *   **Saturday:** Active Recovery / Rest
# *   **Sunday:** Rest
#
# **Detailed Breakdown:**
#
# **1. Strength & Mobility (Monday & Thursday)**
#
# *   **Nutrition Focus:** Maintain your target of approximately **2250 calories** with a strong emphasis on lean protein and anti-inflammatory foods to support initial recovery and muscle adaptation.
# *   **Warm-up (10-15 minutes):**
#     *   **Cardio:** 5 minutes of light cardio (e.g., brisk walking, stationary cycling).
#     *   **Dynamic Stretching:** Controlled arm circles, shoulder pass-throughs (using a light resistance band or PVC pipe), cat-cow stretch, thoracic rotations, bird-dog, glute bridges, and bodyweight squats.
# *   **Rehab/Prehab Exercises (Crucial for Shoulder Health - Perform EVERY session):** These are vital for stabilizing and strengthening your rotator cuff and surrounding shoulder muscles.
#     *   **Band External Rotations (elbow tucked):** 2 sets of 15 reps
#     *   **Band Internal Rotations (elbow tucked):** 2 sets of 15 reps
#     *   **Scapular Retractions:** 2 sets of 15 reps (focus on squeezing your shoulder blades together)
#     *   **Wall Angels:** 2 sets of 10 reps (focus on keeping your arms and back flat against the wall)
#     *   **Resistance Band Pull-Aparts:** 2 sets of 15 reps
# *   **Strength Exercises (Choose 4-5, prioritize excellent form over weight):**
#     *   **Bodyweight Squats:** 3 sets of 10-12 reps
#     *   **Glute Bridges:** 3 sets of 15 reps
#     *   **Push-ups (on knees or incline against a wall/bench):** 3 sets AMRAP (As Many Reps As Possible), but **STOP IMMEDIATELY if you feel any shoulder pain.**
#     *   **Dumbbell Rows (seated or supported by a bench):** 3 sets of 10-12 reps per arm (use a very light weight, maintain a stable shoulder).
#     *   **Plank:** 3 sets, hold for 30-60 seconds.
#     *   **Pallof Press:** 3 sets of 10-12 reps per side (anti-rotation exercise using a cable machine or resistance band).
#     *   *Optional (only if completely pain-free):* **Light Dumbbell Bench Press:** 3 sets of 10-12 reps (use very light dumbbells, maintain a controlled range of motion, and stop if any shoulder discomfort).
# *   **Cool-down (5-10 minutes):** Static stretching focusing on hamstrings, quadriceps, glutes, back, a gentle chest stretch, and gentle shoulder stretches like Child's Pose and Thread the Needle.
#
# **2. Light Cardio & Core (Tuesday & Friday)**
#
# *   **Nutrition Focus:** Ensure adequate hydration throughout the day, and consider a small post-workout replenishment if you do these sessions after strength training.
# *   **Cardio (20-30 minutes):** Engage in low-impact activities like walking, cycling, or using an elliptical machine. Maintain a conversational pace, aiming for Zone 2 heart rate (where you can talk comfortably but are slightly out of breath).
# *   **Core Work (10-15 minutes):**
#     *   **Crunches:** 3 sets of 15-20 reps
#     *   **Leg Raises:** 3 sets of 15-20 reps
#     *   **Russian Twists (bodyweight, controlled):** 3 sets of 15-20 reps per side
#     *   **Dead Bug:** 3 sets of 10-12 reps per side (focus on core engagement and controlled movement).
#
# **3. Active Recovery (Wednesday & Saturday)**
#
# *   **Nutrition Focus:** Concentrate on nutrient-dense foods to aid in muscle repair and recovery.
# *   **Options:** Engage in light walking for 30-45 minutes, gentle stretching, a restorative yoga session, or foam rolling to address any muscle soreness.
#
# ---
#
# ### Phase 2: Building Strength & Introducing Compound Lifts (Weeks 5-12)
#
# **Focus:** In this phase, we'll gradually increase the weight or resistance, begin to introduce modified powerlifting movements, and continue to improve your shoulder stability. **Refining your technique remains a critical component.**
#
# **Weekly Schedule:**
#
# *   **Monday:** Lower Body Focus
# *   **Tuesday:** Upper Body & Core (Shoulder-Conscious)
# *   **Wednesday:** Cardio & Active Recovery
# *   **Thursday:** Full Body Strength
# *   **Friday:** Cardio & Core
# *   **Saturday:** Active Recovery / Optional Light Skill Work
# *   **Sunday:** Rest
#
# **Detailed Breakdown:**
#
# **1. Lower Body Focus (Monday)**
#
# *   **Nutrition Focus:** Continue with approximately **2250 calories**, ensuring adequate carbohydrate intake both before and after your workout to fuel these more demanding sessions.
# *   **Warm-up:** Perform the Phase 1 warm-up, adding in extra hip mobility drills.
# *   **Strength Exercises:**
#     *   **Barbell Back Squat:** 3 sets of 6-8 reps. Start very light, focus intently on perfect form, and ensure the bar position feels comfortable on your back.
#     *   **Romanian Deadlifts (RDLs):** 3 sets of 8-10 reps (can use dumbbells or a light barbell). Focus on feeling the stretch in your hamstrings.
#     *   **Leg Press:** 3 sets of 10-12 reps.
#     *   **Calf Raises:** 3 sets of 15-20 reps.
#     *   **Hip Thrusts:** 3 sets of 10-12 reps.
# *   **Cool-down:** Focus on lower body stretches.
#
# **2. Upper Body & Core (Tuesday)**
#
# *   **Nutrition Focus:** Ensure you're getting sufficient protein intake to support muscle repair and growth after this upper body session.
# *   **Warm-up:** Perform a thorough Phase 1 warm-up, with extra attention on your shoulder prehab exercises.
# *   **Rehab/Prehab Exercises:** Continue with the exercises from Phase 1. If you're feeling good, you can consider a slight increase in resistance on your bands.
# *   **Strength Exercises:**
#     *   **Incline Dumbbell Press:** 3 sets of 8-10 reps. Use a light weight, maintain a controlled range of motion, and **STOP IMMEDIATELY if you experience any shoulder pain.**
#     *   **Seated Cable Rows:** 3 sets of 10-12 reps. Focus on retracting your shoulder blades.
#     *   **Lat Pulldowns:** 3 sets of 10-12 reps.
#     *   ***Cautious Exercise:*** **Overhead Press (Dumbbell, seated, very light):** 2 sets of 8-10 reps. **STOP if you feel any discomfort.** Prioritize scapular (shoulder blade) stability and controlled movement. This exercise requires careful monitoring due to your past injury.
#     *   **Bicep Curls:** 3 sets of 10-12 reps.
#     *   **Triceps Pushdowns:** 3 sets of 10-12 reps.
#     *   **Face Pulls:** 3 sets of 15-20 reps (excellent for shoulder health).
# *   **Core Work:** Incorporate planks, side planks, and anti-rotation exercises (like the Pallof Press) to further strengthen your core.
# *   **Cool-down:** Stretch your upper body and core.
#
# **3. Full Body Strength (Thursday)**
#
# *   **Nutrition Focus:** Ensure you are well-fueled for this demanding full-body session.
# *   **Warm-up:** Perform a comprehensive full-body dynamic warm-up.
# *   **Strength Exercises:**
#     *   **Deadlift (Conventional or Sumo):** 1-2 sets of 3-5 reps. Start very light, focus intensely on perfect form. If your grip or shoulder becomes a limiting factor, consider using lifting straps to allow you to focus on the movement.
#     *   **Front Squats or Goblet Squats:** 3 sets of 6-8 reps. These are excellent alternatives for developing core stability and leg strength.
#     *   **Dumbbell Bench Press (Flat, light):** 3 sets of 8-10 reps. Continue to monitor your shoulder closely.
#     *   **Barbell Rows (Pendlay or Bent-Over):** 3 sets of 8-10 reps. Maintain a rigid torso throughout the movement.
#     *   **Pull-ups/Assisted Pull-ups (using a band or machine):** 3 sets AMRAP (as many reps as possible, or a target range if using assistance).
# *   **Cool-down:** Perform full-body static stretching.
#
# **4. Cardio & Active Recovery (Wednesday, Friday, Saturday)**
#
# *   **Nutrition Focus:** Prioritize hydration and consistent recovery nutrition.
# *   **Cardio:** Wednesday: 30-40 minutes, you can slightly increase the intensity from Phase 1. Friday: 20-30 minutes, you can begin to introduce short intervals (e.g., alternating between a faster pace and a recovery pace).
# *   **Active Recovery:** Continue with the activities outlined in Phase 1 (light walking, stretching, foam rolling).
#
# ---
#
# ### Phase 3: Strength Progression & Refinement (Weeks 13+)
#
# **Focus:** This advanced phase concentrates on gradually increasing the intensity and volume of your compound lifts, refining your technique, building muscle hypertrophy (growth), and further improving your cardiovascular fitness. **Consistent practice and deeply listening to your body are paramount for continued safe progress.**
#
# **Weekly Schedule:**
#
# *   **Monday:** Lower Body Strength
# *   **Tuesday:** Upper Body Hypertrophy (Shoulder-Conscious)
# *   **Wednesday:** Moderate Cardio & Mobility
# *   **Thursday:** Full Body Strength (Powerlifting Focus)
# *   **Friday:** High-Intensity Cardio / Active Recovery
# *   **Saturday:** Active Recovery / Skill Work
# *   **Sunday:** Rest
#
# **Detailed Breakdown:**
#
# **1. Lower Body Strength (Monday)**
#
# *   **Nutrition Focus:** You might adjust your calorie target here. If your primary goal is muscle gain, consider a slight caloric surplus (~2300-2400 calories). If you're aiming for body recomposition (building muscle and losing fat simultaneously), stick closer to maintenance or a slight deficit (~2000-2100 calories). Maintain a high protein intake regardless.
# *   **Warm-up:** Focus on dynamic movements specific to your lower body.
# *   **Strength Exercises:**
#     *   **Barbell Back Squat:** 3-4 sets of 5-7 reps. This is where progressive overload becomes key – aim to gradually increase weight or reps over time while maintaining perfect form.
#     *   **Deadlift:** 1-2 working sets of 3-5 reps. Continue progressive overload. If your grip or shoulder stability is still a concern with heavier weights, strategically use lifting straps to ensure you can lift safely.
#     *   **Leg Press/Hack Squat:** 3 sets of 8-10 reps.
#     *   **Hamstring Curls:** 3 sets of 10-12 reps.
#     *   **Glute Ham Raises (GHR) or Nordic Hamstring Curls:** 3 sets AMRAP (As Many Reps As Possible), or target a specific rep range if using assistance.
#     *   **Calf Raises:** 3 sets of 15-20 reps.
#
# **2. Upper Body Hypertrophy (Tuesday)**
#
# *   **Nutrition Focus:** Ensure ample protein for muscle repair and growth after these higher-volume upper body sessions.
# *   **Warm-up:** Perform a thorough shoulder-specific warm-up, continuing any necessary prehab.
# *   **Rehab/Prehab:** Continue with your rotator cuff exercises as needed, or transition to a maintenance routine if your shoulder feels very robust.
# *   **Strength Exercises:**
#     *   **Bench Press (Barbell or Dumbbell):** 3-4 sets of 6-8 reps. Prioritize perfect form and a pain-free range of motion. If standard bench press causes any discomfort, consider variations like Spoto press (pausing just above the chest) or floor press.
#     *   **Overhead Press (Dumbbell or Barbell):** 3 sets of 6-8 reps. Continue with cautious monitoring. If any pain arises, immediately revert to lighter variations or alternative exercises that don't stress the shoulder.
#     *   **Incline Dumbbell Press:** 3 sets of 8-10 reps.
#     *   **Pull-ups/Weighted Pull-ups:** 3 sets AMRAP (if bodyweight) or 5-8 reps (if adding weight).
#     *   **Dumbbell Rows:** 3 sets of 8-10 reps per arm.
#     *   **Lateral Raises:** 3 sets of 10-12 reps (for shoulder width and health).
#     *   **Rear Delt Flyes:** 3 sets of 12-15 reps (crucial for shoulder balance and posture).
#     *   **Bicep Curls (various grips/angles):** 3 sets of 10-12 reps.
#     *   **Triceps Extensions (various):** 3 sets of 10-12 reps.
#     *   **Face Pulls:** 3 sets of 15-20 reps.
#
# **3. Full Body Strength (Thursday - Powerlifting Focus)**
#
# *   **Nutrition Focus:** Ensure you are sufficiently fueled for these more demanding powerlifting-style workouts.
# *   **Warm-up:** Perform dynamic movements tailored to the main lifts for the day.
# *   **Strength Exercises:**
#     *   **Primary Lift:** Choose one of the main powerlifting movements (Squat, Bench, or Deadlift) for focused intensity. Work up to 1-2 heavy sets of 3-5 reps. You'll rotate which lift is "primary" each week.
#     *   **Secondary Compound Lift:** Follow with another compound lift (e.g., if you squatted heavy, do some moderate bench or deadlifts) for 3 sets of 6-8 reps.
#     *   **Accessory Lifts:** Choose 2-3 exercises specifically for shoulder health and any lagging muscle groups (e.g., more rows, face pulls, dedicated rotator cuff work). Perform 3 sets of 10-15 reps.
#
# **4. Cardio & Active Recovery**
#
# *   **Nutrition Focus:** Replenish lost fluids and nutrients to optimize recovery.
# *   **Cardio:** Wednesday: 30-40 minutes of moderate intensity cardio (Zone 2-3). Friday: 20-30 minutes of higher intensity cardio. This could include HIIT (High-Intensity Interval Training), sprints, or plyometrics, but **only if your shoulder allows for these more explosive movements without any pain or discomfort.**
# *   **Active Recovery:** Essential for managing fatigue, promoting blood flow, and preventing injury. Continue with light activities, stretching, and foam rolling.
#
# ---
#
# Remember, Hector, this plan is a detailed roadmap. Your body's feedback is the ultimate guide. Always prioritize pain-free movement and good form over lifting heavy. Consistency, patience, and smart adjustments will be the keys to your success!
